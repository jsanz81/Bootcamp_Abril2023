# %% [markdown]
# # Primer Paso
# Ejecutar el fichero Refactorzación

# %%
import pandas as pd

df_1=pd.read_csv("./Parte_1.csv",sep=";",decimal=",")
df_2=pd.read_csv("./Parte_2.csv",sep=";",decimal=",")
df_3=pd.read_csv("./Parte_3.csv",sep=";",decimal=",")
df_4=pd.read_csv("./Parte_4.csv",sep=";",decimal=",")
df_5=pd.read_csv("./Parte_5.csv",sep=";",decimal=",")
df_6=pd.read_csv("./Parte_6.csv",sep=";",decimal=",")
df_7=pd.read_csv("./Parte_7.csv",sep=";",decimal=",")
df_8=pd.read_csv("./Parte_8.csv",sep=";",decimal=",")
df_9=pd.read_csv("./Parte_9.csv",sep=";",decimal=",")
df_10=pd.read_csv("./Parte_10.csv",sep=";",decimal=",")
df_11=pd.read_csv("./Parte_11.csv",sep=";",decimal=",")
df_12=pd.read_csv("./Parte_12.csv",sep=";",decimal=",")
df_13=pd.read_csv("./Parte_13.csv",sep=";",decimal=",")
df_14=pd.read_csv("./Parte_14.csv",sep=";",decimal=",")
df_15=pd.read_csv("./Parte_15.csv",sep=";",decimal=",")
df_16=pd.read_csv("./Parte_16.csv",sep=";",decimal=",")
df_17=pd.read_csv("./Parte_17.csv",sep=";",decimal=",")
df_18=pd.read_csv("./Parte_18.csv",sep=";",decimal=",")
df_19=pd.read_csv("./Parte_19.csv",sep=";",decimal=",")
df_20=pd.read_csv("./Parte_20.csv",sep=";",decimal=",")
df_21=pd.read_csv("./Parte_21.csv",sep=";",decimal=",")
df_22=pd.read_csv("./Parte_22.csv",sep=";",decimal=",")
df_23=pd.read_csv("./Parte_23.csv",sep=";",decimal=",")
df_24=pd.read_csv("./Parte_24.csv",sep=";",decimal=",")
df_25=pd.read_csv("./Parte_25.csv",sep=";",decimal=",")
df_26=pd.read_csv("./Parte_26.csv",sep=";",decimal=",")
df_27=pd.read_csv("./Parte_27.csv",sep=";",decimal=",")
df_28=pd.read_csv("./Parte_28.csv",sep=";",decimal=",")
df_29=pd.read_csv("./Parte_29.csv",sep=";",decimal=",")
df_30=pd.read_csv("./Parte_30.csv",sep=";",decimal=",")
df_31=pd.read_csv("./Parte_31.csv",sep=";",decimal=",")
df_32=pd.read_csv("./Parte_32.csv",sep=";",decimal=",")
df_33=pd.read_csv("./Parte_33.csv",sep=";",decimal=",")
df_34=pd.read_csv("./Parte_34.csv",sep=";",decimal=",")
df_35=pd.read_csv("./Parte_35.csv",sep=";",decimal=",")
df_36=pd.read_csv("./Parte_36.csv",sep=";",decimal=",")
df_37=pd.read_csv("./Parte_37.csv",sep=";",decimal=",")
df_38=pd.read_csv("./Parte_38.csv",sep=";",decimal=",")
df_39=pd.read_csv("./Parte_39.csv",sep=";",decimal=",")
df_40=pd.read_csv("./Parte_40.csv",sep=";",decimal=",")
df_41=pd.read_csv("./Parte_41.csv",sep=";",decimal=",")
df_42=pd.read_csv("./Parte_42.csv",sep=";",decimal=",")
df_43=pd.read_csv("./Parte_43.csv",sep=";",decimal=",")
df_44=pd.read_csv("./Parte_44.csv",sep=";",decimal=",")
df_45=pd.read_csv("./Parte_45.csv",sep=";",decimal=",")
df_46=pd.read_csv("./Parte_46.csv",sep=";",decimal=",")
df_47=pd.read_csv("./Parte_47.csv",sep=";",decimal=",")
df_48=pd.read_csv("./Parte_48.csv",sep=";",decimal=",")
df_49=pd.read_csv("./Parte_49.csv",sep=";",decimal=",")
df_50=pd.read_csv("./Parte_50.csv",sep=";",decimal=",")
df_51=pd.read_csv("./Parte_51.csv",sep=";",decimal=",")
df_52=pd.read_csv("./Parte_52.csv",sep=";",decimal=",")
df_53=pd.read_csv("./Parte_53.csv",sep=";",decimal=",")
df_54=pd.read_csv("./Parte_54.csv",sep=";",decimal=",")
df_55=pd.read_csv("./Parte_55.csv",sep=";",decimal=",")
df_56=pd.read_csv("./Parte_56.csv",sep=";",decimal=",")
df_57=pd.read_csv("./Parte_57.csv",sep=";",decimal=",")
df_58=pd.read_csv("./Parte_58.csv",sep=";",decimal=",")
df_59=pd.read_csv("./Parte_59.csv",sep=";",decimal=",")
df_60=pd.read_csv("./Parte_60.csv",sep=";",decimal=",")
df_61=pd.read_csv("./Parte_61.csv",sep=";",decimal=",")
df_62=pd.read_csv("./Parte_62.csv",sep=";",decimal=",")
df_63=pd.read_csv("./Parte_63.csv",sep=";",decimal=",")
df_64=pd.read_csv("./Parte_64.csv",sep=";",decimal=",")
df_65=pd.read_csv("./Parte_65.csv",sep=";",decimal=",")
df_66=pd.read_csv("./Parte_66.csv",sep=";",decimal=",")
df_67=pd.read_csv("./Parte_67.csv",sep=";",decimal=",")
df_68=pd.read_csv("./Parte_68.csv",sep=";",decimal=",")
df_69=pd.read_csv("./Parte_69.csv",sep=";",decimal=",")
df_70=pd.read_csv("./Parte_70.csv",sep=";",decimal=",")
df_71=pd.read_csv("./Parte_71.csv",sep=";",decimal=",")
df_72=pd.read_csv("./Parte_72.csv",sep=";",decimal=",")
df_73=pd.read_csv("./Parte_73.csv",sep=";",decimal=",")
df_74=pd.read_csv("./Parte_74.csv",sep=";",decimal=",")
df_75=pd.read_csv("./Parte_75.csv",sep=";",decimal=",")
df_76=pd.read_csv("./Parte_76.csv",sep=";",decimal=",")
df_77=pd.read_csv("./Parte_77.csv",sep=";",decimal=",")
df_78=pd.read_csv("./Parte_78.csv",sep=";",decimal=",")
df_79=pd.read_csv("./Parte_79.csv",sep=";",decimal=",")
df_80=pd.read_csv("./Parte_80.csv",sep=";",decimal=",")
df_81=pd.read_csv("./Parte_81.csv",sep=";",decimal=",")
df_82=pd.read_csv("./Parte_82.csv",sep=";",decimal=",")
df_83=pd.read_csv("./Parte_83.csv",sep=";",decimal=",")
df_84=pd.read_csv("./Parte_84.csv",sep=";",decimal=",")
df_85=pd.read_csv("./Parte_85.csv",sep=";",decimal=",")
df_86=pd.read_csv("./Parte_86.csv",sep=";",decimal=",")
df_87=pd.read_csv("./Parte_87.csv",sep=";",decimal=",")
df_88=pd.read_csv("./Parte_88.csv",sep=";",decimal=",")
df_89=pd.read_csv("./Parte_89.csv",sep=";",decimal=",")
df_90=pd.read_csv("./Parte_90.csv",sep=";",decimal=",")
df_91=pd.read_csv("./Parte_91.csv",sep=";",decimal=",")
df_92=pd.read_csv("./Parte_92.csv",sep=";",decimal=",")
df_93=pd.read_csv("./Parte_93.csv",sep=";",decimal=",")
df_94=pd.read_csv("./Parte_94.csv",sep=";",decimal=",")
df_95=pd.read_csv("./Parte_95.csv",sep=";",decimal=",")
df_96=pd.read_csv("./Parte_96.csv",sep=";",decimal=",")
df_97=pd.read_csv("./Parte_97.csv",sep=";",decimal=",")
df_98=pd.read_csv("./Parte_98.csv",sep=";",decimal=",")
df_99=pd.read_csv("./Parte_99.csv",sep=";",decimal=",")
df_100=pd.read_csv("./Parte_100.csv",sep=";",decimal=",")
df_101=pd.read_csv("./Parte_101.csv",sep=";",decimal=",")
df_102=pd.read_csv("./Parte_102.csv",sep=";",decimal=",")
df_103=pd.read_csv("./Parte_103.csv",sep=";",decimal=",")
df_104=pd.read_csv("./Parte_104.csv",sep=";",decimal=",")
df_105=pd.read_csv("./Parte_105.csv",sep=";",decimal=",")
df_106=pd.read_csv("./Parte_106.csv",sep=";",decimal=",")
df_107=pd.read_csv("./Parte_107.csv",sep=";",decimal=",")
df_108=pd.read_csv("./Parte_108.csv",sep=";",decimal=",")
df_109=pd.read_csv("./Parte_109.csv",sep=";",decimal=",")
df_110=pd.read_csv("./Parte_110.csv",sep=";",decimal=",")
df_111=pd.read_csv("./Parte_111.csv",sep=";",decimal=",")
df_112=pd.read_csv("./Parte_112.csv",sep=";",decimal=",")
df_113=pd.read_csv("./Parte_113.csv",sep=";",decimal=",")
df_114=pd.read_csv("./Parte_114.csv",sep=";",decimal=",")
df_115=pd.read_csv("./Parte_115.csv",sep=";",decimal=",")
df_116=pd.read_csv("./Parte_116.csv",sep=";",decimal=",")
df_117=pd.read_csv("./Parte_117.csv",sep=";",decimal=",")
df_118=pd.read_csv("./Parte_118.csv",sep=";",decimal=",")
df_119=pd.read_csv("./Parte_119.csv",sep=";",decimal=",")
df_120=pd.read_csv("./Parte_120.csv",sep=";",decimal=",")
df_121=pd.read_csv("./Parte_121.csv",sep=";",decimal=",")
df_122=pd.read_csv("./Parte_122.csv",sep=";",decimal=",")
df_123=pd.read_csv("./Parte_123.csv",sep=";",decimal=",")
df_124=pd.read_csv("./Parte_124.csv",sep=";",decimal=",")
df_125=pd.read_csv("./Parte_125.csv",sep=";",decimal=",")
df_126=pd.read_csv("./Parte_126.csv",sep=";",decimal=",")
df_127=pd.read_csv("./Parte_127.csv",sep=";",decimal=",")
df_128=pd.read_csv("./Parte_128.csv",sep=";",decimal=",")
df_129=pd.read_csv("./Parte_129.csv",sep=";",decimal=",")
df_130=pd.read_csv("./Parte_130.csv",sep=";",decimal=",")
df_131=pd.read_csv("./Parte_131.csv",sep=";",decimal=",")
df_132=pd.read_csv("./Parte_132.csv",sep=";",decimal=",")
df_133=pd.read_csv("./Parte_133.csv",sep=";",decimal=",")
df_134=pd.read_csv("./Parte_134.csv",sep=";",decimal=",")
df_135=pd.read_csv("./Parte_135.csv",sep=";",decimal=",")
df_136=pd.read_csv("./Parte_136.csv",sep=";",decimal=",")
df_137=pd.read_csv("./Parte_137.csv",sep=";",decimal=",")
df_138=pd.read_csv("./Parte_138.csv",sep=";",decimal=",")
df_139=pd.read_csv("./Parte_139.csv",sep=";",decimal=",")
df_140=pd.read_csv("./Parte_140.csv",sep=";",decimal=",")
df_141=pd.read_csv("./Parte_141.csv",sep=";",decimal=",")
df_142=pd.read_csv("./Parte_142.csv",sep=";",decimal=",")
df_143=pd.read_csv("./Parte_143.csv",sep=";",decimal=",")
df_144=pd.read_csv("./Parte_144.csv",sep=";",decimal=",")
df_145=pd.read_csv("./Parte_145.csv",sep=";",decimal=",")
df_146=pd.read_csv("./Parte_146.csv",sep=";",decimal=",")
df_147=pd.read_csv("./Parte_147.csv",sep=";",decimal=",")
df_148=pd.read_csv("./Parte_148.csv",sep=";",decimal=",")
df_149=pd.read_csv("./Parte_149.csv",sep=";",decimal=",")
df_150=pd.read_csv("./Parte_150.csv",sep=";",decimal=",")


df=pd.concat([df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9,df_10,
              df_11,df_12,df_13,df_14,df_15,df_16,df_17,df_18,df_19,df_20,
              df_21,df_22,df_23,df_24,df_25,df_26,df_27,df_28,df_29,df_30,
              df_31,df_32,df_33,df_34,df_35,df_36,df_37,df_38,df_39,df_40,
              df_41,df_42,df_43,df_44,df_45,df_46,df_47,df_48,df_49,df_50,
              df_51,df_52,df_53,df_54,df_55,df_56,df_57,df_58,df_59,df_60,
              df_61,df_62,df_63,df_64,df_65,df_66,df_67,df_68,df_69,df_70,
              df_71,df_72,df_73,df_74,df_75,df_76,df_77,df_78,df_79,df_80,
              df_81,df_82,df_83,df_84,df_85,df_86,df_87,df_88,df_89,df_90,
              df_91,df_92,df_93,df_94,df_95,df_96,df_97,df_98,df_99,df_100,
              df_101,df_102,df_103,df_104,df_105,df_106,df_107,df_108,df_109,df_110,
              df_111,df_112,df_113,df_114,df_115,df_116,df_117,df_118,df_119,df_120,
              df_121,df_122,df_123,df_124,df_125,df_126,df_127,df_128,df_129,df_130,
              df_131,df_132,df_133,df_134,df_135,df_136,df_137,df_138,df_139,df_140,
              df_141,df_142,df_143,df_144,df_145,df_146,df_147,df_148,df_149,df_150])

dim=df.shape[0]

for i in range(dim):
    if i!=dim-1:
        df.loc[i,"Peso_lag_1"]=df.loc[i+1,"Peso"]
    else:
        pass
    
    

for i in range(dim):
    if i!=dim-1:
        df.loc[i,"Altura_lag_1"]=df.loc[i+1,"Altura"]
    else:
        pass
    
    

for i in range(dim):
    if i!=dim-1:
        df.loc[i,"Coste_lag_1"]=df.loc[i+1,"Coste"]
    else:
        pass
    
    

for i in range(dim):
    if i!=dim-1:
        df.loc[i,"Beneficio_lag_1"]=df.loc[i+1,"Beneficio"]
    else:
        pass
    
    

for i in range(dim):
    if i!=dim-1:
        df.loc[i,"Base_X_lag_1"]=df.loc[i+1,"Base_X"]
    else:
        pass
    
    

for i in range(dim):
    if i!=dim-1:
        df.loc[i,"Base_Y_lag_1"]=df.loc[i+1,"Base_Y"]
    else:
        pass
    
    

for i in range(dim):
    if i!=dim-1:
        df.loc[i,"CRM_lag_1"]=df.loc[i+1,"CRM"]
    else:
        pass
    
    

for i in range(dim):
    if i!=dim-1:
        df.loc[i,"ZHab_X_lag_1"]=df.loc[i+1,"ZHab_X"]
    else:
        pass
    
    

for i in range(dim):
    if i!=dim-1:
        df.loc[i,"ZHab_Y_lag_1"]=df.loc[i+1,"ZHab_Y"]
    else:
        pass
    
    

for i in range(dim):
    if i!=dim-1:
        df.loc[i,"Chol_lag_1"]=df.loc[i+1,"Chol"]
    else:
        pass
    
    

for i in range(dim):
    if i!=dim-1:
        df.loc[i,"Thalach_lag_1"]=df.loc[i+1,"Thalach"]
    else:
        pass
    
    

for i in range(dim):
    if i!=dim-1:
        df.loc[i,"Trestbps_lag_1"]=df.loc[i+1,"Trestbps"]
    else:
        pass
    
    

for i in range(dim):
    if i!=dim-1:
        df.loc[i,"Eccentricity_lag_1"]=df.loc[i+1,"Eccentricity"]
    else:
        pass



for i in range(dim):
    if i<dim-1:
        print(i)
        df.loc[i,"TV_Peso_1"]=(df.loc[i,"Peso"]-df.loc[i,"Peso_lag_1"])/df.loc[i,"Peso_lag_1"]
    else:
        pass


for i in range(dim):
    if i<dim-1:
        df.loc[i,"TV_Altura_1"]=(df.loc[i,"Altura"]-df.loc[i,"Altura_lag_1"])/df.loc[i,"Altura_lag_1"]
    else:
        pass


for i in range(dim):
    if i<dim-1:
        df.loc[i,"TV_Coste_1"]=(df.loc[i,"Coste"]-df.loc[i,"Coste_lag_1"])/df.loc[i,"Coste_lag_1"]
    else:
        pass


for i in range(dim):
    if i<dim-1:
        df.loc[i,"TV_Beneficio_1"]=(df.loc[i,"Beneficio"]-df.loc[i,"Beneficio_lag_1"])/df.loc[i,"Beneficio_lag_1"]
    else:
        pass


for i in range(dim):
    if i<dim-1:
        df.loc[i,"TV_Base_X_1"]=(df.loc[i,"Base_X"]-df.loc[i,"Base_X_lag_1"])/df.loc[i,"Base_X_lag_1"]
    else:
        pass


for i in range(dim):
    if i<dim-1:
        df.loc[i,"TV_Base_Y_1"]=(df.loc[i,"Base_Y"]-df.loc[i,"Base_Y_lag_1"])/df.loc[i,"Base_Y_lag_1"]
    else:
        pass


for i in range(dim):
    if i<dim-1:
        df.loc[i,"TV_CRM_1"]=(df.loc[i,"CRM"]-df.loc[i,"CRM_lag_1"])/df.loc[i,"CRM_lag_1"]
    else:
        pass


for i in range(dim):
    if i<dim-1:
        df.loc[i,"TV_ZHab_X_1"]=(df.loc[i,"ZHab_X"]-df.loc[i,"ZHab_X_lag_1"])/df.loc[i,"ZHab_X_lag_1"]
    else:
        pass


for i in range(dim):
    if i<dim-1:
        df.loc[i,"TV_ZHab_Y_1"]=(df.loc[i,"ZHab_Y"]-df.loc[i,"ZHab_Y_lag_1"])/df.loc[i,"ZHab_Y_lag_1"]
    else:
        pass


for i in range(dim):
    if i<dim-1:
        df.loc[i,"TV_Chol_1"]=(df.loc[i,"Chol"]-df.loc[i,"Chol_lag_1"])/df.loc[i,"Chol_lag_1"]
    else:
        pass


for i in range(dim):
    if i<dim-1:
        df.loc[i,"TV_Thalach_1"]=(df.loc[i,"Thalach"]-df.loc[i,"Thalach_lag_1"])/df.loc[i,"Thalach_lag_1"]
    else:
        pass


for i in range(dim):
    if i<dim-1:
        df.loc[i,"TV_Trestbps_1"]=(df.loc[i,"Trestbps"]-df.loc[i,"Trestbps_lag_1"])/df.loc[i,"Trestbps_lag_1"]
    else:
        pass


for i in range(dim):
    if i<dim-1:
        df.loc[i,"TV_Eccentricity_1"]=(df.loc[i,"Eccentricity"]-df.loc[i,"Eccentricity_lag_1"])/df.loc[i,"Eccentricity_lag_1"]
    else:
        pass



for i in range(dim):
    if i<dim-2:
        df.loc[i,"Peso_lag_2"]=df.loc[i+2,"Peso"]
    else:
        pass
    

for i in range(dim):
    if i<dim-2:
        df.loc[i,"Altura_lag_2"]=df.loc[i+2,"Altura"]
    else:
        pass
    

for i in range(dim):
    if i<dim-2:
        df.loc[i,"Coste_lag_2"]=df.loc[i+2,"Coste"]
    else:
        pass
    

for i in range(dim):
    if i<dim-2:
        df.loc[i,"Beneficio_lag_2"]=df.loc[i+2,"Beneficio"]
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"Base_X_lag_2"]=df.loc[i+2,"Base_X"]
    else:
        pass
    

for i in range(dim):
    if i<dim-2:
        df.loc[i,"Base_Y_lag_2"]=df.loc[i+2,"Base_Y"]
    else:
        pass
    

for i in range(dim):
    if i<dim-2:
        df.loc[i,"CRM_lag_2"]=df.loc[i+2,"CRM"]
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"ZHab_X_lag_2"]=df.loc[i+2,"ZHab_X"]
    else:
        pass
    

for i in range(dim):
    if i<dim-2:
        df.loc[i,"ZHab_Y_lag_2"]=df.loc[i+2,"ZHab_Y"]
    else:
        pass
    

for i in range(dim):
    if i<dim-2:
        df.loc[i,"Chol_lag_2"]=df.loc[i+2,"Chol"]
    else:
        pass
    

for i in range(dim):
    if i<dim-2:
        df.loc[i,"Thalach_lag_2"]=df.loc[i+2,"Thalach"]
    else:
        pass
    

for i in range(dim):
    if i<dim-2:
        df.loc[i,"Trestbps_lag_2"]=df.loc[i+2,"Trestbps"]
    else:
        pass
    

for i in range(dim):
    if i<dim-2:
        df.loc[i,"Eccentricity_lag_2"]=df.loc[i+2,"Eccentricity"]
    else:
        pass
for i in range(dim):
    if i<dim-2:
        df.loc[i,"TV_Peso_2"]=(df.loc[i,"Peso"]-df.loc[i,"Peso_lag_2"])/df.loc[i,"Peso_lag_2"]
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"TV_Altura_2"]=(df.loc[i,"Altura"]-df.loc[i,"Altura_lag_2"])/df.loc[i,"Altura_lag_2"]
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"TV_Coste_2"]=(df.loc[i,"Coste"]-df.loc[i,"Coste_lag_2"])/df.loc[i,"Coste_lag_2"]
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"TV_Beneficio_2"]=(df.loc[i,"Beneficio"]-df.loc[i,"Beneficio_lag_2"])/df.loc[i,"Beneficio_lag_2"]
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"TV_Base_X_2"]=(df.loc[i,"Base_X"]-df.loc[i,"Base_X_lag_2"])/df.loc[i,"Base_X_lag_2"]
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"TV_Base_Y_2"]=(df.loc[i,"Base_Y"]-df.loc[i,"Base_Y_lag_2"])/df.loc[i,"Base_Y_lag_2"]
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"TV_CRM_2"]=(df.loc[i,"CRM"]-df.loc[i,"CRM_lag_2"])/df.loc[i,"CRM_lag_2"]
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"TV_ZHab_X_2"]=(df.loc[i,"ZHab_X"]-df.loc[i,"ZHab_X_lag_2"])/df.loc[i,"ZHab_X_lag_2"]
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"TV_ZHab_Y_2"]=(df.loc[i,"ZHab_Y"]-df.loc[i,"ZHab_Y_lag_2"])/df.loc[i,"ZHab_Y_lag_2"]
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"TV_Chol_2"]=(df.loc[i,"Chol"]-df.loc[i,"Chol_lag_2"])/df.loc[i,"Chol_lag_2"]
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"TV_Thalach_2"]=(df.loc[i,"Thalach"]-df.loc[i,"Thalach_lag_2"])/df.loc[i,"Thalach_lag_2"]
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"TV_Trestbps_2"]=(df.loc[i,"Trestbps"]-df.loc[i,"Trestbps_lag_2"])/df.loc[i,"Trestbps_lag_2"]
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"TV_Eccentricity_2"]=(df.loc[i,"Eccentricity"]-df.loc[i,"Eccentricity_lag_2"])/df.loc[i,"Eccentricity_lag_2"]
    else:
        pass

# %%
media_Peso=df['Peso'].mean()
df['Peso']=df['Peso'].fillna(media_Peso)


media_Altura=df['Altura'].mean()
df['Altura']=df['Altura'].fillna(media_Altura)


media_Coste=df['Coste'].mean()
df['Coste']=df['Coste'].fillna(media_Coste)


media_Beneficio=df['Beneficio'].mean()
df['Beneficio']=df['Beneficio'].fillna(media_Beneficio)


media_Base_X=df['Base_X'].mean()
df['Base_X']=df['Base_X'].fillna(media_Base_X)


media_Base_Y=df['Base_Y'].mean()
df['Base_Y']=df['Base_Y'].fillna(media_Base_Y)


media_CRM=df['CRM'].mean()
df['CRM']=df['CRM'].fillna(media_CRM)


media_ZHab_X=df['ZHab_X'].mean()
df['ZHab_X']=df['ZHab_X'].fillna(media_ZHab_X)


media_ZHab_Y=df['ZHab_Y'].mean()
df['ZHab_Y']=df['ZHab_Y'].fillna(media_ZHab_Y)


media_Chol=df['Chol'].mean()
df['Chol']=df['Chol'].fillna(media_Chol)


media_Thalach=df['Thalach'].mean()
df['Thalach']=df['Thalach'].fillna(media_Thalach)


media_Trestbps=df['Trestbps'].mean()
df['Trestbps']=df['Trestbps'].fillna(media_Trestbps)


media_Eccentricity=df['Eccentricity'].mean()
df['Eccentricity']=df['Eccentricity'].fillna(media_Eccentricity)


media_Peso_lag_1=df['Peso_lag_1'].mean()
df['Peso_lag_1']=df['Peso_lag_1'].fillna(media_Peso_lag_1)


media_Altura_lag_1=df['Altura_lag_1'].mean()
df['Altura_lag_1']=df['Altura_lag_1'].fillna(media_Altura_lag_1)


media_Coste_lag_1=df['Coste_lag_1'].mean()
df['Coste_lag_1']=df['Coste_lag_1'].fillna(media_Coste_lag_1)


media_Beneficio_lag_1=df['Beneficio_lag_1'].mean()
df['Beneficio_lag_1']=df['Beneficio_lag_1'].fillna(media_Beneficio_lag_1)


media_Base_X_lag_1=df['Base_X_lag_1'].mean()
df['Base_X_lag_1']=df['Base_X_lag_1'].fillna(media_Base_X_lag_1)


media_Base_Y_lag_1=df['Base_Y_lag_1'].mean()
df['Base_Y_lag_1']=df['Base_Y_lag_1'].fillna(media_Base_Y_lag_1)


media_CRM_lag_1=df['CRM_lag_1'].mean()
df['CRM_lag_1']=df['CRM_lag_1'].fillna(media_CRM_lag_1)


media_ZHab_X_lag_1=df['ZHab_X_lag_1'].mean()
df['ZHab_X_lag_1']=df['ZHab_X_lag_1'].fillna(media_ZHab_X_lag_1)


media_ZHab_Y_lag_1=df['ZHab_Y_lag_1'].mean()
df['ZHab_Y_lag_1']=df['ZHab_Y_lag_1'].fillna(media_ZHab_Y_lag_1)


media_Chol_lag_1=df['Chol_lag_1'].mean()
df['Chol_lag_1']=df['Chol_lag_1'].fillna(media_Chol_lag_1)


media_Thalach_lag_1=df['Thalach_lag_1'].mean()
df['Thalach_lag_1']=df['Thalach_lag_1'].fillna(media_Thalach_lag_1)


media_Trestbps_lag_1=df['Trestbps_lag_1'].mean()
df['Trestbps_lag_1']=df['Trestbps_lag_1'].fillna(media_Trestbps_lag_1)


media_Eccentricity_lag_1=df['Eccentricity_lag_1'].mean()
df['Eccentricity_lag_1']=df['Eccentricity_lag_1'].fillna(media_Eccentricity_lag_1)


media_Peso_lag_2=df['Peso_lag_2'].mean()
df['Peso_lag_2']=df['Peso_lag_2'].fillna(media_Peso_lag_2)


media_Altura_lag_2=df['Altura_lag_2'].mean()
df['Altura_lag_2']=df['Altura_lag_2'].fillna(media_Altura_lag_2)


media_Coste_lag_2=df['Coste_lag_2'].mean()
df['Coste_lag_2']=df['Coste_lag_2'].fillna(media_Coste_lag_2)


media_Beneficio_lag_2=df['Beneficio_lag_2'].mean()
df['Beneficio_lag_2']=df['Beneficio_lag_2'].fillna(media_Beneficio_lag_2)


media_Base_X_lag_2=df['Base_X_lag_2'].mean()
df['Base_X_lag_2']=df['Base_X_lag_2'].fillna(media_Base_X_lag_2)


media_Base_Y_lag_2=df['Base_Y_lag_2'].mean()
df['Base_Y_lag_2']=df['Base_Y_lag_2'].fillna(media_Base_Y_lag_2)


media_CRM_lag_2=df['CRM_lag_2'].mean()
df['CRM_lag_2']=df['CRM_lag_2'].fillna(media_CRM_lag_2)


media_ZHab_X_lag_2=df['ZHab_X_lag_2'].mean()
df['ZHab_X_lag_2']=df['ZHab_X_lag_2'].fillna(media_ZHab_X_lag_2)


media_ZHab_Y_lag_2=df['ZHab_Y_lag_2'].mean()
df['ZHab_Y_lag_2']=df['ZHab_Y_lag_2'].fillna(media_ZHab_Y_lag_2)


media_Chol_lag_2=df['Chol_lag_2'].mean()
df['Chol_lag_2']=df['Chol_lag_2'].fillna(media_Chol_lag_2)


media_Thalach_lag_2=df['Thalach_lag_2'].mean()
df['Thalach_lag_2']=df['Thalach_lag_2'].fillna(media_Thalach_lag_2)


media_Trestbps_lag_2=df['Trestbps_lag_2'].mean()
df['Trestbps_lag_2']=df['Trestbps_lag_2'].fillna(media_Trestbps_lag_2)


media_Eccentricity_lag_2=df['Eccentricity_lag_2'].mean()
df['Eccentricity_lag_2']=df['Eccentricity_lag_2'].fillna(media_Eccentricity_lag_2)

# %%
for i in range(dim):
    if i<dim-2:
        df.loc[i,"media_movil_Peso"]=(df.loc[i,"Peso"]+df.loc[i,"Peso_lag_1"]+df.loc[i,"Peso_lag_2"])/3
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"media_movil_Altura"]=(df.loc[i,"Altura"]+df.loc[i,"Altura_lag_1"]+df.loc[i,"Altura_lag_2"])/3
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"media_movil_Coste"]=(df.loc[i,"Coste"]+df.loc[i,"Coste_lag_1"]+df.loc[i,"Coste_lag_2"])/3
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"media_movil_Beneficio"]=(df.loc[i,"Beneficio"]+df.loc[i,"Beneficio_lag_1"]+df.loc[i,"Beneficio_lag_2"])/3
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"media_movil_Base_X"]=(df.loc[i,"Base_X"]+df.loc[i,"Base_X_lag_1"]+df.loc[i,"Base_X_lag_2"])/3
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"media_movil_Base_Y"]=(df.loc[i,"Base_Y"]+df.loc[i,"Base_Y_lag_1"]+df.loc[i,"Base_Y_lag_2"])/3
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"media_movil_CRM"]=(df.loc[i,"CRM"]+df.loc[i,"CRM_lag_1"]+df.loc[i,"CRM_lag_2"])/3
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"media_movil_ZHab_X"]=(df.loc[i,"ZHab_X"]+df.loc[i,"ZHab_X_lag_1"]+df.loc[i,"ZHab_X_lag_2"])/3
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"media_movil_ZHab_Y"]=(df.loc[i,"ZHab_Y"]+df.loc[i,"ZHab_Y_lag_1"]+df.loc[i,"ZHab_Y_lag_2"])/3
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"media_movil_Chol"]=(df.loc[i,"Chol"]+df.loc[i,"Chol_lag_1"]+df.loc[i,"Chol_lag_2"])/3
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"media_movil_Thalach"]=(df.loc[i,"Thalach"]+df.loc[i,"Thalach_lag_1"]+df.loc[i,"Thalach_lag_2"])/3
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"media_movil_Trestbps"]=(df.loc[i,"Trestbps"]+df.loc[i,"Trestbps_lag_1"]+df.loc[i,"Trestbps_lag_2"])/3
    else:
        pass


for i in range(dim):
    if i<dim-2:
        df.loc[i,"media_movil_Eccentricity"]=(df.loc[i,"Eccentricity"]+df.loc[i,"Eccentricity_lag_1"]+df.loc[i,"Eccentricity_lag_2"])/3
    else:
        pass

# %%
import matplotlib.pyplot as plt

plt.plot(df["media_movil_Peso"])
plt.plot(df["Peso"])
plt.show();


plt.plot(df["media_movil_Altura"])
plt.plot(df["Altura"])
plt.show();


plt.plot(df["media_movil_Coste"])
plt.plot(df["Coste"])
plt.show();


plt.plot(df["media_movil_Beneficio"])
plt.plot(df["Beneficio"])
plt.show();


plt.plot(df["media_movil_Base_X"])
plt.plot(df["Base_X"])
plt.show();


plt.plot(df["media_movil_Base_Y"])
plt.plot(df["Base_Y"])
plt.show();


plt.plot(df["media_movil_CRM"])
plt.plot(df["CRM"])
plt.show();


plt.plot(df["media_movil_ZHab_X"])
plt.plot(df["ZHab_X"])
plt.show();


plt.plot(df["media_movil_ZHab_Y"])
plt.plot(df["ZHab_Y"])
plt.show();


plt.plot(df["media_movil_Chol"])
plt.plot(df["Chol"])
plt.show();


plt.plot(df["media_movil_Thalach"])
plt.plot(df["Thalach"])
plt.show();


plt.plot(df["media_movil_Trestbps"])
plt.plot(df["Trestbps"])
plt.show();


plt.plot(df["media_movil_Eccentricity"])
plt.plot(df["Eccentricity"])
plt.show();


plt.plot(df["media_movil_Peso_lag_1"])
plt.plot(df["Peso_lag_1"])
plt.show();


plt.plot(df["media_movil_Altura_lag_1"])
plt.plot(df["Altura_lag_1"])
plt.show();


plt.plot(df["media_movil_Coste_lag_1"])
plt.plot(df["Coste_lag_1"])
plt.show();


plt.plot(df["media_movil_Beneficio_lag_1"])
plt.plot(df["Beneficio_lag_1"])
plt.show();


plt.plot(df["media_movil_Base_X_lag_1"])
plt.plot(df["Base_X_lag_1"])
plt.show();


plt.plot(df["media_movil_Base_Y_lag_1"])
plt.plot(df["Base_Y_lag_1"])
plt.show();


plt.plot(df["media_movil_CRM_lag_1"])
plt.plot(df["CRM_lag_1"])
plt.show();


plt.plot(df["media_movil_ZHab_X_lag_1"])
plt.plot(df["ZHab_X_lag_1"])
plt.show();


plt.plot(df["media_movil_ZHab_Y_lag_1"])
plt.plot(df["ZHab_Y_lag_1"])
plt.show();


plt.plot(df["media_movil_Chol_lag_1"])
plt.plot(df["Chol_lag_1"])
plt.show();


plt.plot(df["media_movil_Thalach_lag_1"])
plt.plot(df["Thalach_lag_1"])
plt.show();


plt.plot(df["media_movil_Trestbps_lag_1"])
plt.plot(df["Trestbps_lag_1"])
plt.show();


plt.plot(df["media_movil_Eccentricity_lag_1"])
plt.plot(df["Eccentricity_lag_1"])
plt.show();


plt.plot(df["media_movil_TV_Peso_1"])
plt.plot(df["TV_Peso_1"])
plt.show();


plt.plot(df["media_movil_TV_Altura_1"])
plt.plot(df["TV_Altura_1"])
plt.show();


plt.plot(df["media_movil_TV_Coste_1"])
plt.plot(df["TV_Coste_1"])
plt.show();


plt.plot(df["media_movil_TV_Beneficio_1"])
plt.plot(df["TV_Beneficio_1"])
plt.show();


plt.plot(df["media_movil_TV_Base_X_1"])
plt.plot(df["TV_Base_X_1"])
plt.show();


plt.plot(df["media_movil_TV_Base_Y_1"])
plt.plot(df["TV_Base_Y_1"])
plt.show();


plt.plot(df["media_movil_TV_CRM_1"])
plt.plot(df["TV_CRM_1"])
plt.show();


plt.plot(df["media_movil_TV_ZHab_X_1"])
plt.plot(df["TV_ZHab_X_1"])
plt.show();


plt.plot(df["media_movil_TV_ZHab_Y_1"])
plt.plot(df["TV_ZHab_Y_1"])
plt.show();


plt.plot(df["media_movil_TV_Chol_1"])
plt.plot(df["TV_Chol_1"])
plt.show();


plt.plot(df["media_movil_TV_Thalach_1"])
plt.plot(df["TV_Thalach_1"])
plt.show();


plt.plot(df["media_movil_TV_Trestbps_1"])
plt.plot(df["TV_Trestbps_1"])
plt.show();


plt.plot(df["media_movil_TV_Eccentricity_1"])
plt.plot(df["TV_Eccentricity_1"])
plt.show();


plt.plot(df["media_movil_Peso_lag_2"])
plt.plot(df["Peso_lag_2"])
plt.show();


plt.plot(df["media_movil_Altura_lag_2"])
plt.plot(df["Altura_lag_2"])
plt.show();


plt.plot(df["media_movil_Coste_lag_2"])
plt.plot(df["Coste_lag_2"])
plt.show();


plt.plot(df["media_movil_Beneficio_lag_2"])
plt.plot(df["Beneficio_lag_2"])
plt.show();


plt.plot(df["media_movil_Base_X_lag_2"])
plt.plot(df["Base_X_lag_2"])
plt.show();


plt.plot(df["media_movil_Base_Y_lag_2"])
plt.plot(df["Base_Y_lag_2"])
plt.show();


plt.plot(df["media_movil_CRM_lag_2"])
plt.plot(df["CRM_lag_2"])
plt.show();


plt.plot(df["media_movil_ZHab_X_lag_2"])
plt.plot(df["ZHab_X_lag_2"])
plt.show();


plt.plot(df["media_movil_ZHab_Y_lag_2"])
plt.plot(df["ZHab_Y_lag_2"])
plt.show();


plt.plot(df["media_movil_Chol_lag_2"])
plt.plot(df["Chol_lag_2"])
plt.show();


plt.plot(df["media_movil_Thalach_lag_2"])
plt.plot(df["Thalach_lag_2"])
plt.show();


plt.plot(df["media_movil_Trestbps_lag_2"])
plt.plot(df["Trestbps_lag_2"])
plt.show();


plt.plot(df["media_movil_Eccentricity_lag_2"])
plt.plot(df["Eccentricity_lag_2"])
plt.show();


plt.plot(df["media_movil_TV_Peso_2"])
plt.plot(df["TV_Peso_2"])
plt.show();


plt.plot(df["media_movil_TV_Altura_2"])
plt.plot(df["TV_Altura_2"])
plt.show();


plt.plot(df["media_movil_TV_Coste_2"])
plt.plot(df["TV_Coste_2"])
plt.show();


plt.plot(df["media_movil_TV_Beneficio_2"])
plt.plot(df["TV_Beneficio_2"])
plt.show();


plt.plot(df["media_movil_TV_Base_X_2"])
plt.plot(df["TV_Base_X_2"])
plt.show();


plt.plot(df["media_movil_TV_Base_Y_2"])
plt.plot(df["TV_Base_Y_2"])
plt.show();


plt.plot(df["media_movil_TV_CRM_2"])
plt.plot(df["TV_CRM_2"])
plt.show();


plt.plot(df["media_movil_TV_ZHab_X_2"])
plt.plot(df["TV_ZHab_X_2"])
plt.show();


plt.plot(df["media_movil_TV_ZHab_Y_2"])
plt.plot(df["TV_ZHab_Y_2"])
plt.show();


plt.plot(df["media_movil_TV_Chol_2"])
plt.plot(df["TV_Chol_2"])
plt.show();


plt.plot(df["media_movil_TV_Thalach_2"])
plt.plot(df["TV_Thalach_2"])
plt.show();


plt.plot(df["media_movil_TV_Trestbps_2"])
plt.plot(df["TV_Trestbps_2"])
plt.show();


plt.plot(df["media_movil_TV_Eccentricity_2"])
plt.plot(df["TV_Eccentricity_2"])
plt.show();


plt.plot(df["media_movil_media_movil_Peso"])
plt.plot(df["media_movil_Peso"])
plt.show();


plt.plot(df["media_movil_media_movil_Altura"])
plt.plot(df["media_movil_Altura"])
plt.show();


plt.plot(df["media_movil_media_movil_Coste"])
plt.plot(df["media_movil_Coste"])
plt.show();


plt.plot(df["media_movil_media_movil_Beneficio"])
plt.plot(df["media_movil_Beneficio"])
plt.show();


plt.plot(df["media_movil_media_movil_Base_X"])
plt.plot(df["media_movil_Base_X"])
plt.show();


plt.plot(df["media_movil_media_movil_Base_Y"])
plt.plot(df["media_movil_Base_Y"])
plt.show();


plt.plot(df["media_movil_media_movil_CRM"])
plt.plot(df["media_movil_CRM"])
plt.show();


plt.plot(df["media_movil_media_movil_ZHab_X"])
plt.plot(df["media_movil_ZHab_X"])
plt.show();


plt.plot(df["media_movil_media_movil_ZHab_Y"])
plt.plot(df["media_movil_ZHab_Y"])
plt.show();


plt.plot(df["media_movil_media_movil_Chol"])
plt.plot(df["media_movil_Chol"])
plt.show();


plt.plot(df["media_movil_media_movil_Thalach"])
plt.plot(df["media_movil_Thalach"])
plt.show();


plt.plot(df["media_movil_media_movil_Trestbps"])
plt.plot(df["media_movil_Trestbps"])
plt.show();


plt.plot(df["media_movil_media_movil_Eccentricity"])
plt.plot(df["media_movil_Eccentricity"])
plt.show();

# %%
dv_Peso=df['Peso'].std()
media_Peso=df['Peso'].mean()
max_Peso=df['Peso'].max()
min_Peso=df['Peso'].min()
if (dv_Peso/media_Peso>0.3) & (dv_Peso/media_Peso<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Peso"]=(df.loc[i,"Peso"]-media_Peso)/dv_Peso
elif (dv_Peso/media_Peso>=0.7) & (dv_Peso/media_Peso<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Peso"]=(df.loc[i,"Peso"]-min_Peso)/(max_Peso-min_Peso)
elif (dv_Peso/media_Peso>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Peso"]=np.log(df.loc[i,"Peso"])
else:
    pass             
    

dv_Altura=df['Altura'].std()
media_Altura=df['Altura'].mean()
max_Altura=df['Altura'].max()
min_Altura=df['Altura'].min()
if (dv_Altura/media_Altura>0.3) & (dv_Altura/media_Altura<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Altura"]=(df.loc[i,"Altura"]-media_Altura)/dv_Altura
elif (dv_Altura/media_Altura>=0.7) & (dv_Altura/media_Altura<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Altura"]=(df.loc[i,"Altura"]-min_Altura)/(max_Altura-min_Altura)
elif (dv_Altura/media_Altura>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Altura"]=np.log(df.loc[i,"Altura"])
else:
    pass             
    

dv_Coste=df['Coste'].std()
media_Coste=df['Coste'].mean()
max_Coste=df['Coste'].max()
min_Coste=df['Coste'].min()
if (dv_Coste/media_Coste>0.3) & (dv_Coste/media_Coste<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Coste"]=(df.loc[i,"Coste"]-media_Coste)/dv_Coste
elif (dv_Coste/media_Coste>=0.7) & (dv_Coste/media_Coste<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Coste"]=(df.loc[i,"Coste"]-min_Coste)/(max_Coste-min_Coste)
elif (dv_Coste/media_Coste>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Coste"]=np.log(df.loc[i,"Coste"])
else:
    pass             
    

dv_Beneficio=df['Beneficio'].std()
media_Beneficio=df['Beneficio'].mean()
max_Beneficio=df['Beneficio'].max()
min_Beneficio=df['Beneficio'].min()
if (dv_Beneficio/media_Beneficio>0.3) & (dv_Beneficio/media_Beneficio<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Beneficio"]=(df.loc[i,"Beneficio"]-media_Beneficio)/dv_Beneficio
elif (dv_Beneficio/media_Beneficio>=0.7) & (dv_Beneficio/media_Beneficio<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Beneficio"]=(df.loc[i,"Beneficio"]-min_Beneficio)/(max_Beneficio-min_Beneficio)
elif (dv_Beneficio/media_Beneficio>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Beneficio"]=np.log(df.loc[i,"Beneficio"])
else:
    pass             
    

dv_Base_X=df['Base_X'].std()
media_Base_X=df['Base_X'].mean()
max_Base_X=df['Base_X'].max()
min_Base_X=df['Base_X'].min()
if (dv_Base_X/media_Base_X>0.3) & (dv_Base_X/media_Base_X<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Base_X"]=(df.loc[i,"Base_X"]-media_Base_X)/dv_Base_X
elif (dv_Base_X/media_Base_X>=0.7) & (dv_Base_X/media_Base_X<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Base_X"]=(df.loc[i,"Base_X"]-min_Base_X)/(max_Base_X-min_Base_X)
elif (dv_Base_X/media_Base_X>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Base_X"]=np.log(df.loc[i,"Base_X"])
else:
    pass             
    

dv_Base_Y=df['Base_Y'].std()
media_Base_Y=df['Base_Y'].mean()
max_Base_Y=df['Base_Y'].max()
min_Base_Y=df['Base_Y'].min()
if (dv_Base_Y/media_Base_Y>0.3) & (dv_Base_Y/media_Base_Y<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Base_Y"]=(df.loc[i,"Base_Y"]-media_Base_Y)/dv_Base_Y
elif (dv_Base_Y/media_Base_Y>=0.7) & (dv_Base_Y/media_Base_Y<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Base_Y"]=(df.loc[i,"Base_Y"]-min_Base_Y)/(max_Base_Y-min_Base_Y)
elif (dv_Base_Y/media_Base_Y>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Base_Y"]=np.log(df.loc[i,"Base_Y"])
else:
    pass             
    

dv_CRM=df['CRM'].std()
media_CRM=df['CRM'].mean()
max_CRM=df['CRM'].max()
min_CRM=df['CRM'].min()
if (dv_CRM/media_CRM>0.3) & (dv_CRM/media_CRM<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"CRM"]=(df.loc[i,"CRM"]-media_CRM)/dv_CRM
elif (dv_CRM/media_CRM>=0.7) & (dv_CRM/media_CRM<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"CRM"]=(df.loc[i,"CRM"]-min_CRM)/(max_CRM-min_CRM)
elif (dv_CRM/media_CRM>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"CRM"]=np.log(df.loc[i,"CRM"])
else:
    pass             
    

dv_ZHab_X=df['ZHab_X'].std()
media_ZHab_X=df['ZHab_X'].mean()
max_ZHab_X=df['ZHab_X'].max()
min_ZHab_X=df['ZHab_X'].min()
if (dv_ZHab_X/media_ZHab_X>0.3) & (dv_ZHab_X/media_ZHab_X<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"ZHab_X"]=(df.loc[i,"ZHab_X"]-media_ZHab_X)/dv_ZHab_X
elif (dv_ZHab_X/media_ZHab_X>=0.7) & (dv_ZHab_X/media_ZHab_X<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"ZHab_X"]=(df.loc[i,"ZHab_X"]-min_ZHab_X)/(max_ZHab_X-min_ZHab_X)
elif (dv_ZHab_X/media_ZHab_X>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"ZHab_X"]=np.log(df.loc[i,"ZHab_X"])
else:
    pass             
    

dv_ZHab_Y=df['ZHab_Y'].std()
media_ZHab_Y=df['ZHab_Y'].mean()
max_ZHab_Y=df['ZHab_Y'].max()
min_ZHab_Y=df['ZHab_Y'].min()
if (dv_ZHab_Y/media_ZHab_Y>0.3) & (dv_ZHab_Y/media_ZHab_Y<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"ZHab_Y"]=(df.loc[i,"ZHab_Y"]-media_ZHab_Y)/dv_ZHab_Y
elif (dv_ZHab_Y/media_ZHab_Y>=0.7) & (dv_ZHab_Y/media_ZHab_Y<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"ZHab_Y"]=(df.loc[i,"ZHab_Y"]-min_ZHab_Y)/(max_ZHab_Y-min_ZHab_Y)
elif (dv_ZHab_Y/media_ZHab_Y>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"ZHab_Y"]=np.log(df.loc[i,"ZHab_Y"])
else:
    pass             
    

dv_Chol=df['Chol'].std()
media_Chol=df['Chol'].mean()
max_Chol=df['Chol'].max()
min_Chol=df['Chol'].min()
if (dv_Chol/media_Chol>0.3) & (dv_Chol/media_Chol<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Chol"]=(df.loc[i,"Chol"]-media_Chol)/dv_Chol
elif (dv_Chol/media_Chol>=0.7) & (dv_Chol/media_Chol<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Chol"]=(df.loc[i,"Chol"]-min_Chol)/(max_Chol-min_Chol)
elif (dv_Chol/media_Chol>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Chol"]=np.log(df.loc[i,"Chol"])
else:
    pass             
    

dv_Thalach=df['Thalach'].std()
media_Thalach=df['Thalach'].mean()
max_Thalach=df['Thalach'].max()
min_Thalach=df['Thalach'].min()
if (dv_Thalach/media_Thalach>0.3) & (dv_Thalach/media_Thalach<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Thalach"]=(df.loc[i,"Thalach"]-media_Thalach)/dv_Thalach
elif (dv_Thalach/media_Thalach>=0.7) & (dv_Thalach/media_Thalach<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Thalach"]=(df.loc[i,"Thalach"]-min_Thalach)/(max_Thalach-min_Thalach)
elif (dv_Thalach/media_Thalach>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Thalach"]=np.log(df.loc[i,"Thalach"])
else:
    pass             
    

dv_Trestbps=df['Trestbps'].std()
media_Trestbps=df['Trestbps'].mean()
max_Trestbps=df['Trestbps'].max()
min_Trestbps=df['Trestbps'].min()
if (dv_Trestbps/media_Trestbps>0.3) & (dv_Trestbps/media_Trestbps<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Trestbps"]=(df.loc[i,"Trestbps"]-media_Trestbps)/dv_Trestbps
elif (dv_Trestbps/media_Trestbps>=0.7) & (dv_Trestbps/media_Trestbps<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Trestbps"]=(df.loc[i,"Trestbps"]-min_Trestbps)/(max_Trestbps-min_Trestbps)
elif (dv_Trestbps/media_Trestbps>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Trestbps"]=np.log(df.loc[i,"Trestbps"])
else:
    pass             
    

dv_Eccentricity=df['Eccentricity'].std()
media_Eccentricity=df['Eccentricity'].mean()
max_Eccentricity=df['Eccentricity'].max()
min_Eccentricity=df['Eccentricity'].min()
if (dv_Eccentricity/media_Eccentricity>0.3) & (dv_Eccentricity/media_Eccentricity<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Eccentricity"]=(df.loc[i,"Eccentricity"]-media_Eccentricity)/dv_Eccentricity
elif (dv_Eccentricity/media_Eccentricity>=0.7) & (dv_Eccentricity/media_Eccentricity<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Eccentricity"]=(df.loc[i,"Eccentricity"]-min_Eccentricity)/(max_Eccentricity-min_Eccentricity)
elif (dv_Eccentricity/media_Eccentricity>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Eccentricity"]=np.log(df.loc[i,"Eccentricity"])
else:
    pass             
    

dv_Peso_lag_1=df['Peso_lag_1'].std()
media_Peso_lag_1=df['Peso_lag_1'].mean()
max_Peso_lag_1=df['Peso_lag_1'].max()
min_Peso_lag_1=df['Peso_lag_1'].min()
if (dv_Peso_lag_1/media_Peso_lag_1>0.3) & (dv_Peso_lag_1/media_Peso_lag_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Peso_lag_1"]=(df.loc[i,"Peso_lag_1"]-media_Peso_lag_1)/dv_Peso_lag_1
elif (dv_Peso_lag_1/media_Peso_lag_1>=0.7) & (dv_Peso_lag_1/media_Peso_lag_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Peso_lag_1"]=(df.loc[i,"Peso_lag_1"]-min_Peso_lag_1)/(max_Peso_lag_1-min_Peso_lag_1)
elif (dv_Peso_lag_1/media_Peso_lag_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Peso_lag_1"]=np.log(df.loc[i,"Peso_lag_1"])
else:
    pass             
    

dv_Altura_lag_1=df['Altura_lag_1'].std()
media_Altura_lag_1=df['Altura_lag_1'].mean()
max_Altura_lag_1=df['Altura_lag_1'].max()
min_Altura_lag_1=df['Altura_lag_1'].min()
if (dv_Altura_lag_1/media_Altura_lag_1>0.3) & (dv_Altura_lag_1/media_Altura_lag_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Altura_lag_1"]=(df.loc[i,"Altura_lag_1"]-media_Altura_lag_1)/dv_Altura_lag_1
elif (dv_Altura_lag_1/media_Altura_lag_1>=0.7) & (dv_Altura_lag_1/media_Altura_lag_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Altura_lag_1"]=(df.loc[i,"Altura_lag_1"]-min_Altura_lag_1)/(max_Altura_lag_1-min_Altura_lag_1)
elif (dv_Altura_lag_1/media_Altura_lag_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Altura_lag_1"]=np.log(df.loc[i,"Altura_lag_1"])
else:
    pass             
    

dv_Coste_lag_1=df['Coste_lag_1'].std()
media_Coste_lag_1=df['Coste_lag_1'].mean()
max_Coste_lag_1=df['Coste_lag_1'].max()
min_Coste_lag_1=df['Coste_lag_1'].min()
if (dv_Coste_lag_1/media_Coste_lag_1>0.3) & (dv_Coste_lag_1/media_Coste_lag_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Coste_lag_1"]=(df.loc[i,"Coste_lag_1"]-media_Coste_lag_1)/dv_Coste_lag_1
elif (dv_Coste_lag_1/media_Coste_lag_1>=0.7) & (dv_Coste_lag_1/media_Coste_lag_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Coste_lag_1"]=(df.loc[i,"Coste_lag_1"]-min_Coste_lag_1)/(max_Coste_lag_1-min_Coste_lag_1)
elif (dv_Coste_lag_1/media_Coste_lag_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Coste_lag_1"]=np.log(df.loc[i,"Coste_lag_1"])
else:
    pass             
    

dv_Beneficio_lag_1=df['Beneficio_lag_1'].std()
media_Beneficio_lag_1=df['Beneficio_lag_1'].mean()
max_Beneficio_lag_1=df['Beneficio_lag_1'].max()
min_Beneficio_lag_1=df['Beneficio_lag_1'].min()
if (dv_Beneficio_lag_1/media_Beneficio_lag_1>0.3) & (dv_Beneficio_lag_1/media_Beneficio_lag_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Beneficio_lag_1"]=(df.loc[i,"Beneficio_lag_1"]-media_Beneficio_lag_1)/dv_Beneficio_lag_1
elif (dv_Beneficio_lag_1/media_Beneficio_lag_1>=0.7) & (dv_Beneficio_lag_1/media_Beneficio_lag_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Beneficio_lag_1"]=(df.loc[i,"Beneficio_lag_1"]-min_Beneficio_lag_1)/(max_Beneficio_lag_1-min_Beneficio_lag_1)
elif (dv_Beneficio_lag_1/media_Beneficio_lag_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Beneficio_lag_1"]=np.log(df.loc[i,"Beneficio_lag_1"])
else:
    pass             
    

dv_Base_X_lag_1=df['Base_X_lag_1'].std()
media_Base_X_lag_1=df['Base_X_lag_1'].mean()
max_Base_X_lag_1=df['Base_X_lag_1'].max()
min_Base_X_lag_1=df['Base_X_lag_1'].min()
if (dv_Base_X_lag_1/media_Base_X_lag_1>0.3) & (dv_Base_X_lag_1/media_Base_X_lag_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Base_X_lag_1"]=(df.loc[i,"Base_X_lag_1"]-media_Base_X_lag_1)/dv_Base_X_lag_1
elif (dv_Base_X_lag_1/media_Base_X_lag_1>=0.7) & (dv_Base_X_lag_1/media_Base_X_lag_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Base_X_lag_1"]=(df.loc[i,"Base_X_lag_1"]-min_Base_X_lag_1)/(max_Base_X_lag_1-min_Base_X_lag_1)
elif (dv_Base_X_lag_1/media_Base_X_lag_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Base_X_lag_1"]=np.log(df.loc[i,"Base_X_lag_1"])
else:
    pass             
    

dv_Base_Y_lag_1=df['Base_Y_lag_1'].std()
media_Base_Y_lag_1=df['Base_Y_lag_1'].mean()
max_Base_Y_lag_1=df['Base_Y_lag_1'].max()
min_Base_Y_lag_1=df['Base_Y_lag_1'].min()
if (dv_Base_Y_lag_1/media_Base_Y_lag_1>0.3) & (dv_Base_Y_lag_1/media_Base_Y_lag_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Base_Y_lag_1"]=(df.loc[i,"Base_Y_lag_1"]-media_Base_Y_lag_1)/dv_Base_Y_lag_1
elif (dv_Base_Y_lag_1/media_Base_Y_lag_1>=0.7) & (dv_Base_Y_lag_1/media_Base_Y_lag_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Base_Y_lag_1"]=(df.loc[i,"Base_Y_lag_1"]-min_Base_Y_lag_1)/(max_Base_Y_lag_1-min_Base_Y_lag_1)
elif (dv_Base_Y_lag_1/media_Base_Y_lag_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Base_Y_lag_1"]=np.log(df.loc[i,"Base_Y_lag_1"])
else:
    pass             
    

dv_CRM_lag_1=df['CRM_lag_1'].std()
media_CRM_lag_1=df['CRM_lag_1'].mean()
max_CRM_lag_1=df['CRM_lag_1'].max()
min_CRM_lag_1=df['CRM_lag_1'].min()
if (dv_CRM_lag_1/media_CRM_lag_1>0.3) & (dv_CRM_lag_1/media_CRM_lag_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"CRM_lag_1"]=(df.loc[i,"CRM_lag_1"]-media_CRM_lag_1)/dv_CRM_lag_1
elif (dv_CRM_lag_1/media_CRM_lag_1>=0.7) & (dv_CRM_lag_1/media_CRM_lag_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"CRM_lag_1"]=(df.loc[i,"CRM_lag_1"]-min_CRM_lag_1)/(max_CRM_lag_1-min_CRM_lag_1)
elif (dv_CRM_lag_1/media_CRM_lag_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"CRM_lag_1"]=np.log(df.loc[i,"CRM_lag_1"])
else:
    pass             
    

dv_ZHab_X_lag_1=df['ZHab_X_lag_1'].std()
media_ZHab_X_lag_1=df['ZHab_X_lag_1'].mean()
max_ZHab_X_lag_1=df['ZHab_X_lag_1'].max()
min_ZHab_X_lag_1=df['ZHab_X_lag_1'].min()
if (dv_ZHab_X_lag_1/media_ZHab_X_lag_1>0.3) & (dv_ZHab_X_lag_1/media_ZHab_X_lag_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"ZHab_X_lag_1"]=(df.loc[i,"ZHab_X_lag_1"]-media_ZHab_X_lag_1)/dv_ZHab_X_lag_1
elif (dv_ZHab_X_lag_1/media_ZHab_X_lag_1>=0.7) & (dv_ZHab_X_lag_1/media_ZHab_X_lag_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"ZHab_X_lag_1"]=(df.loc[i,"ZHab_X_lag_1"]-min_ZHab_X_lag_1)/(max_ZHab_X_lag_1-min_ZHab_X_lag_1)
elif (dv_ZHab_X_lag_1/media_ZHab_X_lag_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"ZHab_X_lag_1"]=np.log(df.loc[i,"ZHab_X_lag_1"])
else:
    pass             
    

dv_ZHab_Y_lag_1=df['ZHab_Y_lag_1'].std()
media_ZHab_Y_lag_1=df['ZHab_Y_lag_1'].mean()
max_ZHab_Y_lag_1=df['ZHab_Y_lag_1'].max()
min_ZHab_Y_lag_1=df['ZHab_Y_lag_1'].min()
if (dv_ZHab_Y_lag_1/media_ZHab_Y_lag_1>0.3) & (dv_ZHab_Y_lag_1/media_ZHab_Y_lag_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"ZHab_Y_lag_1"]=(df.loc[i,"ZHab_Y_lag_1"]-media_ZHab_Y_lag_1)/dv_ZHab_Y_lag_1
elif (dv_ZHab_Y_lag_1/media_ZHab_Y_lag_1>=0.7) & (dv_ZHab_Y_lag_1/media_ZHab_Y_lag_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"ZHab_Y_lag_1"]=(df.loc[i,"ZHab_Y_lag_1"]-min_ZHab_Y_lag_1)/(max_ZHab_Y_lag_1-min_ZHab_Y_lag_1)
elif (dv_ZHab_Y_lag_1/media_ZHab_Y_lag_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"ZHab_Y_lag_1"]=np.log(df.loc[i,"ZHab_Y_lag_1"])
else:
    pass             
    

dv_Chol_lag_1=df['Chol_lag_1'].std()
media_Chol_lag_1=df['Chol_lag_1'].mean()
max_Chol_lag_1=df['Chol_lag_1'].max()
min_Chol_lag_1=df['Chol_lag_1'].min()
if (dv_Chol_lag_1/media_Chol_lag_1>0.3) & (dv_Chol_lag_1/media_Chol_lag_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Chol_lag_1"]=(df.loc[i,"Chol_lag_1"]-media_Chol_lag_1)/dv_Chol_lag_1
elif (dv_Chol_lag_1/media_Chol_lag_1>=0.7) & (dv_Chol_lag_1/media_Chol_lag_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Chol_lag_1"]=(df.loc[i,"Chol_lag_1"]-min_Chol_lag_1)/(max_Chol_lag_1-min_Chol_lag_1)
elif (dv_Chol_lag_1/media_Chol_lag_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Chol_lag_1"]=np.log(df.loc[i,"Chol_lag_1"])
else:
    pass             
    

dv_Thalach_lag_1=df['Thalach_lag_1'].std()
media_Thalach_lag_1=df['Thalach_lag_1'].mean()
max_Thalach_lag_1=df['Thalach_lag_1'].max()
min_Thalach_lag_1=df['Thalach_lag_1'].min()
if (dv_Thalach_lag_1/media_Thalach_lag_1>0.3) & (dv_Thalach_lag_1/media_Thalach_lag_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Thalach_lag_1"]=(df.loc[i,"Thalach_lag_1"]-media_Thalach_lag_1)/dv_Thalach_lag_1
elif (dv_Thalach_lag_1/media_Thalach_lag_1>=0.7) & (dv_Thalach_lag_1/media_Thalach_lag_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Thalach_lag_1"]=(df.loc[i,"Thalach_lag_1"]-min_Thalach_lag_1)/(max_Thalach_lag_1-min_Thalach_lag_1)
elif (dv_Thalach_lag_1/media_Thalach_lag_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Thalach_lag_1"]=np.log(df.loc[i,"Thalach_lag_1"])
else:
    pass             
    

dv_Trestbps_lag_1=df['Trestbps_lag_1'].std()
media_Trestbps_lag_1=df['Trestbps_lag_1'].mean()
max_Trestbps_lag_1=df['Trestbps_lag_1'].max()
min_Trestbps_lag_1=df['Trestbps_lag_1'].min()
if (dv_Trestbps_lag_1/media_Trestbps_lag_1>0.3) & (dv_Trestbps_lag_1/media_Trestbps_lag_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Trestbps_lag_1"]=(df.loc[i,"Trestbps_lag_1"]-media_Trestbps_lag_1)/dv_Trestbps_lag_1
elif (dv_Trestbps_lag_1/media_Trestbps_lag_1>=0.7) & (dv_Trestbps_lag_1/media_Trestbps_lag_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Trestbps_lag_1"]=(df.loc[i,"Trestbps_lag_1"]-min_Trestbps_lag_1)/(max_Trestbps_lag_1-min_Trestbps_lag_1)
elif (dv_Trestbps_lag_1/media_Trestbps_lag_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Trestbps_lag_1"]=np.log(df.loc[i,"Trestbps_lag_1"])
else:
    pass             
    

dv_Eccentricity_lag_1=df['Eccentricity_lag_1'].std()
media_Eccentricity_lag_1=df['Eccentricity_lag_1'].mean()
max_Eccentricity_lag_1=df['Eccentricity_lag_1'].max()
min_Eccentricity_lag_1=df['Eccentricity_lag_1'].min()
if (dv_Eccentricity_lag_1/media_Eccentricity_lag_1>0.3) & (dv_Eccentricity_lag_1/media_Eccentricity_lag_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Eccentricity_lag_1"]=(df.loc[i,"Eccentricity_lag_1"]-media_Eccentricity_lag_1)/dv_Eccentricity_lag_1
elif (dv_Eccentricity_lag_1/media_Eccentricity_lag_1>=0.7) & (dv_Eccentricity_lag_1/media_Eccentricity_lag_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Eccentricity_lag_1"]=(df.loc[i,"Eccentricity_lag_1"]-min_Eccentricity_lag_1)/(max_Eccentricity_lag_1-min_Eccentricity_lag_1)
elif (dv_Eccentricity_lag_1/media_Eccentricity_lag_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Eccentricity_lag_1"]=np.log(df.loc[i,"Eccentricity_lag_1"])
else:
    pass             
    

dv_TV_Peso_1=df['TV_Peso_1'].std()
media_TV_Peso_1=df['TV_Peso_1'].mean()
max_TV_Peso_1=df['TV_Peso_1'].max()
min_TV_Peso_1=df['TV_Peso_1'].min()
if (dv_TV_Peso_1/media_TV_Peso_1>0.3) & (dv_TV_Peso_1/media_TV_Peso_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Peso_1"]=(df.loc[i,"TV_Peso_1"]-media_TV_Peso_1)/dv_TV_Peso_1
elif (dv_TV_Peso_1/media_TV_Peso_1>=0.7) & (dv_TV_Peso_1/media_TV_Peso_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Peso_1"]=(df.loc[i,"TV_Peso_1"]-min_TV_Peso_1)/(max_TV_Peso_1-min_TV_Peso_1)
elif (dv_TV_Peso_1/media_TV_Peso_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Peso_1"]=np.log(df.loc[i,"TV_Peso_1"])
else:
    pass             
    

dv_TV_Altura_1=df['TV_Altura_1'].std()
media_TV_Altura_1=df['TV_Altura_1'].mean()
max_TV_Altura_1=df['TV_Altura_1'].max()
min_TV_Altura_1=df['TV_Altura_1'].min()
if (dv_TV_Altura_1/media_TV_Altura_1>0.3) & (dv_TV_Altura_1/media_TV_Altura_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Altura_1"]=(df.loc[i,"TV_Altura_1"]-media_TV_Altura_1)/dv_TV_Altura_1
elif (dv_TV_Altura_1/media_TV_Altura_1>=0.7) & (dv_TV_Altura_1/media_TV_Altura_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Altura_1"]=(df.loc[i,"TV_Altura_1"]-min_TV_Altura_1)/(max_TV_Altura_1-min_TV_Altura_1)
elif (dv_TV_Altura_1/media_TV_Altura_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Altura_1"]=np.log(df.loc[i,"TV_Altura_1"])
else:
    pass             
    

dv_TV_Coste_1=df['TV_Coste_1'].std()
media_TV_Coste_1=df['TV_Coste_1'].mean()
max_TV_Coste_1=df['TV_Coste_1'].max()
min_TV_Coste_1=df['TV_Coste_1'].min()
if (dv_TV_Coste_1/media_TV_Coste_1>0.3) & (dv_TV_Coste_1/media_TV_Coste_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Coste_1"]=(df.loc[i,"TV_Coste_1"]-media_TV_Coste_1)/dv_TV_Coste_1
elif (dv_TV_Coste_1/media_TV_Coste_1>=0.7) & (dv_TV_Coste_1/media_TV_Coste_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Coste_1"]=(df.loc[i,"TV_Coste_1"]-min_TV_Coste_1)/(max_TV_Coste_1-min_TV_Coste_1)
elif (dv_TV_Coste_1/media_TV_Coste_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Coste_1"]=np.log(df.loc[i,"TV_Coste_1"])
else:
    pass             
    

dv_TV_Beneficio_1=df['TV_Beneficio_1'].std()
media_TV_Beneficio_1=df['TV_Beneficio_1'].mean()
max_TV_Beneficio_1=df['TV_Beneficio_1'].max()
min_TV_Beneficio_1=df['TV_Beneficio_1'].min()
if (dv_TV_Beneficio_1/media_TV_Beneficio_1>0.3) & (dv_TV_Beneficio_1/media_TV_Beneficio_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Beneficio_1"]=(df.loc[i,"TV_Beneficio_1"]-media_TV_Beneficio_1)/dv_TV_Beneficio_1
elif (dv_TV_Beneficio_1/media_TV_Beneficio_1>=0.7) & (dv_TV_Beneficio_1/media_TV_Beneficio_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Beneficio_1"]=(df.loc[i,"TV_Beneficio_1"]-min_TV_Beneficio_1)/(max_TV_Beneficio_1-min_TV_Beneficio_1)
elif (dv_TV_Beneficio_1/media_TV_Beneficio_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Beneficio_1"]=np.log(df.loc[i,"TV_Beneficio_1"])
else:
    pass             
    

dv_TV_Base_X_1=df['TV_Base_X_1'].std()
media_TV_Base_X_1=df['TV_Base_X_1'].mean()
max_TV_Base_X_1=df['TV_Base_X_1'].max()
min_TV_Base_X_1=df['TV_Base_X_1'].min()
if (dv_TV_Base_X_1/media_TV_Base_X_1>0.3) & (dv_TV_Base_X_1/media_TV_Base_X_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Base_X_1"]=(df.loc[i,"TV_Base_X_1"]-media_TV_Base_X_1)/dv_TV_Base_X_1
elif (dv_TV_Base_X_1/media_TV_Base_X_1>=0.7) & (dv_TV_Base_X_1/media_TV_Base_X_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Base_X_1"]=(df.loc[i,"TV_Base_X_1"]-min_TV_Base_X_1)/(max_TV_Base_X_1-min_TV_Base_X_1)
elif (dv_TV_Base_X_1/media_TV_Base_X_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Base_X_1"]=np.log(df.loc[i,"TV_Base_X_1"])
else:
    pass             
    

dv_TV_Base_Y_1=df['TV_Base_Y_1'].std()
media_TV_Base_Y_1=df['TV_Base_Y_1'].mean()
max_TV_Base_Y_1=df['TV_Base_Y_1'].max()
min_TV_Base_Y_1=df['TV_Base_Y_1'].min()
if (dv_TV_Base_Y_1/media_TV_Base_Y_1>0.3) & (dv_TV_Base_Y_1/media_TV_Base_Y_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Base_Y_1"]=(df.loc[i,"TV_Base_Y_1"]-media_TV_Base_Y_1)/dv_TV_Base_Y_1
elif (dv_TV_Base_Y_1/media_TV_Base_Y_1>=0.7) & (dv_TV_Base_Y_1/media_TV_Base_Y_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Base_Y_1"]=(df.loc[i,"TV_Base_Y_1"]-min_TV_Base_Y_1)/(max_TV_Base_Y_1-min_TV_Base_Y_1)
elif (dv_TV_Base_Y_1/media_TV_Base_Y_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Base_Y_1"]=np.log(df.loc[i,"TV_Base_Y_1"])
else:
    pass             
    

dv_TV_CRM_1=df['TV_CRM_1'].std()
media_TV_CRM_1=df['TV_CRM_1'].mean()
max_TV_CRM_1=df['TV_CRM_1'].max()
min_TV_CRM_1=df['TV_CRM_1'].min()
if (dv_TV_CRM_1/media_TV_CRM_1>0.3) & (dv_TV_CRM_1/media_TV_CRM_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_CRM_1"]=(df.loc[i,"TV_CRM_1"]-media_TV_CRM_1)/dv_TV_CRM_1
elif (dv_TV_CRM_1/media_TV_CRM_1>=0.7) & (dv_TV_CRM_1/media_TV_CRM_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_CRM_1"]=(df.loc[i,"TV_CRM_1"]-min_TV_CRM_1)/(max_TV_CRM_1-min_TV_CRM_1)
elif (dv_TV_CRM_1/media_TV_CRM_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_CRM_1"]=np.log(df.loc[i,"TV_CRM_1"])
else:
    pass             
    

dv_TV_ZHab_X_1=df['TV_ZHab_X_1'].std()
media_TV_ZHab_X_1=df['TV_ZHab_X_1'].mean()
max_TV_ZHab_X_1=df['TV_ZHab_X_1'].max()
min_TV_ZHab_X_1=df['TV_ZHab_X_1'].min()
if (dv_TV_ZHab_X_1/media_TV_ZHab_X_1>0.3) & (dv_TV_ZHab_X_1/media_TV_ZHab_X_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_ZHab_X_1"]=(df.loc[i,"TV_ZHab_X_1"]-media_TV_ZHab_X_1)/dv_TV_ZHab_X_1
elif (dv_TV_ZHab_X_1/media_TV_ZHab_X_1>=0.7) & (dv_TV_ZHab_X_1/media_TV_ZHab_X_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_ZHab_X_1"]=(df.loc[i,"TV_ZHab_X_1"]-min_TV_ZHab_X_1)/(max_TV_ZHab_X_1-min_TV_ZHab_X_1)
elif (dv_TV_ZHab_X_1/media_TV_ZHab_X_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_ZHab_X_1"]=np.log(df.loc[i,"TV_ZHab_X_1"])
else:
    pass             
    

dv_TV_ZHab_Y_1=df['TV_ZHab_Y_1'].std()
media_TV_ZHab_Y_1=df['TV_ZHab_Y_1'].mean()
max_TV_ZHab_Y_1=df['TV_ZHab_Y_1'].max()
min_TV_ZHab_Y_1=df['TV_ZHab_Y_1'].min()
if (dv_TV_ZHab_Y_1/media_TV_ZHab_Y_1>0.3) & (dv_TV_ZHab_Y_1/media_TV_ZHab_Y_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_ZHab_Y_1"]=(df.loc[i,"TV_ZHab_Y_1"]-media_TV_ZHab_Y_1)/dv_TV_ZHab_Y_1
elif (dv_TV_ZHab_Y_1/media_TV_ZHab_Y_1>=0.7) & (dv_TV_ZHab_Y_1/media_TV_ZHab_Y_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_ZHab_Y_1"]=(df.loc[i,"TV_ZHab_Y_1"]-min_TV_ZHab_Y_1)/(max_TV_ZHab_Y_1-min_TV_ZHab_Y_1)
elif (dv_TV_ZHab_Y_1/media_TV_ZHab_Y_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_ZHab_Y_1"]=np.log(df.loc[i,"TV_ZHab_Y_1"])
else:
    pass             
    

dv_TV_Chol_1=df['TV_Chol_1'].std()
media_TV_Chol_1=df['TV_Chol_1'].mean()
max_TV_Chol_1=df['TV_Chol_1'].max()
min_TV_Chol_1=df['TV_Chol_1'].min()
if (dv_TV_Chol_1/media_TV_Chol_1>0.3) & (dv_TV_Chol_1/media_TV_Chol_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Chol_1"]=(df.loc[i,"TV_Chol_1"]-media_TV_Chol_1)/dv_TV_Chol_1
elif (dv_TV_Chol_1/media_TV_Chol_1>=0.7) & (dv_TV_Chol_1/media_TV_Chol_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Chol_1"]=(df.loc[i,"TV_Chol_1"]-min_TV_Chol_1)/(max_TV_Chol_1-min_TV_Chol_1)
elif (dv_TV_Chol_1/media_TV_Chol_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Chol_1"]=np.log(df.loc[i,"TV_Chol_1"])
else:
    pass             
    

dv_TV_Thalach_1=df['TV_Thalach_1'].std()
media_TV_Thalach_1=df['TV_Thalach_1'].mean()
max_TV_Thalach_1=df['TV_Thalach_1'].max()
min_TV_Thalach_1=df['TV_Thalach_1'].min()
if (dv_TV_Thalach_1/media_TV_Thalach_1>0.3) & (dv_TV_Thalach_1/media_TV_Thalach_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Thalach_1"]=(df.loc[i,"TV_Thalach_1"]-media_TV_Thalach_1)/dv_TV_Thalach_1
elif (dv_TV_Thalach_1/media_TV_Thalach_1>=0.7) & (dv_TV_Thalach_1/media_TV_Thalach_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Thalach_1"]=(df.loc[i,"TV_Thalach_1"]-min_TV_Thalach_1)/(max_TV_Thalach_1-min_TV_Thalach_1)
elif (dv_TV_Thalach_1/media_TV_Thalach_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Thalach_1"]=np.log(df.loc[i,"TV_Thalach_1"])
else:
    pass             
    

dv_TV_Trestbps_1=df['TV_Trestbps_1'].std()
media_TV_Trestbps_1=df['TV_Trestbps_1'].mean()
max_TV_Trestbps_1=df['TV_Trestbps_1'].max()
min_TV_Trestbps_1=df['TV_Trestbps_1'].min()
if (dv_TV_Trestbps_1/media_TV_Trestbps_1>0.3) & (dv_TV_Trestbps_1/media_TV_Trestbps_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Trestbps_1"]=(df.loc[i,"TV_Trestbps_1"]-media_TV_Trestbps_1)/dv_TV_Trestbps_1
elif (dv_TV_Trestbps_1/media_TV_Trestbps_1>=0.7) & (dv_TV_Trestbps_1/media_TV_Trestbps_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Trestbps_1"]=(df.loc[i,"TV_Trestbps_1"]-min_TV_Trestbps_1)/(max_TV_Trestbps_1-min_TV_Trestbps_1)
elif (dv_TV_Trestbps_1/media_TV_Trestbps_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Trestbps_1"]=np.log(df.loc[i,"TV_Trestbps_1"])
else:
    pass             
    

dv_TV_Eccentricity_1=df['TV_Eccentricity_1'].std()
media_TV_Eccentricity_1=df['TV_Eccentricity_1'].mean()
max_TV_Eccentricity_1=df['TV_Eccentricity_1'].max()
min_TV_Eccentricity_1=df['TV_Eccentricity_1'].min()
if (dv_TV_Eccentricity_1/media_TV_Eccentricity_1>0.3) & (dv_TV_Eccentricity_1/media_TV_Eccentricity_1<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Eccentricity_1"]=(df.loc[i,"TV_Eccentricity_1"]-media_TV_Eccentricity_1)/dv_TV_Eccentricity_1
elif (dv_TV_Eccentricity_1/media_TV_Eccentricity_1>=0.7) & (dv_TV_Eccentricity_1/media_TV_Eccentricity_1<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Eccentricity_1"]=(df.loc[i,"TV_Eccentricity_1"]-min_TV_Eccentricity_1)/(max_TV_Eccentricity_1-min_TV_Eccentricity_1)
elif (dv_TV_Eccentricity_1/media_TV_Eccentricity_1>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Eccentricity_1"]=np.log(df.loc[i,"TV_Eccentricity_1"])
else:
    pass             
    

dv_Peso_lag_2=df['Peso_lag_2'].std()
media_Peso_lag_2=df['Peso_lag_2'].mean()
max_Peso_lag_2=df['Peso_lag_2'].max()
min_Peso_lag_2=df['Peso_lag_2'].min()
if (dv_Peso_lag_2/media_Peso_lag_2>0.3) & (dv_Peso_lag_2/media_Peso_lag_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Peso_lag_2"]=(df.loc[i,"Peso_lag_2"]-media_Peso_lag_2)/dv_Peso_lag_2
elif (dv_Peso_lag_2/media_Peso_lag_2>=0.7) & (dv_Peso_lag_2/media_Peso_lag_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Peso_lag_2"]=(df.loc[i,"Peso_lag_2"]-min_Peso_lag_2)/(max_Peso_lag_2-min_Peso_lag_2)
elif (dv_Peso_lag_2/media_Peso_lag_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Peso_lag_2"]=np.log(df.loc[i,"Peso_lag_2"])
else:
    pass             
    

dv_Altura_lag_2=df['Altura_lag_2'].std()
media_Altura_lag_2=df['Altura_lag_2'].mean()
max_Altura_lag_2=df['Altura_lag_2'].max()
min_Altura_lag_2=df['Altura_lag_2'].min()
if (dv_Altura_lag_2/media_Altura_lag_2>0.3) & (dv_Altura_lag_2/media_Altura_lag_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Altura_lag_2"]=(df.loc[i,"Altura_lag_2"]-media_Altura_lag_2)/dv_Altura_lag_2
elif (dv_Altura_lag_2/media_Altura_lag_2>=0.7) & (dv_Altura_lag_2/media_Altura_lag_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Altura_lag_2"]=(df.loc[i,"Altura_lag_2"]-min_Altura_lag_2)/(max_Altura_lag_2-min_Altura_lag_2)
elif (dv_Altura_lag_2/media_Altura_lag_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Altura_lag_2"]=np.log(df.loc[i,"Altura_lag_2"])
else:
    pass             
    

dv_Coste_lag_2=df['Coste_lag_2'].std()
media_Coste_lag_2=df['Coste_lag_2'].mean()
max_Coste_lag_2=df['Coste_lag_2'].max()
min_Coste_lag_2=df['Coste_lag_2'].min()
if (dv_Coste_lag_2/media_Coste_lag_2>0.3) & (dv_Coste_lag_2/media_Coste_lag_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Coste_lag_2"]=(df.loc[i,"Coste_lag_2"]-media_Coste_lag_2)/dv_Coste_lag_2
elif (dv_Coste_lag_2/media_Coste_lag_2>=0.7) & (dv_Coste_lag_2/media_Coste_lag_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Coste_lag_2"]=(df.loc[i,"Coste_lag_2"]-min_Coste_lag_2)/(max_Coste_lag_2-min_Coste_lag_2)
elif (dv_Coste_lag_2/media_Coste_lag_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Coste_lag_2"]=np.log(df.loc[i,"Coste_lag_2"])
else:
    pass             
    

dv_Beneficio_lag_2=df['Beneficio_lag_2'].std()
media_Beneficio_lag_2=df['Beneficio_lag_2'].mean()
max_Beneficio_lag_2=df['Beneficio_lag_2'].max()
min_Beneficio_lag_2=df['Beneficio_lag_2'].min()
if (dv_Beneficio_lag_2/media_Beneficio_lag_2>0.3) & (dv_Beneficio_lag_2/media_Beneficio_lag_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Beneficio_lag_2"]=(df.loc[i,"Beneficio_lag_2"]-media_Beneficio_lag_2)/dv_Beneficio_lag_2
elif (dv_Beneficio_lag_2/media_Beneficio_lag_2>=0.7) & (dv_Beneficio_lag_2/media_Beneficio_lag_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Beneficio_lag_2"]=(df.loc[i,"Beneficio_lag_2"]-min_Beneficio_lag_2)/(max_Beneficio_lag_2-min_Beneficio_lag_2)
elif (dv_Beneficio_lag_2/media_Beneficio_lag_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Beneficio_lag_2"]=np.log(df.loc[i,"Beneficio_lag_2"])
else:
    pass             
    

dv_Base_X_lag_2=df['Base_X_lag_2'].std()
media_Base_X_lag_2=df['Base_X_lag_2'].mean()
max_Base_X_lag_2=df['Base_X_lag_2'].max()
min_Base_X_lag_2=df['Base_X_lag_2'].min()
if (dv_Base_X_lag_2/media_Base_X_lag_2>0.3) & (dv_Base_X_lag_2/media_Base_X_lag_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Base_X_lag_2"]=(df.loc[i,"Base_X_lag_2"]-media_Base_X_lag_2)/dv_Base_X_lag_2
elif (dv_Base_X_lag_2/media_Base_X_lag_2>=0.7) & (dv_Base_X_lag_2/media_Base_X_lag_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Base_X_lag_2"]=(df.loc[i,"Base_X_lag_2"]-min_Base_X_lag_2)/(max_Base_X_lag_2-min_Base_X_lag_2)
elif (dv_Base_X_lag_2/media_Base_X_lag_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Base_X_lag_2"]=np.log(df.loc[i,"Base_X_lag_2"])
else:
    pass             
    

dv_Base_Y_lag_2=df['Base_Y_lag_2'].std()
media_Base_Y_lag_2=df['Base_Y_lag_2'].mean()
max_Base_Y_lag_2=df['Base_Y_lag_2'].max()
min_Base_Y_lag_2=df['Base_Y_lag_2'].min()
if (dv_Base_Y_lag_2/media_Base_Y_lag_2>0.3) & (dv_Base_Y_lag_2/media_Base_Y_lag_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Base_Y_lag_2"]=(df.loc[i,"Base_Y_lag_2"]-media_Base_Y_lag_2)/dv_Base_Y_lag_2
elif (dv_Base_Y_lag_2/media_Base_Y_lag_2>=0.7) & (dv_Base_Y_lag_2/media_Base_Y_lag_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Base_Y_lag_2"]=(df.loc[i,"Base_Y_lag_2"]-min_Base_Y_lag_2)/(max_Base_Y_lag_2-min_Base_Y_lag_2)
elif (dv_Base_Y_lag_2/media_Base_Y_lag_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Base_Y_lag_2"]=np.log(df.loc[i,"Base_Y_lag_2"])
else:
    pass             
    

dv_CRM_lag_2=df['CRM_lag_2'].std()
media_CRM_lag_2=df['CRM_lag_2'].mean()
max_CRM_lag_2=df['CRM_lag_2'].max()
min_CRM_lag_2=df['CRM_lag_2'].min()
if (dv_CRM_lag_2/media_CRM_lag_2>0.3) & (dv_CRM_lag_2/media_CRM_lag_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"CRM_lag_2"]=(df.loc[i,"CRM_lag_2"]-media_CRM_lag_2)/dv_CRM_lag_2
elif (dv_CRM_lag_2/media_CRM_lag_2>=0.7) & (dv_CRM_lag_2/media_CRM_lag_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"CRM_lag_2"]=(df.loc[i,"CRM_lag_2"]-min_CRM_lag_2)/(max_CRM_lag_2-min_CRM_lag_2)
elif (dv_CRM_lag_2/media_CRM_lag_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"CRM_lag_2"]=np.log(df.loc[i,"CRM_lag_2"])
else:
    pass             
    

dv_ZHab_X_lag_2=df['ZHab_X_lag_2'].std()
media_ZHab_X_lag_2=df['ZHab_X_lag_2'].mean()
max_ZHab_X_lag_2=df['ZHab_X_lag_2'].max()
min_ZHab_X_lag_2=df['ZHab_X_lag_2'].min()
if (dv_ZHab_X_lag_2/media_ZHab_X_lag_2>0.3) & (dv_ZHab_X_lag_2/media_ZHab_X_lag_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"ZHab_X_lag_2"]=(df.loc[i,"ZHab_X_lag_2"]-media_ZHab_X_lag_2)/dv_ZHab_X_lag_2
elif (dv_ZHab_X_lag_2/media_ZHab_X_lag_2>=0.7) & (dv_ZHab_X_lag_2/media_ZHab_X_lag_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"ZHab_X_lag_2"]=(df.loc[i,"ZHab_X_lag_2"]-min_ZHab_X_lag_2)/(max_ZHab_X_lag_2-min_ZHab_X_lag_2)
elif (dv_ZHab_X_lag_2/media_ZHab_X_lag_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"ZHab_X_lag_2"]=np.log(df.loc[i,"ZHab_X_lag_2"])
else:
    pass             
    

dv_ZHab_Y_lag_2=df['ZHab_Y_lag_2'].std()
media_ZHab_Y_lag_2=df['ZHab_Y_lag_2'].mean()
max_ZHab_Y_lag_2=df['ZHab_Y_lag_2'].max()
min_ZHab_Y_lag_2=df['ZHab_Y_lag_2'].min()
if (dv_ZHab_Y_lag_2/media_ZHab_Y_lag_2>0.3) & (dv_ZHab_Y_lag_2/media_ZHab_Y_lag_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"ZHab_Y_lag_2"]=(df.loc[i,"ZHab_Y_lag_2"]-media_ZHab_Y_lag_2)/dv_ZHab_Y_lag_2
elif (dv_ZHab_Y_lag_2/media_ZHab_Y_lag_2>=0.7) & (dv_ZHab_Y_lag_2/media_ZHab_Y_lag_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"ZHab_Y_lag_2"]=(df.loc[i,"ZHab_Y_lag_2"]-min_ZHab_Y_lag_2)/(max_ZHab_Y_lag_2-min_ZHab_Y_lag_2)
elif (dv_ZHab_Y_lag_2/media_ZHab_Y_lag_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"ZHab_Y_lag_2"]=np.log(df.loc[i,"ZHab_Y_lag_2"])
else:
    pass             
    

dv_Chol_lag_2=df['Chol_lag_2'].std()
media_Chol_lag_2=df['Chol_lag_2'].mean()
max_Chol_lag_2=df['Chol_lag_2'].max()
min_Chol_lag_2=df['Chol_lag_2'].min()
if (dv_Chol_lag_2/media_Chol_lag_2>0.3) & (dv_Chol_lag_2/media_Chol_lag_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Chol_lag_2"]=(df.loc[i,"Chol_lag_2"]-media_Chol_lag_2)/dv_Chol_lag_2
elif (dv_Chol_lag_2/media_Chol_lag_2>=0.7) & (dv_Chol_lag_2/media_Chol_lag_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Chol_lag_2"]=(df.loc[i,"Chol_lag_2"]-min_Chol_lag_2)/(max_Chol_lag_2-min_Chol_lag_2)
elif (dv_Chol_lag_2/media_Chol_lag_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Chol_lag_2"]=np.log(df.loc[i,"Chol_lag_2"])
else:
    pass             
    

dv_Thalach_lag_2=df['Thalach_lag_2'].std()
media_Thalach_lag_2=df['Thalach_lag_2'].mean()
max_Thalach_lag_2=df['Thalach_lag_2'].max()
min_Thalach_lag_2=df['Thalach_lag_2'].min()
if (dv_Thalach_lag_2/media_Thalach_lag_2>0.3) & (dv_Thalach_lag_2/media_Thalach_lag_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Thalach_lag_2"]=(df.loc[i,"Thalach_lag_2"]-media_Thalach_lag_2)/dv_Thalach_lag_2
elif (dv_Thalach_lag_2/media_Thalach_lag_2>=0.7) & (dv_Thalach_lag_2/media_Thalach_lag_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Thalach_lag_2"]=(df.loc[i,"Thalach_lag_2"]-min_Thalach_lag_2)/(max_Thalach_lag_2-min_Thalach_lag_2)
elif (dv_Thalach_lag_2/media_Thalach_lag_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Thalach_lag_2"]=np.log(df.loc[i,"Thalach_lag_2"])
else:
    pass             
    

dv_Trestbps_lag_2=df['Trestbps_lag_2'].std()
media_Trestbps_lag_2=df['Trestbps_lag_2'].mean()
max_Trestbps_lag_2=df['Trestbps_lag_2'].max()
min_Trestbps_lag_2=df['Trestbps_lag_2'].min()
if (dv_Trestbps_lag_2/media_Trestbps_lag_2>0.3) & (dv_Trestbps_lag_2/media_Trestbps_lag_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Trestbps_lag_2"]=(df.loc[i,"Trestbps_lag_2"]-media_Trestbps_lag_2)/dv_Trestbps_lag_2
elif (dv_Trestbps_lag_2/media_Trestbps_lag_2>=0.7) & (dv_Trestbps_lag_2/media_Trestbps_lag_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Trestbps_lag_2"]=(df.loc[i,"Trestbps_lag_2"]-min_Trestbps_lag_2)/(max_Trestbps_lag_2-min_Trestbps_lag_2)
elif (dv_Trestbps_lag_2/media_Trestbps_lag_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Trestbps_lag_2"]=np.log(df.loc[i,"Trestbps_lag_2"])
else:
    pass             
    

dv_Eccentricity_lag_2=df['Eccentricity_lag_2'].std()
media_Eccentricity_lag_2=df['Eccentricity_lag_2'].mean()
max_Eccentricity_lag_2=df['Eccentricity_lag_2'].max()
min_Eccentricity_lag_2=df['Eccentricity_lag_2'].min()
if (dv_Eccentricity_lag_2/media_Eccentricity_lag_2>0.3) & (dv_Eccentricity_lag_2/media_Eccentricity_lag_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Eccentricity_lag_2"]=(df.loc[i,"Eccentricity_lag_2"]-media_Eccentricity_lag_2)/dv_Eccentricity_lag_2
elif (dv_Eccentricity_lag_2/media_Eccentricity_lag_2>=0.7) & (dv_Eccentricity_lag_2/media_Eccentricity_lag_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"Eccentricity_lag_2"]=(df.loc[i,"Eccentricity_lag_2"]-min_Eccentricity_lag_2)/(max_Eccentricity_lag_2-min_Eccentricity_lag_2)
elif (dv_Eccentricity_lag_2/media_Eccentricity_lag_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"Eccentricity_lag_2"]=np.log(df.loc[i,"Eccentricity_lag_2"])
else:
    pass             
    

dv_TV_Peso_2=df['TV_Peso_2'].std()
media_TV_Peso_2=df['TV_Peso_2'].mean()
max_TV_Peso_2=df['TV_Peso_2'].max()
min_TV_Peso_2=df['TV_Peso_2'].min()
if (dv_TV_Peso_2/media_TV_Peso_2>0.3) & (dv_TV_Peso_2/media_TV_Peso_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Peso_2"]=(df.loc[i,"TV_Peso_2"]-media_TV_Peso_2)/dv_TV_Peso_2
elif (dv_TV_Peso_2/media_TV_Peso_2>=0.7) & (dv_TV_Peso_2/media_TV_Peso_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Peso_2"]=(df.loc[i,"TV_Peso_2"]-min_TV_Peso_2)/(max_TV_Peso_2-min_TV_Peso_2)
elif (dv_TV_Peso_2/media_TV_Peso_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Peso_2"]=np.log(df.loc[i,"TV_Peso_2"])
else:
    pass             
    

dv_TV_Altura_2=df['TV_Altura_2'].std()
media_TV_Altura_2=df['TV_Altura_2'].mean()
max_TV_Altura_2=df['TV_Altura_2'].max()
min_TV_Altura_2=df['TV_Altura_2'].min()
if (dv_TV_Altura_2/media_TV_Altura_2>0.3) & (dv_TV_Altura_2/media_TV_Altura_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Altura_2"]=(df.loc[i,"TV_Altura_2"]-media_TV_Altura_2)/dv_TV_Altura_2
elif (dv_TV_Altura_2/media_TV_Altura_2>=0.7) & (dv_TV_Altura_2/media_TV_Altura_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Altura_2"]=(df.loc[i,"TV_Altura_2"]-min_TV_Altura_2)/(max_TV_Altura_2-min_TV_Altura_2)
elif (dv_TV_Altura_2/media_TV_Altura_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Altura_2"]=np.log(df.loc[i,"TV_Altura_2"])
else:
    pass             
    

dv_TV_Coste_2=df['TV_Coste_2'].std()
media_TV_Coste_2=df['TV_Coste_2'].mean()
max_TV_Coste_2=df['TV_Coste_2'].max()
min_TV_Coste_2=df['TV_Coste_2'].min()
if (dv_TV_Coste_2/media_TV_Coste_2>0.3) & (dv_TV_Coste_2/media_TV_Coste_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Coste_2"]=(df.loc[i,"TV_Coste_2"]-media_TV_Coste_2)/dv_TV_Coste_2
elif (dv_TV_Coste_2/media_TV_Coste_2>=0.7) & (dv_TV_Coste_2/media_TV_Coste_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Coste_2"]=(df.loc[i,"TV_Coste_2"]-min_TV_Coste_2)/(max_TV_Coste_2-min_TV_Coste_2)
elif (dv_TV_Coste_2/media_TV_Coste_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Coste_2"]=np.log(df.loc[i,"TV_Coste_2"])
else:
    pass             
    

dv_TV_Beneficio_2=df['TV_Beneficio_2'].std()
media_TV_Beneficio_2=df['TV_Beneficio_2'].mean()
max_TV_Beneficio_2=df['TV_Beneficio_2'].max()
min_TV_Beneficio_2=df['TV_Beneficio_2'].min()
if (dv_TV_Beneficio_2/media_TV_Beneficio_2>0.3) & (dv_TV_Beneficio_2/media_TV_Beneficio_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Beneficio_2"]=(df.loc[i,"TV_Beneficio_2"]-media_TV_Beneficio_2)/dv_TV_Beneficio_2
elif (dv_TV_Beneficio_2/media_TV_Beneficio_2>=0.7) & (dv_TV_Beneficio_2/media_TV_Beneficio_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Beneficio_2"]=(df.loc[i,"TV_Beneficio_2"]-min_TV_Beneficio_2)/(max_TV_Beneficio_2-min_TV_Beneficio_2)
elif (dv_TV_Beneficio_2/media_TV_Beneficio_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Beneficio_2"]=np.log(df.loc[i,"TV_Beneficio_2"])
else:
    pass             
    

dv_TV_Base_X_2=df['TV_Base_X_2'].std()
media_TV_Base_X_2=df['TV_Base_X_2'].mean()
max_TV_Base_X_2=df['TV_Base_X_2'].max()
min_TV_Base_X_2=df['TV_Base_X_2'].min()
if (dv_TV_Base_X_2/media_TV_Base_X_2>0.3) & (dv_TV_Base_X_2/media_TV_Base_X_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Base_X_2"]=(df.loc[i,"TV_Base_X_2"]-media_TV_Base_X_2)/dv_TV_Base_X_2
elif (dv_TV_Base_X_2/media_TV_Base_X_2>=0.7) & (dv_TV_Base_X_2/media_TV_Base_X_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Base_X_2"]=(df.loc[i,"TV_Base_X_2"]-min_TV_Base_X_2)/(max_TV_Base_X_2-min_TV_Base_X_2)
elif (dv_TV_Base_X_2/media_TV_Base_X_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Base_X_2"]=np.log(df.loc[i,"TV_Base_X_2"])
else:
    pass             
    

dv_TV_Base_Y_2=df['TV_Base_Y_2'].std()
media_TV_Base_Y_2=df['TV_Base_Y_2'].mean()
max_TV_Base_Y_2=df['TV_Base_Y_2'].max()
min_TV_Base_Y_2=df['TV_Base_Y_2'].min()
if (dv_TV_Base_Y_2/media_TV_Base_Y_2>0.3) & (dv_TV_Base_Y_2/media_TV_Base_Y_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Base_Y_2"]=(df.loc[i,"TV_Base_Y_2"]-media_TV_Base_Y_2)/dv_TV_Base_Y_2
elif (dv_TV_Base_Y_2/media_TV_Base_Y_2>=0.7) & (dv_TV_Base_Y_2/media_TV_Base_Y_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Base_Y_2"]=(df.loc[i,"TV_Base_Y_2"]-min_TV_Base_Y_2)/(max_TV_Base_Y_2-min_TV_Base_Y_2)
elif (dv_TV_Base_Y_2/media_TV_Base_Y_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Base_Y_2"]=np.log(df.loc[i,"TV_Base_Y_2"])
else:
    pass             
    

dv_TV_CRM_2=df['TV_CRM_2'].std()
media_TV_CRM_2=df['TV_CRM_2'].mean()
max_TV_CRM_2=df['TV_CRM_2'].max()
min_TV_CRM_2=df['TV_CRM_2'].min()
if (dv_TV_CRM_2/media_TV_CRM_2>0.3) & (dv_TV_CRM_2/media_TV_CRM_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_CRM_2"]=(df.loc[i,"TV_CRM_2"]-media_TV_CRM_2)/dv_TV_CRM_2
elif (dv_TV_CRM_2/media_TV_CRM_2>=0.7) & (dv_TV_CRM_2/media_TV_CRM_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_CRM_2"]=(df.loc[i,"TV_CRM_2"]-min_TV_CRM_2)/(max_TV_CRM_2-min_TV_CRM_2)
elif (dv_TV_CRM_2/media_TV_CRM_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_CRM_2"]=np.log(df.loc[i,"TV_CRM_2"])
else:
    pass             
    

dv_TV_ZHab_X_2=df['TV_ZHab_X_2'].std()
media_TV_ZHab_X_2=df['TV_ZHab_X_2'].mean()
max_TV_ZHab_X_2=df['TV_ZHab_X_2'].max()
min_TV_ZHab_X_2=df['TV_ZHab_X_2'].min()
if (dv_TV_ZHab_X_2/media_TV_ZHab_X_2>0.3) & (dv_TV_ZHab_X_2/media_TV_ZHab_X_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_ZHab_X_2"]=(df.loc[i,"TV_ZHab_X_2"]-media_TV_ZHab_X_2)/dv_TV_ZHab_X_2
elif (dv_TV_ZHab_X_2/media_TV_ZHab_X_2>=0.7) & (dv_TV_ZHab_X_2/media_TV_ZHab_X_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_ZHab_X_2"]=(df.loc[i,"TV_ZHab_X_2"]-min_TV_ZHab_X_2)/(max_TV_ZHab_X_2-min_TV_ZHab_X_2)
elif (dv_TV_ZHab_X_2/media_TV_ZHab_X_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_ZHab_X_2"]=np.log(df.loc[i,"TV_ZHab_X_2"])
else:
    pass             
    

dv_TV_ZHab_Y_2=df['TV_ZHab_Y_2'].std()
media_TV_ZHab_Y_2=df['TV_ZHab_Y_2'].mean()
max_TV_ZHab_Y_2=df['TV_ZHab_Y_2'].max()
min_TV_ZHab_Y_2=df['TV_ZHab_Y_2'].min()
if (dv_TV_ZHab_Y_2/media_TV_ZHab_Y_2>0.3) & (dv_TV_ZHab_Y_2/media_TV_ZHab_Y_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_ZHab_Y_2"]=(df.loc[i,"TV_ZHab_Y_2"]-media_TV_ZHab_Y_2)/dv_TV_ZHab_Y_2
elif (dv_TV_ZHab_Y_2/media_TV_ZHab_Y_2>=0.7) & (dv_TV_ZHab_Y_2/media_TV_ZHab_Y_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_ZHab_Y_2"]=(df.loc[i,"TV_ZHab_Y_2"]-min_TV_ZHab_Y_2)/(max_TV_ZHab_Y_2-min_TV_ZHab_Y_2)
elif (dv_TV_ZHab_Y_2/media_TV_ZHab_Y_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_ZHab_Y_2"]=np.log(df.loc[i,"TV_ZHab_Y_2"])
else:
    pass             
    

dv_TV_Chol_2=df['TV_Chol_2'].std()
media_TV_Chol_2=df['TV_Chol_2'].mean()
max_TV_Chol_2=df['TV_Chol_2'].max()
min_TV_Chol_2=df['TV_Chol_2'].min()
if (dv_TV_Chol_2/media_TV_Chol_2>0.3) & (dv_TV_Chol_2/media_TV_Chol_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Chol_2"]=(df.loc[i,"TV_Chol_2"]-media_TV_Chol_2)/dv_TV_Chol_2
elif (dv_TV_Chol_2/media_TV_Chol_2>=0.7) & (dv_TV_Chol_2/media_TV_Chol_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Chol_2"]=(df.loc[i,"TV_Chol_2"]-min_TV_Chol_2)/(max_TV_Chol_2-min_TV_Chol_2)
elif (dv_TV_Chol_2/media_TV_Chol_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Chol_2"]=np.log(df.loc[i,"TV_Chol_2"])
else:
    pass             
    

dv_TV_Thalach_2=df['TV_Thalach_2'].std()
media_TV_Thalach_2=df['TV_Thalach_2'].mean()
max_TV_Thalach_2=df['TV_Thalach_2'].max()
min_TV_Thalach_2=df['TV_Thalach_2'].min()
if (dv_TV_Thalach_2/media_TV_Thalach_2>0.3) & (dv_TV_Thalach_2/media_TV_Thalach_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Thalach_2"]=(df.loc[i,"TV_Thalach_2"]-media_TV_Thalach_2)/dv_TV_Thalach_2
elif (dv_TV_Thalach_2/media_TV_Thalach_2>=0.7) & (dv_TV_Thalach_2/media_TV_Thalach_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Thalach_2"]=(df.loc[i,"TV_Thalach_2"]-min_TV_Thalach_2)/(max_TV_Thalach_2-min_TV_Thalach_2)
elif (dv_TV_Thalach_2/media_TV_Thalach_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Thalach_2"]=np.log(df.loc[i,"TV_Thalach_2"])
else:
    pass             
    

dv_TV_Trestbps_2=df['TV_Trestbps_2'].std()
media_TV_Trestbps_2=df['TV_Trestbps_2'].mean()
max_TV_Trestbps_2=df['TV_Trestbps_2'].max()
min_TV_Trestbps_2=df['TV_Trestbps_2'].min()
if (dv_TV_Trestbps_2/media_TV_Trestbps_2>0.3) & (dv_TV_Trestbps_2/media_TV_Trestbps_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Trestbps_2"]=(df.loc[i,"TV_Trestbps_2"]-media_TV_Trestbps_2)/dv_TV_Trestbps_2
elif (dv_TV_Trestbps_2/media_TV_Trestbps_2>=0.7) & (dv_TV_Trestbps_2/media_TV_Trestbps_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Trestbps_2"]=(df.loc[i,"TV_Trestbps_2"]-min_TV_Trestbps_2)/(max_TV_Trestbps_2-min_TV_Trestbps_2)
elif (dv_TV_Trestbps_2/media_TV_Trestbps_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Trestbps_2"]=np.log(df.loc[i,"TV_Trestbps_2"])
else:
    pass             
    

dv_TV_Eccentricity_2=df['TV_Eccentricity_2'].std()
media_TV_Eccentricity_2=df['TV_Eccentricity_2'].mean()
max_TV_Eccentricity_2=df['TV_Eccentricity_2'].max()
min_TV_Eccentricity_2=df['TV_Eccentricity_2'].min()
if (dv_TV_Eccentricity_2/media_TV_Eccentricity_2>0.3) & (dv_TV_Eccentricity_2/media_TV_Eccentricity_2<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Eccentricity_2"]=(df.loc[i,"TV_Eccentricity_2"]-media_TV_Eccentricity_2)/dv_TV_Eccentricity_2
elif (dv_TV_Eccentricity_2/media_TV_Eccentricity_2>=0.7) & (dv_TV_Eccentricity_2/media_TV_Eccentricity_2<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"TV_Eccentricity_2"]=(df.loc[i,"TV_Eccentricity_2"]-min_TV_Eccentricity_2)/(max_TV_Eccentricity_2-min_TV_Eccentricity_2)
elif (dv_TV_Eccentricity_2/media_TV_Eccentricity_2>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"TV_Eccentricity_2"]=np.log(df.loc[i,"TV_Eccentricity_2"])
else:
    pass             
    

dv_media_movil_Peso=df['media_movil_Peso'].std()
media_media_movil_Peso=df['media_movil_Peso'].mean()
max_media_movil_Peso=df['media_movil_Peso'].max()
min_media_movil_Peso=df['media_movil_Peso'].min()
if (dv_media_movil_Peso/media_media_movil_Peso>0.3) & (dv_media_movil_Peso/media_media_movil_Peso<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Peso"]=(df.loc[i,"media_movil_Peso"]-media_media_movil_Peso)/dv_media_movil_Peso
elif (dv_media_movil_Peso/media_media_movil_Peso>=0.7) & (dv_media_movil_Peso/media_media_movil_Peso<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Peso"]=(df.loc[i,"media_movil_Peso"]-min_media_movil_Peso)/(max_media_movil_Peso-min_media_movil_Peso)
elif (dv_media_movil_Peso/media_media_movil_Peso>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"media_movil_Peso"]=np.log(df.loc[i,"media_movil_Peso"])
else:
    pass             
    

dv_media_movil_Altura=df['media_movil_Altura'].std()
media_media_movil_Altura=df['media_movil_Altura'].mean()
max_media_movil_Altura=df['media_movil_Altura'].max()
min_media_movil_Altura=df['media_movil_Altura'].min()
if (dv_media_movil_Altura/media_media_movil_Altura>0.3) & (dv_media_movil_Altura/media_media_movil_Altura<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Altura"]=(df.loc[i,"media_movil_Altura"]-media_media_movil_Altura)/dv_media_movil_Altura
elif (dv_media_movil_Altura/media_media_movil_Altura>=0.7) & (dv_media_movil_Altura/media_media_movil_Altura<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Altura"]=(df.loc[i,"media_movil_Altura"]-min_media_movil_Altura)/(max_media_movil_Altura-min_media_movil_Altura)
elif (dv_media_movil_Altura/media_media_movil_Altura>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"media_movil_Altura"]=np.log(df.loc[i,"media_movil_Altura"])
else:
    pass             
    

dv_media_movil_Coste=df['media_movil_Coste'].std()
media_media_movil_Coste=df['media_movil_Coste'].mean()
max_media_movil_Coste=df['media_movil_Coste'].max()
min_media_movil_Coste=df['media_movil_Coste'].min()
if (dv_media_movil_Coste/media_media_movil_Coste>0.3) & (dv_media_movil_Coste/media_media_movil_Coste<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Coste"]=(df.loc[i,"media_movil_Coste"]-media_media_movil_Coste)/dv_media_movil_Coste
elif (dv_media_movil_Coste/media_media_movil_Coste>=0.7) & (dv_media_movil_Coste/media_media_movil_Coste<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Coste"]=(df.loc[i,"media_movil_Coste"]-min_media_movil_Coste)/(max_media_movil_Coste-min_media_movil_Coste)
elif (dv_media_movil_Coste/media_media_movil_Coste>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"media_movil_Coste"]=np.log(df.loc[i,"media_movil_Coste"])
else:
    pass             
    

dv_media_movil_Beneficio=df['media_movil_Beneficio'].std()
media_media_movil_Beneficio=df['media_movil_Beneficio'].mean()
max_media_movil_Beneficio=df['media_movil_Beneficio'].max()
min_media_movil_Beneficio=df['media_movil_Beneficio'].min()
if (dv_media_movil_Beneficio/media_media_movil_Beneficio>0.3) & (dv_media_movil_Beneficio/media_media_movil_Beneficio<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Beneficio"]=(df.loc[i,"media_movil_Beneficio"]-media_media_movil_Beneficio)/dv_media_movil_Beneficio
elif (dv_media_movil_Beneficio/media_media_movil_Beneficio>=0.7) & (dv_media_movil_Beneficio/media_media_movil_Beneficio<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Beneficio"]=(df.loc[i,"media_movil_Beneficio"]-min_media_movil_Beneficio)/(max_media_movil_Beneficio-min_media_movil_Beneficio)
elif (dv_media_movil_Beneficio/media_media_movil_Beneficio>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"media_movil_Beneficio"]=np.log(df.loc[i,"media_movil_Beneficio"])
else:
    pass             
    

dv_media_movil_Base_X=df['media_movil_Base_X'].std()
media_media_movil_Base_X=df['media_movil_Base_X'].mean()
max_media_movil_Base_X=df['media_movil_Base_X'].max()
min_media_movil_Base_X=df['media_movil_Base_X'].min()
if (dv_media_movil_Base_X/media_media_movil_Base_X>0.3) & (dv_media_movil_Base_X/media_media_movil_Base_X<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Base_X"]=(df.loc[i,"media_movil_Base_X"]-media_media_movil_Base_X)/dv_media_movil_Base_X
elif (dv_media_movil_Base_X/media_media_movil_Base_X>=0.7) & (dv_media_movil_Base_X/media_media_movil_Base_X<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Base_X"]=(df.loc[i,"media_movil_Base_X"]-min_media_movil_Base_X)/(max_media_movil_Base_X-min_media_movil_Base_X)
elif (dv_media_movil_Base_X/media_media_movil_Base_X>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"media_movil_Base_X"]=np.log(df.loc[i,"media_movil_Base_X"])
else:
    pass             
    

dv_media_movil_Base_Y=df['media_movil_Base_Y'].std()
media_media_movil_Base_Y=df['media_movil_Base_Y'].mean()
max_media_movil_Base_Y=df['media_movil_Base_Y'].max()
min_media_movil_Base_Y=df['media_movil_Base_Y'].min()
if (dv_media_movil_Base_Y/media_media_movil_Base_Y>0.3) & (dv_media_movil_Base_Y/media_media_movil_Base_Y<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Base_Y"]=(df.loc[i,"media_movil_Base_Y"]-media_media_movil_Base_Y)/dv_media_movil_Base_Y
elif (dv_media_movil_Base_Y/media_media_movil_Base_Y>=0.7) & (dv_media_movil_Base_Y/media_media_movil_Base_Y<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Base_Y"]=(df.loc[i,"media_movil_Base_Y"]-min_media_movil_Base_Y)/(max_media_movil_Base_Y-min_media_movil_Base_Y)
elif (dv_media_movil_Base_Y/media_media_movil_Base_Y>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"media_movil_Base_Y"]=np.log(df.loc[i,"media_movil_Base_Y"])
else:
    pass             
    

dv_media_movil_CRM=df['media_movil_CRM'].std()
media_media_movil_CRM=df['media_movil_CRM'].mean()
max_media_movil_CRM=df['media_movil_CRM'].max()
min_media_movil_CRM=df['media_movil_CRM'].min()
if (dv_media_movil_CRM/media_media_movil_CRM>0.3) & (dv_media_movil_CRM/media_media_movil_CRM<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_CRM"]=(df.loc[i,"media_movil_CRM"]-media_media_movil_CRM)/dv_media_movil_CRM
elif (dv_media_movil_CRM/media_media_movil_CRM>=0.7) & (dv_media_movil_CRM/media_media_movil_CRM<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_CRM"]=(df.loc[i,"media_movil_CRM"]-min_media_movil_CRM)/(max_media_movil_CRM-min_media_movil_CRM)
elif (dv_media_movil_CRM/media_media_movil_CRM>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"media_movil_CRM"]=np.log(df.loc[i,"media_movil_CRM"])
else:
    pass             
    

dv_media_movil_ZHab_X=df['media_movil_ZHab_X'].std()
media_media_movil_ZHab_X=df['media_movil_ZHab_X'].mean()
max_media_movil_ZHab_X=df['media_movil_ZHab_X'].max()
min_media_movil_ZHab_X=df['media_movil_ZHab_X'].min()
if (dv_media_movil_ZHab_X/media_media_movil_ZHab_X>0.3) & (dv_media_movil_ZHab_X/media_media_movil_ZHab_X<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_ZHab_X"]=(df.loc[i,"media_movil_ZHab_X"]-media_media_movil_ZHab_X)/dv_media_movil_ZHab_X
elif (dv_media_movil_ZHab_X/media_media_movil_ZHab_X>=0.7) & (dv_media_movil_ZHab_X/media_media_movil_ZHab_X<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_ZHab_X"]=(df.loc[i,"media_movil_ZHab_X"]-min_media_movil_ZHab_X)/(max_media_movil_ZHab_X-min_media_movil_ZHab_X)
elif (dv_media_movil_ZHab_X/media_media_movil_ZHab_X>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"media_movil_ZHab_X"]=np.log(df.loc[i,"media_movil_ZHab_X"])
else:
    pass             
    

dv_media_movil_ZHab_Y=df['media_movil_ZHab_Y'].std()
media_media_movil_ZHab_Y=df['media_movil_ZHab_Y'].mean()
max_media_movil_ZHab_Y=df['media_movil_ZHab_Y'].max()
min_media_movil_ZHab_Y=df['media_movil_ZHab_Y'].min()
if (dv_media_movil_ZHab_Y/media_media_movil_ZHab_Y>0.3) & (dv_media_movil_ZHab_Y/media_media_movil_ZHab_Y<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_ZHab_Y"]=(df.loc[i,"media_movil_ZHab_Y"]-media_media_movil_ZHab_Y)/dv_media_movil_ZHab_Y
elif (dv_media_movil_ZHab_Y/media_media_movil_ZHab_Y>=0.7) & (dv_media_movil_ZHab_Y/media_media_movil_ZHab_Y<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_ZHab_Y"]=(df.loc[i,"media_movil_ZHab_Y"]-min_media_movil_ZHab_Y)/(max_media_movil_ZHab_Y-min_media_movil_ZHab_Y)
elif (dv_media_movil_ZHab_Y/media_media_movil_ZHab_Y>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"media_movil_ZHab_Y"]=np.log(df.loc[i,"media_movil_ZHab_Y"])
else:
    pass             
    

dv_media_movil_Chol=df['media_movil_Chol'].std()
media_media_movil_Chol=df['media_movil_Chol'].mean()
max_media_movil_Chol=df['media_movil_Chol'].max()
min_media_movil_Chol=df['media_movil_Chol'].min()
if (dv_media_movil_Chol/media_media_movil_Chol>0.3) & (dv_media_movil_Chol/media_media_movil_Chol<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Chol"]=(df.loc[i,"media_movil_Chol"]-media_media_movil_Chol)/dv_media_movil_Chol
elif (dv_media_movil_Chol/media_media_movil_Chol>=0.7) & (dv_media_movil_Chol/media_media_movil_Chol<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Chol"]=(df.loc[i,"media_movil_Chol"]-min_media_movil_Chol)/(max_media_movil_Chol-min_media_movil_Chol)
elif (dv_media_movil_Chol/media_media_movil_Chol>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"media_movil_Chol"]=np.log(df.loc[i,"media_movil_Chol"])
else:
    pass             
    

dv_media_movil_Thalach=df['media_movil_Thalach'].std()
media_media_movil_Thalach=df['media_movil_Thalach'].mean()
max_media_movil_Thalach=df['media_movil_Thalach'].max()
min_media_movil_Thalach=df['media_movil_Thalach'].min()
if (dv_media_movil_Thalach/media_media_movil_Thalach>0.3) & (dv_media_movil_Thalach/media_media_movil_Thalach<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Thalach"]=(df.loc[i,"media_movil_Thalach"]-media_media_movil_Thalach)/dv_media_movil_Thalach
elif (dv_media_movil_Thalach/media_media_movil_Thalach>=0.7) & (dv_media_movil_Thalach/media_media_movil_Thalach<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Thalach"]=(df.loc[i,"media_movil_Thalach"]-min_media_movil_Thalach)/(max_media_movil_Thalach-min_media_movil_Thalach)
elif (dv_media_movil_Thalach/media_media_movil_Thalach>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"media_movil_Thalach"]=np.log(df.loc[i,"media_movil_Thalach"])
else:
    pass             
    

dv_media_movil_Trestbps=df['media_movil_Trestbps'].std()
media_media_movil_Trestbps=df['media_movil_Trestbps'].mean()
max_media_movil_Trestbps=df['media_movil_Trestbps'].max()
min_media_movil_Trestbps=df['media_movil_Trestbps'].min()
if (dv_media_movil_Trestbps/media_media_movil_Trestbps>0.3) & (dv_media_movil_Trestbps/media_media_movil_Trestbps<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Trestbps"]=(df.loc[i,"media_movil_Trestbps"]-media_media_movil_Trestbps)/dv_media_movil_Trestbps
elif (dv_media_movil_Trestbps/media_media_movil_Trestbps>=0.7) & (dv_media_movil_Trestbps/media_media_movil_Trestbps<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Trestbps"]=(df.loc[i,"media_movil_Trestbps"]-min_media_movil_Trestbps)/(max_media_movil_Trestbps-min_media_movil_Trestbps)
elif (dv_media_movil_Trestbps/media_media_movil_Trestbps>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"media_movil_Trestbps"]=np.log(df.loc[i,"media_movil_Trestbps"])
else:
    pass             
    

dv_media_movil_Eccentricity=df['media_movil_Eccentricity'].std()
media_media_movil_Eccentricity=df['media_movil_Eccentricity'].mean()
max_media_movil_Eccentricity=df['media_movil_Eccentricity'].max()
min_media_movil_Eccentricity=df['media_movil_Eccentricity'].min()
if (dv_media_movil_Eccentricity/media_media_movil_Eccentricity>0.3) & (dv_media_movil_Eccentricity/media_media_movil_Eccentricity<0.7):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Eccentricity"]=(df.loc[i,"media_movil_Eccentricity"]-media_media_movil_Eccentricity)/dv_media_movil_Eccentricity
elif (dv_media_movil_Eccentricity/media_media_movil_Eccentricity>=0.7) & (dv_media_movil_Eccentricity/media_media_movil_Eccentricity<1.3):
    dim=df.shape[0]
    for i in range(dim):
        df.loc[i,"media_movil_Eccentricity"]=(df.loc[i,"media_movil_Eccentricity"]-min_media_movil_Eccentricity)/(max_media_movil_Eccentricity-min_media_movil_Eccentricity)
elif (dv_media_movil_Eccentricity/media_media_movil_Eccentricity>=1.3):
      dim=df.shape[0]
      for i in range(dim):
        import numpy as np
        df.loc[i,"media_movil_Eccentricity"]=np.log(df.loc[i,"media_movil_Eccentricity"])
else:
    pass

# %%
for i in range(len(df)):
    if df.loc[i,"media_movil_ID"]>df.loc[i+1,"media_movil_ID"]:
        df.loc[i,"Tendecia_ID"]=1
    else:
        if df.loc[i,"ID"]<df.loc[i+1,"ID"]:
            df.loc[i,"Tendecia_ID"]=2
        else:
            df.loc[i,"Tendecia_ID"]=3

    df["Tendecia_ID_categorizada"]=np.where(df["Tendecia_ID"]==1,'Decreciente',df["Tendecia_ID"])
    df["Tendecia_ID_categorizada"]=np.where(df["Tendecia_ID"]=='2','Crecreciente',df["Tendecia_ID"])
    df["Tendecia_ID_categorizada"]=np.where(df["Tendecia_ID"]=='3','Constate',df["Tendecia_ID"])
    del df["Tendecia_ID"]


    if df.loc[i,"media_movil_Peso"]>df.loc[i+1,"media_movil_Peso"]:
        df.loc[i,"Tendecia_Peso"]=1
    else:
        if df.loc[i,"Peso"]<df.loc[i+1,"Peso"]:
            df.loc[i,"Tendecia_Peso"]=2
        else:
            df.loc[i,"Tendecia_Peso"]=3

    df["Tendecia_Peso_categorizada"]=np.where(df["Tendecia_Peso"]==1,'Decreciente',df["Tendecia_Peso"])
    df["Tendecia_Peso_categorizada"]=np.where(df["Tendecia_Peso"]=='2','Crecreciente',df["Tendecia_Peso"])
    df["Tendecia_Peso_categorizada"]=np.where(df["Tendecia_Peso"]=='3','Constate',df["Tendecia_Peso"])
    del df["Tendecia_Peso"]


    if df.loc[i,"media_movil_Altura"]>df.loc[i+1,"media_movil_Altura"]:
        df.loc[i,"Tendecia_Altura"]=1
    else:
        if df.loc[i,"Altura"]<df.loc[i+1,"Altura"]:
            df.loc[i,"Tendecia_Altura"]=2
        else:
            df.loc[i,"Tendecia_Altura"]=3

    df["Tendecia_Altura_categorizada"]=np.where(df["Tendecia_Altura"]==1,'Decreciente',df["Tendecia_Altura"])
    df["Tendecia_Altura_categorizada"]=np.where(df["Tendecia_Altura"]=='2','Crecreciente',df["Tendecia_Altura"])
    df["Tendecia_Altura_categorizada"]=np.where(df["Tendecia_Altura"]=='3','Constate',df["Tendecia_Altura"])
    del df["Tendecia_Altura"]


    if df.loc[i,"media_movil_Coste"]>df.loc[i+1,"media_movil_Coste"]:
        df.loc[i,"Tendecia_Coste"]=1
    else:
        if df.loc[i,"Coste"]<df.loc[i+1,"Coste"]:
            df.loc[i,"Tendecia_Coste"]=2
        else:
            df.loc[i,"Tendecia_Coste"]=3

    df["Tendecia_Coste_categorizada"]=np.where(df["Tendecia_Coste"]==1,'Decreciente',df["Tendecia_Coste"])
    df["Tendecia_Coste_categorizada"]=np.where(df["Tendecia_Coste"]=='2','Crecreciente',df["Tendecia_Coste"])
    df["Tendecia_Coste_categorizada"]=np.where(df["Tendecia_Coste"]=='3','Constate',df["Tendecia_Coste"])
    del df["Tendecia_Coste"]


    if df.loc[i,"media_movil_Beneficio"]>df.loc[i+1,"media_movil_Beneficio"]:
        df.loc[i,"Tendecia_Beneficio"]=1
    else:
        if df.loc[i,"Beneficio"]<df.loc[i+1,"Beneficio"]:
            df.loc[i,"Tendecia_Beneficio"]=2
        else:
            df.loc[i,"Tendecia_Beneficio"]=3

    df["Tendecia_Beneficio_categorizada"]=np.where(df["Tendecia_Beneficio"]==1,'Decreciente',df["Tendecia_Beneficio"])
    df["Tendecia_Beneficio_categorizada"]=np.where(df["Tendecia_Beneficio"]=='2','Crecreciente',df["Tendecia_Beneficio"])
    df["Tendecia_Beneficio_categorizada"]=np.where(df["Tendecia_Beneficio"]=='3','Constate',df["Tendecia_Beneficio"])
    del df["Tendecia_Beneficio"]


    if df.loc[i,"media_movil_Base_X"]>df.loc[i+1,"media_movil_Base_X"]:
        df.loc[i,"Tendecia_Base_X"]=1
    else:
        if df.loc[i,"Base_X"]<df.loc[i+1,"Base_X"]:
            df.loc[i,"Tendecia_Base_X"]=2
        else:
            df.loc[i,"Tendecia_Base_X"]=3

    df["Tendecia_Base_X_categorizada"]=np.where(df["Tendecia_Base_X"]==1,'Decreciente',df["Tendecia_Base_X"])
    df["Tendecia_Base_X_categorizada"]=np.where(df["Tendecia_Base_X"]=='2','Crecreciente',df["Tendecia_Base_X"])
    df["Tendecia_Base_X_categorizada"]=np.where(df["Tendecia_Base_X"]=='3','Constate',df["Tendecia_Base_X"])
    del df["Tendecia_Base_X"]


    if df.loc[i,"media_movil_Base_Y"]>df.loc[i+1,"media_movil_Base_Y"]:
        df.loc[i,"Tendecia_Base_Y"]=1
    else:
        if df.loc[i,"Base_Y"]<df.loc[i+1,"Base_Y"]:
            df.loc[i,"Tendecia_Base_Y"]=2
        else:
            df.loc[i,"Tendecia_Base_Y"]=3

    df["Tendecia_Base_Y_categorizada"]=np.where(df["Tendecia_Base_Y"]==1,'Decreciente',df["Tendecia_Base_Y"])
    df["Tendecia_Base_Y_categorizada"]=np.where(df["Tendecia_Base_Y"]=='2','Crecreciente',df["Tendecia_Base_Y"])
    df["Tendecia_Base_Y_categorizada"]=np.where(df["Tendecia_Base_Y"]=='3','Constate',df["Tendecia_Base_Y"])
    del df["Tendecia_Base_Y"]


    if df.loc[i,"media_movil_CRM"]>df.loc[i+1,"media_movil_CRM"]:
        df.loc[i,"Tendecia_CRM"]=1
    else:
        if df.loc[i,"CRM"]<df.loc[i+1,"CRM"]:
            df.loc[i,"Tendecia_CRM"]=2
        else:
            df.loc[i,"Tendecia_CRM"]=3

    df["Tendecia_CRM_categorizada"]=np.where(df["Tendecia_CRM"]==1,'Decreciente',df["Tendecia_CRM"])
    df["Tendecia_CRM_categorizada"]=np.where(df["Tendecia_CRM"]=='2','Crecreciente',df["Tendecia_CRM"])
    df["Tendecia_CRM_categorizada"]=np.where(df["Tendecia_CRM"]=='3','Constate',df["Tendecia_CRM"])
    del df["Tendecia_CRM"]


    if df.loc[i,"media_movil_ZHab_X"]>df.loc[i+1,"media_movil_ZHab_X"]:
        df.loc[i,"Tendecia_ZHab_X"]=1
    else:
        if df.loc[i,"ZHab_X"]<df.loc[i+1,"ZHab_X"]:
            df.loc[i,"Tendecia_ZHab_X"]=2
        else:
            df.loc[i,"Tendecia_ZHab_X"]=3

    df["Tendecia_ZHab_X_categorizada"]=np.where(df["Tendecia_ZHab_X"]==1,'Decreciente',df["Tendecia_ZHab_X"])
    df["Tendecia_ZHab_X_categorizada"]=np.where(df["Tendecia_ZHab_X"]=='2','Crecreciente',df["Tendecia_ZHab_X"])
    df["Tendecia_ZHab_X_categorizada"]=np.where(df["Tendecia_ZHab_X"]=='3','Constate',df["Tendecia_ZHab_X"])
    del df["Tendecia_ZHab_X"]


    if df.loc[i,"media_movil_ZHab_Y"]>df.loc[i+1,"media_movil_ZHab_Y"]:
        df.loc[i,"Tendecia_ZHab_Y"]=1
    else:
        if df.loc[i,"ZHab_Y"]<df.loc[i+1,"ZHab_Y"]:
            df.loc[i,"Tendecia_ZHab_Y"]=2
        else:
            df.loc[i,"Tendecia_ZHab_Y"]=3

    df["Tendecia_ZHab_Y_categorizada"]=np.where(df["Tendecia_ZHab_Y"]==1,'Decreciente',df["Tendecia_ZHab_Y"])
    df["Tendecia_ZHab_Y_categorizada"]=np.where(df["Tendecia_ZHab_Y"]=='2','Crecreciente',df["Tendecia_ZHab_Y"])
    df["Tendecia_ZHab_Y_categorizada"]=np.where(df["Tendecia_ZHab_Y"]=='3','Constate',df["Tendecia_ZHab_Y"])
    del df["Tendecia_ZHab_Y"]


    if df.loc[i,"media_movil_Chol"]>df.loc[i+1,"media_movil_Chol"]:
        df.loc[i,"Tendecia_Chol"]=1
    else:
        if df.loc[i,"Chol"]<df.loc[i+1,"Chol"]:
            df.loc[i,"Tendecia_Chol"]=2
        else:
            df.loc[i,"Tendecia_Chol"]=3

    df["Tendecia_Chol_categorizada"]=np.where(df["Tendecia_Chol"]==1,'Decreciente',df["Tendecia_Chol"])
    df["Tendecia_Chol_categorizada"]=np.where(df["Tendecia_Chol"]=='2','Crecreciente',df["Tendecia_Chol"])
    df["Tendecia_Chol_categorizada"]=np.where(df["Tendecia_Chol"]=='3','Constate',df["Tendecia_Chol"])
    del df["Tendecia_Chol"]


    if df.loc[i,"media_movil_Thalach"]>df.loc[i+1,"media_movil_Thalach"]:
        df.loc[i,"Tendecia_Thalach"]=1
    else:
        if df.loc[i,"Thalach"]<df.loc[i+1,"Thalach"]:
            df.loc[i,"Tendecia_Thalach"]=2
        else:
            df.loc[i,"Tendecia_Thalach"]=3

    df["Tendecia_Thalach_categorizada"]=np.where(df["Tendecia_Thalach"]==1,'Decreciente',df["Tendecia_Thalach"])
    df["Tendecia_Thalach_categorizada"]=np.where(df["Tendecia_Thalach"]=='2','Crecreciente',df["Tendecia_Thalach"])
    df["Tendecia_Thalach_categorizada"]=np.where(df["Tendecia_Thalach"]=='3','Constate',df["Tendecia_Thalach"])
    del df["Tendecia_Thalach"]


    if df.loc[i,"media_movil_Trestbps"]>df.loc[i+1,"media_movil_Trestbps"]:
        df.loc[i,"Tendecia_Trestbps"]=1
    else:
        if df.loc[i,"Trestbps"]<df.loc[i+1,"Trestbps"]:
            df.loc[i,"Tendecia_Trestbps"]=2
        else:
            df.loc[i,"Tendecia_Trestbps"]=3

    df["Tendecia_Trestbps_categorizada"]=np.where(df["Tendecia_Trestbps"]==1,'Decreciente',df["Tendecia_Trestbps"])
    df["Tendecia_Trestbps_categorizada"]=np.where(df["Tendecia_Trestbps"]=='2','Crecreciente',df["Tendecia_Trestbps"])
    df["Tendecia_Trestbps_categorizada"]=np.where(df["Tendecia_Trestbps"]=='3','Constate',df["Tendecia_Trestbps"])
    del df["Tendecia_Trestbps"]


    if df.loc[i,"media_movil_Eccentricity"]>df.loc[i+1,"media_movil_Eccentricity"]:
        df.loc[i,"Tendecia_Eccentricity"]=1
    else:
        if df.loc[i,"Eccentricity"]<df.loc[i+1,"Eccentricity"]:
            df.loc[i,"Tendecia_Eccentricity"]=2
        else:
            df.loc[i,"Tendecia_Eccentricity"]=3

    df["Tendecia_Eccentricity_categorizada"]=np.where(df["Tendecia_Eccentricity"]==1,'Decreciente',df["Tendecia_Eccentricity"])
    df["Tendecia_Eccentricity_categorizada"]=np.where(df["Tendecia_Eccentricity"]=='2','Crecreciente',df["Tendecia_Eccentricity"])
    df["Tendecia_Eccentricity_categorizada"]=np.where(df["Tendecia_Eccentricity"]=='3','Constate',df["Tendecia_Eccentricity"])
    del df["Tendecia_Eccentricity"]


    if df.loc[i,"media_movil_Peso_lag_1"]>df.loc[i+1,"media_movil_Peso_lag_1"]:
        df.loc[i,"Tendecia_Peso_lag_1"]=1
    else:
        if df.loc[i,"Peso_lag_1"]<df.loc[i+1,"Peso_lag_1"]:
            df.loc[i,"Tendecia_Peso_lag_1"]=2
        else:
            df.loc[i,"Tendecia_Peso_lag_1"]=3

    df["Tendecia_Peso_lag_1_categorizada"]=np.where(df["Tendecia_Peso_lag_1"]==1,'Decreciente',df["Tendecia_Peso_lag_1"])
    df["Tendecia_Peso_lag_1_categorizada"]=np.where(df["Tendecia_Peso_lag_1"]=='2','Crecreciente',df["Tendecia_Peso_lag_1"])
    df["Tendecia_Peso_lag_1_categorizada"]=np.where(df["Tendecia_Peso_lag_1"]=='3','Constate',df["Tendecia_Peso_lag_1"])
    del df["Tendecia_Peso_lag_1"]


    if df.loc[i,"media_movil_Altura_lag_1"]>df.loc[i+1,"media_movil_Altura_lag_1"]:
        df.loc[i,"Tendecia_Altura_lag_1"]=1
    else:
        if df.loc[i,"Altura_lag_1"]<df.loc[i+1,"Altura_lag_1"]:
            df.loc[i,"Tendecia_Altura_lag_1"]=2
        else:
            df.loc[i,"Tendecia_Altura_lag_1"]=3

    df["Tendecia_Altura_lag_1_categorizada"]=np.where(df["Tendecia_Altura_lag_1"]==1,'Decreciente',df["Tendecia_Altura_lag_1"])
    df["Tendecia_Altura_lag_1_categorizada"]=np.where(df["Tendecia_Altura_lag_1"]=='2','Crecreciente',df["Tendecia_Altura_lag_1"])
    df["Tendecia_Altura_lag_1_categorizada"]=np.where(df["Tendecia_Altura_lag_1"]=='3','Constate',df["Tendecia_Altura_lag_1"])
    del df["Tendecia_Altura_lag_1"]


    if df.loc[i,"media_movil_Coste_lag_1"]>df.loc[i+1,"media_movil_Coste_lag_1"]:
        df.loc[i,"Tendecia_Coste_lag_1"]=1
    else:
        if df.loc[i,"Coste_lag_1"]<df.loc[i+1,"Coste_lag_1"]:
            df.loc[i,"Tendecia_Coste_lag_1"]=2
        else:
            df.loc[i,"Tendecia_Coste_lag_1"]=3

    df["Tendecia_Coste_lag_1_categorizada"]=np.where(df["Tendecia_Coste_lag_1"]==1,'Decreciente',df["Tendecia_Coste_lag_1"])
    df["Tendecia_Coste_lag_1_categorizada"]=np.where(df["Tendecia_Coste_lag_1"]=='2','Crecreciente',df["Tendecia_Coste_lag_1"])
    df["Tendecia_Coste_lag_1_categorizada"]=np.where(df["Tendecia_Coste_lag_1"]=='3','Constate',df["Tendecia_Coste_lag_1"])
    del df["Tendecia_Coste_lag_1"]


    if df.loc[i,"media_movil_Beneficio_lag_1"]>df.loc[i+1,"media_movil_Beneficio_lag_1"]:
        df.loc[i,"Tendecia_Beneficio_lag_1"]=1
    else:
        if df.loc[i,"Beneficio_lag_1"]<df.loc[i+1,"Beneficio_lag_1"]:
            df.loc[i,"Tendecia_Beneficio_lag_1"]=2
        else:
            df.loc[i,"Tendecia_Beneficio_lag_1"]=3

    df["Tendecia_Beneficio_lag_1_categorizada"]=np.where(df["Tendecia_Beneficio_lag_1"]==1,'Decreciente',df["Tendecia_Beneficio_lag_1"])
    df["Tendecia_Beneficio_lag_1_categorizada"]=np.where(df["Tendecia_Beneficio_lag_1"]=='2','Crecreciente',df["Tendecia_Beneficio_lag_1"])
    df["Tendecia_Beneficio_lag_1_categorizada"]=np.where(df["Tendecia_Beneficio_lag_1"]=='3','Constate',df["Tendecia_Beneficio_lag_1"])
    del df["Tendecia_Beneficio_lag_1"]


    if df.loc[i,"media_movil_Base_X_lag_1"]>df.loc[i+1,"media_movil_Base_X_lag_1"]:
        df.loc[i,"Tendecia_Base_X_lag_1"]=1
    else:
        if df.loc[i,"Base_X_lag_1"]<df.loc[i+1,"Base_X_lag_1"]:
            df.loc[i,"Tendecia_Base_X_lag_1"]=2
        else:
            df.loc[i,"Tendecia_Base_X_lag_1"]=3

    df["Tendecia_Base_X_lag_1_categorizada"]=np.where(df["Tendecia_Base_X_lag_1"]==1,'Decreciente',df["Tendecia_Base_X_lag_1"])
    df["Tendecia_Base_X_lag_1_categorizada"]=np.where(df["Tendecia_Base_X_lag_1"]=='2','Crecreciente',df["Tendecia_Base_X_lag_1"])
    df["Tendecia_Base_X_lag_1_categorizada"]=np.where(df["Tendecia_Base_X_lag_1"]=='3','Constate',df["Tendecia_Base_X_lag_1"])
    del df["Tendecia_Base_X_lag_1"]


    if df.loc[i,"media_movil_Base_Y_lag_1"]>df.loc[i+1,"media_movil_Base_Y_lag_1"]:
        df.loc[i,"Tendecia_Base_Y_lag_1"]=1
    else:
        if df.loc[i,"Base_Y_lag_1"]<df.loc[i+1,"Base_Y_lag_1"]:
            df.loc[i,"Tendecia_Base_Y_lag_1"]=2
        else:
            df.loc[i,"Tendecia_Base_Y_lag_1"]=3

    df["Tendecia_Base_Y_lag_1_categorizada"]=np.where(df["Tendecia_Base_Y_lag_1"]==1,'Decreciente',df["Tendecia_Base_Y_lag_1"])
    df["Tendecia_Base_Y_lag_1_categorizada"]=np.where(df["Tendecia_Base_Y_lag_1"]=='2','Crecreciente',df["Tendecia_Base_Y_lag_1"])
    df["Tendecia_Base_Y_lag_1_categorizada"]=np.where(df["Tendecia_Base_Y_lag_1"]=='3','Constate',df["Tendecia_Base_Y_lag_1"])
    del df["Tendecia_Base_Y_lag_1"]


    if df.loc[i,"media_movil_CRM_lag_1"]>df.loc[i+1,"media_movil_CRM_lag_1"]:
        df.loc[i,"Tendecia_CRM_lag_1"]=1
    else:
        if df.loc[i,"CRM_lag_1"]<df.loc[i+1,"CRM_lag_1"]:
            df.loc[i,"Tendecia_CRM_lag_1"]=2
        else:
            df.loc[i,"Tendecia_CRM_lag_1"]=3

    df["Tendecia_CRM_lag_1_categorizada"]=np.where(df["Tendecia_CRM_lag_1"]==1,'Decreciente',df["Tendecia_CRM_lag_1"])
    df["Tendecia_CRM_lag_1_categorizada"]=np.where(df["Tendecia_CRM_lag_1"]=='2','Crecreciente',df["Tendecia_CRM_lag_1"])
    df["Tendecia_CRM_lag_1_categorizada"]=np.where(df["Tendecia_CRM_lag_1"]=='3','Constate',df["Tendecia_CRM_lag_1"])
    del df["Tendecia_CRM_lag_1"]


    if df.loc[i,"media_movil_ZHab_X_lag_1"]>df.loc[i+1,"media_movil_ZHab_X_lag_1"]:
        df.loc[i,"Tendecia_ZHab_X_lag_1"]=1
    else:
        if df.loc[i,"ZHab_X_lag_1"]<df.loc[i+1,"ZHab_X_lag_1"]:
            df.loc[i,"Tendecia_ZHab_X_lag_1"]=2
        else:
            df.loc[i,"Tendecia_ZHab_X_lag_1"]=3

    df["Tendecia_ZHab_X_lag_1_categorizada"]=np.where(df["Tendecia_ZHab_X_lag_1"]==1,'Decreciente',df["Tendecia_ZHab_X_lag_1"])
    df["Tendecia_ZHab_X_lag_1_categorizada"]=np.where(df["Tendecia_ZHab_X_lag_1"]=='2','Crecreciente',df["Tendecia_ZHab_X_lag_1"])
    df["Tendecia_ZHab_X_lag_1_categorizada"]=np.where(df["Tendecia_ZHab_X_lag_1"]=='3','Constate',df["Tendecia_ZHab_X_lag_1"])
    del df["Tendecia_ZHab_X_lag_1"]


    if df.loc[i,"media_movil_ZHab_Y_lag_1"]>df.loc[i+1,"media_movil_ZHab_Y_lag_1"]:
        df.loc[i,"Tendecia_ZHab_Y_lag_1"]=1
    else:
        if df.loc[i,"ZHab_Y_lag_1"]<df.loc[i+1,"ZHab_Y_lag_1"]:
            df.loc[i,"Tendecia_ZHab_Y_lag_1"]=2
        else:
            df.loc[i,"Tendecia_ZHab_Y_lag_1"]=3

    df["Tendecia_ZHab_Y_lag_1_categorizada"]=np.where(df["Tendecia_ZHab_Y_lag_1"]==1,'Decreciente',df["Tendecia_ZHab_Y_lag_1"])
    df["Tendecia_ZHab_Y_lag_1_categorizada"]=np.where(df["Tendecia_ZHab_Y_lag_1"]=='2','Crecreciente',df["Tendecia_ZHab_Y_lag_1"])
    df["Tendecia_ZHab_Y_lag_1_categorizada"]=np.where(df["Tendecia_ZHab_Y_lag_1"]=='3','Constate',df["Tendecia_ZHab_Y_lag_1"])
    del df["Tendecia_ZHab_Y_lag_1"]


    if df.loc[i,"media_movil_Chol_lag_1"]>df.loc[i+1,"media_movil_Chol_lag_1"]:
        df.loc[i,"Tendecia_Chol_lag_1"]=1
    else:
        if df.loc[i,"Chol_lag_1"]<df.loc[i+1,"Chol_lag_1"]:
            df.loc[i,"Tendecia_Chol_lag_1"]=2
        else:
            df.loc[i,"Tendecia_Chol_lag_1"]=3

    df["Tendecia_Chol_lag_1_categorizada"]=np.where(df["Tendecia_Chol_lag_1"]==1,'Decreciente',df["Tendecia_Chol_lag_1"])
    df["Tendecia_Chol_lag_1_categorizada"]=np.where(df["Tendecia_Chol_lag_1"]=='2','Crecreciente',df["Tendecia_Chol_lag_1"])
    df["Tendecia_Chol_lag_1_categorizada"]=np.where(df["Tendecia_Chol_lag_1"]=='3','Constate',df["Tendecia_Chol_lag_1"])
    del df["Tendecia_Chol_lag_1"]


    if df.loc[i,"media_movil_Thalach_lag_1"]>df.loc[i+1,"media_movil_Thalach_lag_1"]:
        df.loc[i,"Tendecia_Thalach_lag_1"]=1
    else:
        if df.loc[i,"Thalach_lag_1"]<df.loc[i+1,"Thalach_lag_1"]:
            df.loc[i,"Tendecia_Thalach_lag_1"]=2
        else:
            df.loc[i,"Tendecia_Thalach_lag_1"]=3

    df["Tendecia_Thalach_lag_1_categorizada"]=np.where(df["Tendecia_Thalach_lag_1"]==1,'Decreciente',df["Tendecia_Thalach_lag_1"])
    df["Tendecia_Thalach_lag_1_categorizada"]=np.where(df["Tendecia_Thalach_lag_1"]=='2','Crecreciente',df["Tendecia_Thalach_lag_1"])
    df["Tendecia_Thalach_lag_1_categorizada"]=np.where(df["Tendecia_Thalach_lag_1"]=='3','Constate',df["Tendecia_Thalach_lag_1"])
    del df["Tendecia_Thalach_lag_1"]


    if df.loc[i,"media_movil_Trestbps_lag_1"]>df.loc[i+1,"media_movil_Trestbps_lag_1"]:
        df.loc[i,"Tendecia_Trestbps_lag_1"]=1
    else:
        if df.loc[i,"Trestbps_lag_1"]<df.loc[i+1,"Trestbps_lag_1"]:
            df.loc[i,"Tendecia_Trestbps_lag_1"]=2
        else:
            df.loc[i,"Tendecia_Trestbps_lag_1"]=3

    df["Tendecia_Trestbps_lag_1_categorizada"]=np.where(df["Tendecia_Trestbps_lag_1"]==1,'Decreciente',df["Tendecia_Trestbps_lag_1"])
    df["Tendecia_Trestbps_lag_1_categorizada"]=np.where(df["Tendecia_Trestbps_lag_1"]=='2','Crecreciente',df["Tendecia_Trestbps_lag_1"])
    df["Tendecia_Trestbps_lag_1_categorizada"]=np.where(df["Tendecia_Trestbps_lag_1"]=='3','Constate',df["Tendecia_Trestbps_lag_1"])
    del df["Tendecia_Trestbps_lag_1"]


    if df.loc[i,"media_movil_Eccentricity_lag_1"]>df.loc[i+1,"media_movil_Eccentricity_lag_1"]:
        df.loc[i,"Tendecia_Eccentricity_lag_1"]=1
    else:
        if df.loc[i,"Eccentricity_lag_1"]<df.loc[i+1,"Eccentricity_lag_1"]:
            df.loc[i,"Tendecia_Eccentricity_lag_1"]=2
        else:
            df.loc[i,"Tendecia_Eccentricity_lag_1"]=3

    df["Tendecia_Eccentricity_lag_1_categorizada"]=np.where(df["Tendecia_Eccentricity_lag_1"]==1,'Decreciente',df["Tendecia_Eccentricity_lag_1"])
    df["Tendecia_Eccentricity_lag_1_categorizada"]=np.where(df["Tendecia_Eccentricity_lag_1"]=='2','Crecreciente',df["Tendecia_Eccentricity_lag_1"])
    df["Tendecia_Eccentricity_lag_1_categorizada"]=np.where(df["Tendecia_Eccentricity_lag_1"]=='3','Constate',df["Tendecia_Eccentricity_lag_1"])
    del df["Tendecia_Eccentricity_lag_1"]


    if df.loc[i,"media_movil_TV_Peso_1"]>df.loc[i+1,"media_movil_TV_Peso_1"]:
        df.loc[i,"Tendecia_TV_Peso_1"]=1
    else:
        if df.loc[i,"TV_Peso_1"]<df.loc[i+1,"TV_Peso_1"]:
            df.loc[i,"Tendecia_TV_Peso_1"]=2
        else:
            df.loc[i,"Tendecia_TV_Peso_1"]=3

    df["Tendecia_TV_Peso_1_categorizada"]=np.where(df["Tendecia_TV_Peso_1"]==1,'Decreciente',df["Tendecia_TV_Peso_1"])
    df["Tendecia_TV_Peso_1_categorizada"]=np.where(df["Tendecia_TV_Peso_1"]=='2','Crecreciente',df["Tendecia_TV_Peso_1"])
    df["Tendecia_TV_Peso_1_categorizada"]=np.where(df["Tendecia_TV_Peso_1"]=='3','Constate',df["Tendecia_TV_Peso_1"])
    del df["Tendecia_TV_Peso_1"]


    if df.loc[i,"media_movil_TV_Altura_1"]>df.loc[i+1,"media_movil_TV_Altura_1"]:
        df.loc[i,"Tendecia_TV_Altura_1"]=1
    else:
        if df.loc[i,"TV_Altura_1"]<df.loc[i+1,"TV_Altura_1"]:
            df.loc[i,"Tendecia_TV_Altura_1"]=2
        else:
            df.loc[i,"Tendecia_TV_Altura_1"]=3

    df["Tendecia_TV_Altura_1_categorizada"]=np.where(df["Tendecia_TV_Altura_1"]==1,'Decreciente',df["Tendecia_TV_Altura_1"])
    df["Tendecia_TV_Altura_1_categorizada"]=np.where(df["Tendecia_TV_Altura_1"]=='2','Crecreciente',df["Tendecia_TV_Altura_1"])
    df["Tendecia_TV_Altura_1_categorizada"]=np.where(df["Tendecia_TV_Altura_1"]=='3','Constate',df["Tendecia_TV_Altura_1"])
    del df["Tendecia_TV_Altura_1"]


    if df.loc[i,"media_movil_TV_Coste_1"]>df.loc[i+1,"media_movil_TV_Coste_1"]:
        df.loc[i,"Tendecia_TV_Coste_1"]=1
    else:
        if df.loc[i,"TV_Coste_1"]<df.loc[i+1,"TV_Coste_1"]:
            df.loc[i,"Tendecia_TV_Coste_1"]=2
        else:
            df.loc[i,"Tendecia_TV_Coste_1"]=3

    df["Tendecia_TV_Coste_1_categorizada"]=np.where(df["Tendecia_TV_Coste_1"]==1,'Decreciente',df["Tendecia_TV_Coste_1"])
    df["Tendecia_TV_Coste_1_categorizada"]=np.where(df["Tendecia_TV_Coste_1"]=='2','Crecreciente',df["Tendecia_TV_Coste_1"])
    df["Tendecia_TV_Coste_1_categorizada"]=np.where(df["Tendecia_TV_Coste_1"]=='3','Constate',df["Tendecia_TV_Coste_1"])
    del df["Tendecia_TV_Coste_1"]


    if df.loc[i,"media_movil_TV_Beneficio_1"]>df.loc[i+1,"media_movil_TV_Beneficio_1"]:
        df.loc[i,"Tendecia_TV_Beneficio_1"]=1
    else:
        if df.loc[i,"TV_Beneficio_1"]<df.loc[i+1,"TV_Beneficio_1"]:
            df.loc[i,"Tendecia_TV_Beneficio_1"]=2
        else:
            df.loc[i,"Tendecia_TV_Beneficio_1"]=3

    df["Tendecia_TV_Beneficio_1_categorizada"]=np.where(df["Tendecia_TV_Beneficio_1"]==1,'Decreciente',df["Tendecia_TV_Beneficio_1"])
    df["Tendecia_TV_Beneficio_1_categorizada"]=np.where(df["Tendecia_TV_Beneficio_1"]=='2','Crecreciente',df["Tendecia_TV_Beneficio_1"])
    df["Tendecia_TV_Beneficio_1_categorizada"]=np.where(df["Tendecia_TV_Beneficio_1"]=='3','Constate',df["Tendecia_TV_Beneficio_1"])
    del df["Tendecia_TV_Beneficio_1"]


    if df.loc[i,"media_movil_TV_Base_X_1"]>df.loc[i+1,"media_movil_TV_Base_X_1"]:
        df.loc[i,"Tendecia_TV_Base_X_1"]=1
    else:
        if df.loc[i,"TV_Base_X_1"]<df.loc[i+1,"TV_Base_X_1"]:
            df.loc[i,"Tendecia_TV_Base_X_1"]=2
        else:
            df.loc[i,"Tendecia_TV_Base_X_1"]=3

    df["Tendecia_TV_Base_X_1_categorizada"]=np.where(df["Tendecia_TV_Base_X_1"]==1,'Decreciente',df["Tendecia_TV_Base_X_1"])
    df["Tendecia_TV_Base_X_1_categorizada"]=np.where(df["Tendecia_TV_Base_X_1"]=='2','Crecreciente',df["Tendecia_TV_Base_X_1"])
    df["Tendecia_TV_Base_X_1_categorizada"]=np.where(df["Tendecia_TV_Base_X_1"]=='3','Constate',df["Tendecia_TV_Base_X_1"])
    del df["Tendecia_TV_Base_X_1"]


    if df.loc[i,"media_movil_TV_Base_Y_1"]>df.loc[i+1,"media_movil_TV_Base_Y_1"]:
        df.loc[i,"Tendecia_TV_Base_Y_1"]=1
    else:
        if df.loc[i,"TV_Base_Y_1"]<df.loc[i+1,"TV_Base_Y_1"]:
            df.loc[i,"Tendecia_TV_Base_Y_1"]=2
        else:
            df.loc[i,"Tendecia_TV_Base_Y_1"]=3

    df["Tendecia_TV_Base_Y_1_categorizada"]=np.where(df["Tendecia_TV_Base_Y_1"]==1,'Decreciente',df["Tendecia_TV_Base_Y_1"])
    df["Tendecia_TV_Base_Y_1_categorizada"]=np.where(df["Tendecia_TV_Base_Y_1"]=='2','Crecreciente',df["Tendecia_TV_Base_Y_1"])
    df["Tendecia_TV_Base_Y_1_categorizada"]=np.where(df["Tendecia_TV_Base_Y_1"]=='3','Constate',df["Tendecia_TV_Base_Y_1"])
    del df["Tendecia_TV_Base_Y_1"]


    if df.loc[i,"media_movil_TV_CRM_1"]>df.loc[i+1,"media_movil_TV_CRM_1"]:
        df.loc[i,"Tendecia_TV_CRM_1"]=1
    else:
        if df.loc[i,"TV_CRM_1"]<df.loc[i+1,"TV_CRM_1"]:
            df.loc[i,"Tendecia_TV_CRM_1"]=2
        else:
            df.loc[i,"Tendecia_TV_CRM_1"]=3

    df["Tendecia_TV_CRM_1_categorizada"]=np.where(df["Tendecia_TV_CRM_1"]==1,'Decreciente',df["Tendecia_TV_CRM_1"])
    df["Tendecia_TV_CRM_1_categorizada"]=np.where(df["Tendecia_TV_CRM_1"]=='2','Crecreciente',df["Tendecia_TV_CRM_1"])
    df["Tendecia_TV_CRM_1_categorizada"]=np.where(df["Tendecia_TV_CRM_1"]=='3','Constate',df["Tendecia_TV_CRM_1"])
    del df["Tendecia_TV_CRM_1"]


    if df.loc[i,"media_movil_TV_ZHab_X_1"]>df.loc[i+1,"media_movil_TV_ZHab_X_1"]:
        df.loc[i,"Tendecia_TV_ZHab_X_1"]=1
    else:
        if df.loc[i,"TV_ZHab_X_1"]<df.loc[i+1,"TV_ZHab_X_1"]:
            df.loc[i,"Tendecia_TV_ZHab_X_1"]=2
        else:
            df.loc[i,"Tendecia_TV_ZHab_X_1"]=3

    df["Tendecia_TV_ZHab_X_1_categorizada"]=np.where(df["Tendecia_TV_ZHab_X_1"]==1,'Decreciente',df["Tendecia_TV_ZHab_X_1"])
    df["Tendecia_TV_ZHab_X_1_categorizada"]=np.where(df["Tendecia_TV_ZHab_X_1"]=='2','Crecreciente',df["Tendecia_TV_ZHab_X_1"])
    df["Tendecia_TV_ZHab_X_1_categorizada"]=np.where(df["Tendecia_TV_ZHab_X_1"]=='3','Constate',df["Tendecia_TV_ZHab_X_1"])
    del df["Tendecia_TV_ZHab_X_1"]


    if df.loc[i,"media_movil_TV_ZHab_Y_1"]>df.loc[i+1,"media_movil_TV_ZHab_Y_1"]:
        df.loc[i,"Tendecia_TV_ZHab_Y_1"]=1
    else:
        if df.loc[i,"TV_ZHab_Y_1"]<df.loc[i+1,"TV_ZHab_Y_1"]:
            df.loc[i,"Tendecia_TV_ZHab_Y_1"]=2
        else:
            df.loc[i,"Tendecia_TV_ZHab_Y_1"]=3

    df["Tendecia_TV_ZHab_Y_1_categorizada"]=np.where(df["Tendecia_TV_ZHab_Y_1"]==1,'Decreciente',df["Tendecia_TV_ZHab_Y_1"])
    df["Tendecia_TV_ZHab_Y_1_categorizada"]=np.where(df["Tendecia_TV_ZHab_Y_1"]=='2','Crecreciente',df["Tendecia_TV_ZHab_Y_1"])
    df["Tendecia_TV_ZHab_Y_1_categorizada"]=np.where(df["Tendecia_TV_ZHab_Y_1"]=='3','Constate',df["Tendecia_TV_ZHab_Y_1"])
    del df["Tendecia_TV_ZHab_Y_1"]


    if df.loc[i,"media_movil_TV_Chol_1"]>df.loc[i+1,"media_movil_TV_Chol_1"]:
        df.loc[i,"Tendecia_TV_Chol_1"]=1
    else:
        if df.loc[i,"TV_Chol_1"]<df.loc[i+1,"TV_Chol_1"]:
            df.loc[i,"Tendecia_TV_Chol_1"]=2
        else:
            df.loc[i,"Tendecia_TV_Chol_1"]=3

    df["Tendecia_TV_Chol_1_categorizada"]=np.where(df["Tendecia_TV_Chol_1"]==1,'Decreciente',df["Tendecia_TV_Chol_1"])
    df["Tendecia_TV_Chol_1_categorizada"]=np.where(df["Tendecia_TV_Chol_1"]=='2','Crecreciente',df["Tendecia_TV_Chol_1"])
    df["Tendecia_TV_Chol_1_categorizada"]=np.where(df["Tendecia_TV_Chol_1"]=='3','Constate',df["Tendecia_TV_Chol_1"])
    del df["Tendecia_TV_Chol_1"]


    if df.loc[i,"media_movil_TV_Thalach_1"]>df.loc[i+1,"media_movil_TV_Thalach_1"]:
        df.loc[i,"Tendecia_TV_Thalach_1"]=1
    else:
        if df.loc[i,"TV_Thalach_1"]<df.loc[i+1,"TV_Thalach_1"]:
            df.loc[i,"Tendecia_TV_Thalach_1"]=2
        else:
            df.loc[i,"Tendecia_TV_Thalach_1"]=3

    df["Tendecia_TV_Thalach_1_categorizada"]=np.where(df["Tendecia_TV_Thalach_1"]==1,'Decreciente',df["Tendecia_TV_Thalach_1"])
    df["Tendecia_TV_Thalach_1_categorizada"]=np.where(df["Tendecia_TV_Thalach_1"]=='2','Crecreciente',df["Tendecia_TV_Thalach_1"])
    df["Tendecia_TV_Thalach_1_categorizada"]=np.where(df["Tendecia_TV_Thalach_1"]=='3','Constate',df["Tendecia_TV_Thalach_1"])
    del df["Tendecia_TV_Thalach_1"]


    if df.loc[i,"media_movil_TV_Trestbps_1"]>df.loc[i+1,"media_movil_TV_Trestbps_1"]:
        df.loc[i,"Tendecia_TV_Trestbps_1"]=1
    else:
        if df.loc[i,"TV_Trestbps_1"]<df.loc[i+1,"TV_Trestbps_1"]:
            df.loc[i,"Tendecia_TV_Trestbps_1"]=2
        else:
            df.loc[i,"Tendecia_TV_Trestbps_1"]=3

    df["Tendecia_TV_Trestbps_1_categorizada"]=np.where(df["Tendecia_TV_Trestbps_1"]==1,'Decreciente',df["Tendecia_TV_Trestbps_1"])
    df["Tendecia_TV_Trestbps_1_categorizada"]=np.where(df["Tendecia_TV_Trestbps_1"]=='2','Crecreciente',df["Tendecia_TV_Trestbps_1"])
    df["Tendecia_TV_Trestbps_1_categorizada"]=np.where(df["Tendecia_TV_Trestbps_1"]=='3','Constate',df["Tendecia_TV_Trestbps_1"])
    del df["Tendecia_TV_Trestbps_1"]


    if df.loc[i,"media_movil_TV_Eccentricity_1"]>df.loc[i+1,"media_movil_TV_Eccentricity_1"]:
        df.loc[i,"Tendecia_TV_Eccentricity_1"]=1
    else:
        if df.loc[i,"TV_Eccentricity_1"]<df.loc[i+1,"TV_Eccentricity_1"]:
            df.loc[i,"Tendecia_TV_Eccentricity_1"]=2
        else:
            df.loc[i,"Tendecia_TV_Eccentricity_1"]=3

    df["Tendecia_TV_Eccentricity_1_categorizada"]=np.where(df["Tendecia_TV_Eccentricity_1"]==1,'Decreciente',df["Tendecia_TV_Eccentricity_1"])
    df["Tendecia_TV_Eccentricity_1_categorizada"]=np.where(df["Tendecia_TV_Eccentricity_1"]=='2','Crecreciente',df["Tendecia_TV_Eccentricity_1"])
    df["Tendecia_TV_Eccentricity_1_categorizada"]=np.where(df["Tendecia_TV_Eccentricity_1"]=='3','Constate',df["Tendecia_TV_Eccentricity_1"])
    del df["Tendecia_TV_Eccentricity_1"]


    if df.loc[i,"media_movil_Peso_lag_2"]>df.loc[i+1,"media_movil_Peso_lag_2"]:
        df.loc[i,"Tendecia_Peso_lag_2"]=1
    else:
        if df.loc[i,"Peso_lag_2"]<df.loc[i+1,"Peso_lag_2"]:
            df.loc[i,"Tendecia_Peso_lag_2"]=2
        else:
            df.loc[i,"Tendecia_Peso_lag_2"]=3

    df["Tendecia_Peso_lag_2_categorizada"]=np.where(df["Tendecia_Peso_lag_2"]==1,'Decreciente',df["Tendecia_Peso_lag_2"])
    df["Tendecia_Peso_lag_2_categorizada"]=np.where(df["Tendecia_Peso_lag_2"]=='2','Crecreciente',df["Tendecia_Peso_lag_2"])
    df["Tendecia_Peso_lag_2_categorizada"]=np.where(df["Tendecia_Peso_lag_2"]=='3','Constate',df["Tendecia_Peso_lag_2"])
    del df["Tendecia_Peso_lag_2"]


    if df.loc[i,"media_movil_Altura_lag_2"]>df.loc[i+1,"media_movil_Altura_lag_2"]:
        df.loc[i,"Tendecia_Altura_lag_2"]=1
    else:
        if df.loc[i,"Altura_lag_2"]<df.loc[i+1,"Altura_lag_2"]:
            df.loc[i,"Tendecia_Altura_lag_2"]=2
        else:
            df.loc[i,"Tendecia_Altura_lag_2"]=3

    df["Tendecia_Altura_lag_2_categorizada"]=np.where(df["Tendecia_Altura_lag_2"]==1,'Decreciente',df["Tendecia_Altura_lag_2"])
    df["Tendecia_Altura_lag_2_categorizada"]=np.where(df["Tendecia_Altura_lag_2"]=='2','Crecreciente',df["Tendecia_Altura_lag_2"])
    df["Tendecia_Altura_lag_2_categorizada"]=np.where(df["Tendecia_Altura_lag_2"]=='3','Constate',df["Tendecia_Altura_lag_2"])
    del df["Tendecia_Altura_lag_2"]


    if df.loc[i,"media_movil_Coste_lag_2"]>df.loc[i+1,"media_movil_Coste_lag_2"]:
        df.loc[i,"Tendecia_Coste_lag_2"]=1
    else:
        if df.loc[i,"Coste_lag_2"]<df.loc[i+1,"Coste_lag_2"]:
            df.loc[i,"Tendecia_Coste_lag_2"]=2
        else:
            df.loc[i,"Tendecia_Coste_lag_2"]=3

    df["Tendecia_Coste_lag_2_categorizada"]=np.where(df["Tendecia_Coste_lag_2"]==1,'Decreciente',df["Tendecia_Coste_lag_2"])
    df["Tendecia_Coste_lag_2_categorizada"]=np.where(df["Tendecia_Coste_lag_2"]=='2','Crecreciente',df["Tendecia_Coste_lag_2"])
    df["Tendecia_Coste_lag_2_categorizada"]=np.where(df["Tendecia_Coste_lag_2"]=='3','Constate',df["Tendecia_Coste_lag_2"])
    del df["Tendecia_Coste_lag_2"]


    if df.loc[i,"media_movil_Beneficio_lag_2"]>df.loc[i+1,"media_movil_Beneficio_lag_2"]:
        df.loc[i,"Tendecia_Beneficio_lag_2"]=1
    else:
        if df.loc[i,"Beneficio_lag_2"]<df.loc[i+1,"Beneficio_lag_2"]:
            df.loc[i,"Tendecia_Beneficio_lag_2"]=2
        else:
            df.loc[i,"Tendecia_Beneficio_lag_2"]=3

    df["Tendecia_Beneficio_lag_2_categorizada"]=np.where(df["Tendecia_Beneficio_lag_2"]==1,'Decreciente',df["Tendecia_Beneficio_lag_2"])
    df["Tendecia_Beneficio_lag_2_categorizada"]=np.where(df["Tendecia_Beneficio_lag_2"]=='2','Crecreciente',df["Tendecia_Beneficio_lag_2"])
    df["Tendecia_Beneficio_lag_2_categorizada"]=np.where(df["Tendecia_Beneficio_lag_2"]=='3','Constate',df["Tendecia_Beneficio_lag_2"])
    del df["Tendecia_Beneficio_lag_2"]


    if df.loc[i,"media_movil_Base_X_lag_2"]>df.loc[i+1,"media_movil_Base_X_lag_2"]:
        df.loc[i,"Tendecia_Base_X_lag_2"]=1
    else:
        if df.loc[i,"Base_X_lag_2"]<df.loc[i+1,"Base_X_lag_2"]:
            df.loc[i,"Tendecia_Base_X_lag_2"]=2
        else:
            df.loc[i,"Tendecia_Base_X_lag_2"]=3

    df["Tendecia_Base_X_lag_2_categorizada"]=np.where(df["Tendecia_Base_X_lag_2"]==1,'Decreciente',df["Tendecia_Base_X_lag_2"])
    df["Tendecia_Base_X_lag_2_categorizada"]=np.where(df["Tendecia_Base_X_lag_2"]=='2','Crecreciente',df["Tendecia_Base_X_lag_2"])
    df["Tendecia_Base_X_lag_2_categorizada"]=np.where(df["Tendecia_Base_X_lag_2"]=='3','Constate',df["Tendecia_Base_X_lag_2"])
    del df["Tendecia_Base_X_lag_2"]


    if df.loc[i,"media_movil_Base_Y_lag_2"]>df.loc[i+1,"media_movil_Base_Y_lag_2"]:
        df.loc[i,"Tendecia_Base_Y_lag_2"]=1
    else:
        if df.loc[i,"Base_Y_lag_2"]<df.loc[i+1,"Base_Y_lag_2"]:
            df.loc[i,"Tendecia_Base_Y_lag_2"]=2
        else:
            df.loc[i,"Tendecia_Base_Y_lag_2"]=3

    df["Tendecia_Base_Y_lag_2_categorizada"]=np.where(df["Tendecia_Base_Y_lag_2"]==1,'Decreciente',df["Tendecia_Base_Y_lag_2"])
    df["Tendecia_Base_Y_lag_2_categorizada"]=np.where(df["Tendecia_Base_Y_lag_2"]=='2','Crecreciente',df["Tendecia_Base_Y_lag_2"])
    df["Tendecia_Base_Y_lag_2_categorizada"]=np.where(df["Tendecia_Base_Y_lag_2"]=='3','Constate',df["Tendecia_Base_Y_lag_2"])
    del df["Tendecia_Base_Y_lag_2"]


    if df.loc[i,"media_movil_CRM_lag_2"]>df.loc[i+1,"media_movil_CRM_lag_2"]:
        df.loc[i,"Tendecia_CRM_lag_2"]=1
    else:
        if df.loc[i,"CRM_lag_2"]<df.loc[i+1,"CRM_lag_2"]:
            df.loc[i,"Tendecia_CRM_lag_2"]=2
        else:
            df.loc[i,"Tendecia_CRM_lag_2"]=3

    df["Tendecia_CRM_lag_2_categorizada"]=np.where(df["Tendecia_CRM_lag_2"]==1,'Decreciente',df["Tendecia_CRM_lag_2"])
    df["Tendecia_CRM_lag_2_categorizada"]=np.where(df["Tendecia_CRM_lag_2"]=='2','Crecreciente',df["Tendecia_CRM_lag_2"])
    df["Tendecia_CRM_lag_2_categorizada"]=np.where(df["Tendecia_CRM_lag_2"]=='3','Constate',df["Tendecia_CRM_lag_2"])
    del df["Tendecia_CRM_lag_2"]


    if df.loc[i,"media_movil_ZHab_X_lag_2"]>df.loc[i+1,"media_movil_ZHab_X_lag_2"]:
        df.loc[i,"Tendecia_ZHab_X_lag_2"]=1
    else:
        if df.loc[i,"ZHab_X_lag_2"]<df.loc[i+1,"ZHab_X_lag_2"]:
            df.loc[i,"Tendecia_ZHab_X_lag_2"]=2
        else:
            df.loc[i,"Tendecia_ZHab_X_lag_2"]=3

    df["Tendecia_ZHab_X_lag_2_categorizada"]=np.where(df["Tendecia_ZHab_X_lag_2"]==1,'Decreciente',df["Tendecia_ZHab_X_lag_2"])
    df["Tendecia_ZHab_X_lag_2_categorizada"]=np.where(df["Tendecia_ZHab_X_lag_2"]=='2','Crecreciente',df["Tendecia_ZHab_X_lag_2"])
    df["Tendecia_ZHab_X_lag_2_categorizada"]=np.where(df["Tendecia_ZHab_X_lag_2"]=='3','Constate',df["Tendecia_ZHab_X_lag_2"])
    del df["Tendecia_ZHab_X_lag_2"]


    if df.loc[i,"media_movil_ZHab_Y_lag_2"]>df.loc[i+1,"media_movil_ZHab_Y_lag_2"]:
        df.loc[i,"Tendecia_ZHab_Y_lag_2"]=1
    else:
        if df.loc[i,"ZHab_Y_lag_2"]<df.loc[i+1,"ZHab_Y_lag_2"]:
            df.loc[i,"Tendecia_ZHab_Y_lag_2"]=2
        else:
            df.loc[i,"Tendecia_ZHab_Y_lag_2"]=3

    df["Tendecia_ZHab_Y_lag_2_categorizada"]=np.where(df["Tendecia_ZHab_Y_lag_2"]==1,'Decreciente',df["Tendecia_ZHab_Y_lag_2"])
    df["Tendecia_ZHab_Y_lag_2_categorizada"]=np.where(df["Tendecia_ZHab_Y_lag_2"]=='2','Crecreciente',df["Tendecia_ZHab_Y_lag_2"])
    df["Tendecia_ZHab_Y_lag_2_categorizada"]=np.where(df["Tendecia_ZHab_Y_lag_2"]=='3','Constate',df["Tendecia_ZHab_Y_lag_2"])
    del df["Tendecia_ZHab_Y_lag_2"]


    if df.loc[i,"media_movil_Chol_lag_2"]>df.loc[i+1,"media_movil_Chol_lag_2"]:
        df.loc[i,"Tendecia_Chol_lag_2"]=1
    else:
        if df.loc[i,"Chol_lag_2"]<df.loc[i+1,"Chol_lag_2"]:
            df.loc[i,"Tendecia_Chol_lag_2"]=2
        else:
            df.loc[i,"Tendecia_Chol_lag_2"]=3

    df["Tendecia_Chol_lag_2_categorizada"]=np.where(df["Tendecia_Chol_lag_2"]==1,'Decreciente',df["Tendecia_Chol_lag_2"])
    df["Tendecia_Chol_lag_2_categorizada"]=np.where(df["Tendecia_Chol_lag_2"]=='2','Crecreciente',df["Tendecia_Chol_lag_2"])
    df["Tendecia_Chol_lag_2_categorizada"]=np.where(df["Tendecia_Chol_lag_2"]=='3','Constate',df["Tendecia_Chol_lag_2"])
    del df["Tendecia_Chol_lag_2"]


    if df.loc[i,"media_movil_Thalach_lag_2"]>df.loc[i+1,"media_movil_Thalach_lag_2"]:
        df.loc[i,"Tendecia_Thalach_lag_2"]=1
    else:
        if df.loc[i,"Thalach_lag_2"]<df.loc[i+1,"Thalach_lag_2"]:
            df.loc[i,"Tendecia_Thalach_lag_2"]=2
        else:
            df.loc[i,"Tendecia_Thalach_lag_2"]=3

    df["Tendecia_Thalach_lag_2_categorizada"]=np.where(df["Tendecia_Thalach_lag_2"]==1,'Decreciente',df["Tendecia_Thalach_lag_2"])
    df["Tendecia_Thalach_lag_2_categorizada"]=np.where(df["Tendecia_Thalach_lag_2"]=='2','Crecreciente',df["Tendecia_Thalach_lag_2"])
    df["Tendecia_Thalach_lag_2_categorizada"]=np.where(df["Tendecia_Thalach_lag_2"]=='3','Constate',df["Tendecia_Thalach_lag_2"])
    del df["Tendecia_Thalach_lag_2"]


    if df.loc[i,"media_movil_Trestbps_lag_2"]>df.loc[i+1,"media_movil_Trestbps_lag_2"]:
        df.loc[i,"Tendecia_Trestbps_lag_2"]=1
    else:
        if df.loc[i,"Trestbps_lag_2"]<df.loc[i+1,"Trestbps_lag_2"]:
            df.loc[i,"Tendecia_Trestbps_lag_2"]=2
        else:
            df.loc[i,"Tendecia_Trestbps_lag_2"]=3

    df["Tendecia_Trestbps_lag_2_categorizada"]=np.where(df["Tendecia_Trestbps_lag_2"]==1,'Decreciente',df["Tendecia_Trestbps_lag_2"])
    df["Tendecia_Trestbps_lag_2_categorizada"]=np.where(df["Tendecia_Trestbps_lag_2"]=='2','Crecreciente',df["Tendecia_Trestbps_lag_2"])
    df["Tendecia_Trestbps_lag_2_categorizada"]=np.where(df["Tendecia_Trestbps_lag_2"]=='3','Constate',df["Tendecia_Trestbps_lag_2"])
    del df["Tendecia_Trestbps_lag_2"]


    if df.loc[i,"media_movil_Eccentricity_lag_2"]>df.loc[i+1,"media_movil_Eccentricity_lag_2"]:
        df.loc[i,"Tendecia_Eccentricity_lag_2"]=1
    else:
        if df.loc[i,"Eccentricity_lag_2"]<df.loc[i+1,"Eccentricity_lag_2"]:
            df.loc[i,"Tendecia_Eccentricity_lag_2"]=2
        else:
            df.loc[i,"Tendecia_Eccentricity_lag_2"]=3

    df["Tendecia_Eccentricity_lag_2_categorizada"]=np.where(df["Tendecia_Eccentricity_lag_2"]==1,'Decreciente',df["Tendecia_Eccentricity_lag_2"])
    df["Tendecia_Eccentricity_lag_2_categorizada"]=np.where(df["Tendecia_Eccentricity_lag_2"]=='2','Crecreciente',df["Tendecia_Eccentricity_lag_2"])
    df["Tendecia_Eccentricity_lag_2_categorizada"]=np.where(df["Tendecia_Eccentricity_lag_2"]=='3','Constate',df["Tendecia_Eccentricity_lag_2"])
    del df["Tendecia_Eccentricity_lag_2"]


    if df.loc[i,"media_movil_TV_Peso_2"]>df.loc[i+1,"media_movil_TV_Peso_2"]:
        df.loc[i,"Tendecia_TV_Peso_2"]=1
    else:
        if df.loc[i,"TV_Peso_2"]<df.loc[i+1,"TV_Peso_2"]:
            df.loc[i,"Tendecia_TV_Peso_2"]=2
        else:
            df.loc[i,"Tendecia_TV_Peso_2"]=3

    df["Tendecia_TV_Peso_2_categorizada"]=np.where(df["Tendecia_TV_Peso_2"]==1,'Decreciente',df["Tendecia_TV_Peso_2"])
    df["Tendecia_TV_Peso_2_categorizada"]=np.where(df["Tendecia_TV_Peso_2"]=='2','Crecreciente',df["Tendecia_TV_Peso_2"])
    df["Tendecia_TV_Peso_2_categorizada"]=np.where(df["Tendecia_TV_Peso_2"]=='3','Constate',df["Tendecia_TV_Peso_2"])
    del df["Tendecia_TV_Peso_2"]


    if df.loc[i,"media_movil_TV_Altura_2"]>df.loc[i+1,"media_movil_TV_Altura_2"]:
        df.loc[i,"Tendecia_TV_Altura_2"]=1
    else:
        if df.loc[i,"TV_Altura_2"]<df.loc[i+1,"TV_Altura_2"]:
            df.loc[i,"Tendecia_TV_Altura_2"]=2
        else:
            df.loc[i,"Tendecia_TV_Altura_2"]=3

    df["Tendecia_TV_Altura_2_categorizada"]=np.where(df["Tendecia_TV_Altura_2"]==1,'Decreciente',df["Tendecia_TV_Altura_2"])
    df["Tendecia_TV_Altura_2_categorizada"]=np.where(df["Tendecia_TV_Altura_2"]=='2','Crecreciente',df["Tendecia_TV_Altura_2"])
    df["Tendecia_TV_Altura_2_categorizada"]=np.where(df["Tendecia_TV_Altura_2"]=='3','Constate',df["Tendecia_TV_Altura_2"])
    del df["Tendecia_TV_Altura_2"]


    if df.loc[i,"media_movil_TV_Coste_2"]>df.loc[i+1,"media_movil_TV_Coste_2"]:
        df.loc[i,"Tendecia_TV_Coste_2"]=1
    else:
        if df.loc[i,"TV_Coste_2"]<df.loc[i+1,"TV_Coste_2"]:
            df.loc[i,"Tendecia_TV_Coste_2"]=2
        else:
            df.loc[i,"Tendecia_TV_Coste_2"]=3

    df["Tendecia_TV_Coste_2_categorizada"]=np.where(df["Tendecia_TV_Coste_2"]==1,'Decreciente',df["Tendecia_TV_Coste_2"])
    df["Tendecia_TV_Coste_2_categorizada"]=np.where(df["Tendecia_TV_Coste_2"]=='2','Crecreciente',df["Tendecia_TV_Coste_2"])
    df["Tendecia_TV_Coste_2_categorizada"]=np.where(df["Tendecia_TV_Coste_2"]=='3','Constate',df["Tendecia_TV_Coste_2"])
    del df["Tendecia_TV_Coste_2"]


    if df.loc[i,"media_movil_TV_Beneficio_2"]>df.loc[i+1,"media_movil_TV_Beneficio_2"]:
        df.loc[i,"Tendecia_TV_Beneficio_2"]=1
    else:
        if df.loc[i,"TV_Beneficio_2"]<df.loc[i+1,"TV_Beneficio_2"]:
            df.loc[i,"Tendecia_TV_Beneficio_2"]=2
        else:
            df.loc[i,"Tendecia_TV_Beneficio_2"]=3

    df["Tendecia_TV_Beneficio_2_categorizada"]=np.where(df["Tendecia_TV_Beneficio_2"]==1,'Decreciente',df["Tendecia_TV_Beneficio_2"])
    df["Tendecia_TV_Beneficio_2_categorizada"]=np.where(df["Tendecia_TV_Beneficio_2"]=='2','Crecreciente',df["Tendecia_TV_Beneficio_2"])
    df["Tendecia_TV_Beneficio_2_categorizada"]=np.where(df["Tendecia_TV_Beneficio_2"]=='3','Constate',df["Tendecia_TV_Beneficio_2"])
    del df["Tendecia_TV_Beneficio_2"]


    if df.loc[i,"media_movil_TV_Base_X_2"]>df.loc[i+1,"media_movil_TV_Base_X_2"]:
        df.loc[i,"Tendecia_TV_Base_X_2"]=1
    else:
        if df.loc[i,"TV_Base_X_2"]<df.loc[i+1,"TV_Base_X_2"]:
            df.loc[i,"Tendecia_TV_Base_X_2"]=2
        else:
            df.loc[i,"Tendecia_TV_Base_X_2"]=3

    df["Tendecia_TV_Base_X_2_categorizada"]=np.where(df["Tendecia_TV_Base_X_2"]==1,'Decreciente',df["Tendecia_TV_Base_X_2"])
    df["Tendecia_TV_Base_X_2_categorizada"]=np.where(df["Tendecia_TV_Base_X_2"]=='2','Crecreciente',df["Tendecia_TV_Base_X_2"])
    df["Tendecia_TV_Base_X_2_categorizada"]=np.where(df["Tendecia_TV_Base_X_2"]=='3','Constate',df["Tendecia_TV_Base_X_2"])
    del df["Tendecia_TV_Base_X_2"]


    if df.loc[i,"media_movil_TV_Base_Y_2"]>df.loc[i+1,"media_movil_TV_Base_Y_2"]:
        df.loc[i,"Tendecia_TV_Base_Y_2"]=1
    else:
        if df.loc[i,"TV_Base_Y_2"]<df.loc[i+1,"TV_Base_Y_2"]:
            df.loc[i,"Tendecia_TV_Base_Y_2"]=2
        else:
            df.loc[i,"Tendecia_TV_Base_Y_2"]=3

    df["Tendecia_TV_Base_Y_2_categorizada"]=np.where(df["Tendecia_TV_Base_Y_2"]==1,'Decreciente',df["Tendecia_TV_Base_Y_2"])
    df["Tendecia_TV_Base_Y_2_categorizada"]=np.where(df["Tendecia_TV_Base_Y_2"]=='2','Crecreciente',df["Tendecia_TV_Base_Y_2"])
    df["Tendecia_TV_Base_Y_2_categorizada"]=np.where(df["Tendecia_TV_Base_Y_2"]=='3','Constate',df["Tendecia_TV_Base_Y_2"])
    del df["Tendecia_TV_Base_Y_2"]


    if df.loc[i,"media_movil_TV_CRM_2"]>df.loc[i+1,"media_movil_TV_CRM_2"]:
        df.loc[i,"Tendecia_TV_CRM_2"]=1
    else:
        if df.loc[i,"TV_CRM_2"]<df.loc[i+1,"TV_CRM_2"]:
            df.loc[i,"Tendecia_TV_CRM_2"]=2
        else:
            df.loc[i,"Tendecia_TV_CRM_2"]=3

    df["Tendecia_TV_CRM_2_categorizada"]=np.where(df["Tendecia_TV_CRM_2"]==1,'Decreciente',df["Tendecia_TV_CRM_2"])
    df["Tendecia_TV_CRM_2_categorizada"]=np.where(df["Tendecia_TV_CRM_2"]=='2','Crecreciente',df["Tendecia_TV_CRM_2"])
    df["Tendecia_TV_CRM_2_categorizada"]=np.where(df["Tendecia_TV_CRM_2"]=='3','Constate',df["Tendecia_TV_CRM_2"])
    del df["Tendecia_TV_CRM_2"]


    if df.loc[i,"media_movil_TV_ZHab_X_2"]>df.loc[i+1,"media_movil_TV_ZHab_X_2"]:
        df.loc[i,"Tendecia_TV_ZHab_X_2"]=1
    else:
        if df.loc[i,"TV_ZHab_X_2"]<df.loc[i+1,"TV_ZHab_X_2"]:
            df.loc[i,"Tendecia_TV_ZHab_X_2"]=2
        else:
            df.loc[i,"Tendecia_TV_ZHab_X_2"]=3

    df["Tendecia_TV_ZHab_X_2_categorizada"]=np.where(df["Tendecia_TV_ZHab_X_2"]==1,'Decreciente',df["Tendecia_TV_ZHab_X_2"])
    df["Tendecia_TV_ZHab_X_2_categorizada"]=np.where(df["Tendecia_TV_ZHab_X_2"]=='2','Crecreciente',df["Tendecia_TV_ZHab_X_2"])
    df["Tendecia_TV_ZHab_X_2_categorizada"]=np.where(df["Tendecia_TV_ZHab_X_2"]=='3','Constate',df["Tendecia_TV_ZHab_X_2"])
    del df["Tendecia_TV_ZHab_X_2"]


    if df.loc[i,"media_movil_TV_ZHab_Y_2"]>df.loc[i+1,"media_movil_TV_ZHab_Y_2"]:
        df.loc[i,"Tendecia_TV_ZHab_Y_2"]=1
    else:
        if df.loc[i,"TV_ZHab_Y_2"]<df.loc[i+1,"TV_ZHab_Y_2"]:
            df.loc[i,"Tendecia_TV_ZHab_Y_2"]=2
        else:
            df.loc[i,"Tendecia_TV_ZHab_Y_2"]=3

    df["Tendecia_TV_ZHab_Y_2_categorizada"]=np.where(df["Tendecia_TV_ZHab_Y_2"]==1,'Decreciente',df["Tendecia_TV_ZHab_Y_2"])
    df["Tendecia_TV_ZHab_Y_2_categorizada"]=np.where(df["Tendecia_TV_ZHab_Y_2"]=='2','Crecreciente',df["Tendecia_TV_ZHab_Y_2"])
    df["Tendecia_TV_ZHab_Y_2_categorizada"]=np.where(df["Tendecia_TV_ZHab_Y_2"]=='3','Constate',df["Tendecia_TV_ZHab_Y_2"])
    del df["Tendecia_TV_ZHab_Y_2"]


    if df.loc[i,"media_movil_TV_Chol_2"]>df.loc[i+1,"media_movil_TV_Chol_2"]:
        df.loc[i,"Tendecia_TV_Chol_2"]=1
    else:
        if df.loc[i,"TV_Chol_2"]<df.loc[i+1,"TV_Chol_2"]:
            df.loc[i,"Tendecia_TV_Chol_2"]=2
        else:
            df.loc[i,"Tendecia_TV_Chol_2"]=3

    df["Tendecia_TV_Chol_2_categorizada"]=np.where(df["Tendecia_TV_Chol_2"]==1,'Decreciente',df["Tendecia_TV_Chol_2"])
    df["Tendecia_TV_Chol_2_categorizada"]=np.where(df["Tendecia_TV_Chol_2"]=='2','Crecreciente',df["Tendecia_TV_Chol_2"])
    df["Tendecia_TV_Chol_2_categorizada"]=np.where(df["Tendecia_TV_Chol_2"]=='3','Constate',df["Tendecia_TV_Chol_2"])
    del df["Tendecia_TV_Chol_2"]


    if df.loc[i,"media_movil_TV_Thalach_2"]>df.loc[i+1,"media_movil_TV_Thalach_2"]:
        df.loc[i,"Tendecia_TV_Thalach_2"]=1
    else:
        if df.loc[i,"TV_Thalach_2"]<df.loc[i+1,"TV_Thalach_2"]:
            df.loc[i,"Tendecia_TV_Thalach_2"]=2
        else:
            df.loc[i,"Tendecia_TV_Thalach_2"]=3

    df["Tendecia_TV_Thalach_2_categorizada"]=np.where(df["Tendecia_TV_Thalach_2"]==1,'Decreciente',df["Tendecia_TV_Thalach_2"])
    df["Tendecia_TV_Thalach_2_categorizada"]=np.where(df["Tendecia_TV_Thalach_2"]=='2','Crecreciente',df["Tendecia_TV_Thalach_2"])
    df["Tendecia_TV_Thalach_2_categorizada"]=np.where(df["Tendecia_TV_Thalach_2"]=='3','Constate',df["Tendecia_TV_Thalach_2"])
    del df["Tendecia_TV_Thalach_2"]


    if df.loc[i,"media_movil_TV_Trestbps_2"]>df.loc[i+1,"media_movil_TV_Trestbps_2"]:
        df.loc[i,"Tendecia_TV_Trestbps_2"]=1
    else:
        if df.loc[i,"TV_Trestbps_2"]<df.loc[i+1,"TV_Trestbps_2"]:
            df.loc[i,"Tendecia_TV_Trestbps_2"]=2
        else:
            df.loc[i,"Tendecia_TV_Trestbps_2"]=3

    df["Tendecia_TV_Trestbps_2_categorizada"]=np.where(df["Tendecia_TV_Trestbps_2"]==1,'Decreciente',df["Tendecia_TV_Trestbps_2"])
    df["Tendecia_TV_Trestbps_2_categorizada"]=np.where(df["Tendecia_TV_Trestbps_2"]=='2','Crecreciente',df["Tendecia_TV_Trestbps_2"])
    df["Tendecia_TV_Trestbps_2_categorizada"]=np.where(df["Tendecia_TV_Trestbps_2"]=='3','Constate',df["Tendecia_TV_Trestbps_2"])
    del df["Tendecia_TV_Trestbps_2"]


    if df.loc[i,"media_movil_TV_Eccentricity_2"]>df.loc[i+1,"media_movil_TV_Eccentricity_2"]:
        df.loc[i,"Tendecia_TV_Eccentricity_2"]=1
    else:
        if df.loc[i,"TV_Eccentricity_2"]<df.loc[i+1,"TV_Eccentricity_2"]:
            df.loc[i,"Tendecia_TV_Eccentricity_2"]=2
        else:
            df.loc[i,"Tendecia_TV_Eccentricity_2"]=3

    df["Tendecia_TV_Eccentricity_2_categorizada"]=np.where(df["Tendecia_TV_Eccentricity_2"]==1,'Decreciente',df["Tendecia_TV_Eccentricity_2"])
    df["Tendecia_TV_Eccentricity_2_categorizada"]=np.where(df["Tendecia_TV_Eccentricity_2"]=='2','Crecreciente',df["Tendecia_TV_Eccentricity_2"])
    df["Tendecia_TV_Eccentricity_2_categorizada"]=np.where(df["Tendecia_TV_Eccentricity_2"]=='3','Constate',df["Tendecia_TV_Eccentricity_2"])
    del df["Tendecia_TV_Eccentricity_2"]


    if df.loc[i,"media_movil_media_movil_Peso"]>df.loc[i+1,"media_movil_media_movil_Peso"]:
        df.loc[i,"Tendecia_media_movil_Peso"]=1
    else:
        if df.loc[i,"media_movil_Peso"]<df.loc[i+1,"media_movil_Peso"]:
            df.loc[i,"Tendecia_media_movil_Peso"]=2
        else:
            df.loc[i,"Tendecia_media_movil_Peso"]=3

    df["Tendecia_media_movil_Peso_categorizada"]=np.where(df["Tendecia_media_movil_Peso"]==1,'Decreciente',df["Tendecia_media_movil_Peso"])
    df["Tendecia_media_movil_Peso_categorizada"]=np.where(df["Tendecia_media_movil_Peso"]=='2','Crecreciente',df["Tendecia_media_movil_Peso"])
    df["Tendecia_media_movil_Peso_categorizada"]=np.where(df["Tendecia_media_movil_Peso"]=='3','Constate',df["Tendecia_media_movil_Peso"])
    del df["Tendecia_media_movil_Peso"]


    if df.loc[i,"media_movil_media_movil_Altura"]>df.loc[i+1,"media_movil_media_movil_Altura"]:
        df.loc[i,"Tendecia_media_movil_Altura"]=1
    else:
        if df.loc[i,"media_movil_Altura"]<df.loc[i+1,"media_movil_Altura"]:
            df.loc[i,"Tendecia_media_movil_Altura"]=2
        else:
            df.loc[i,"Tendecia_media_movil_Altura"]=3

    df["Tendecia_media_movil_Altura_categorizada"]=np.where(df["Tendecia_media_movil_Altura"]==1,'Decreciente',df["Tendecia_media_movil_Altura"])
    df["Tendecia_media_movil_Altura_categorizada"]=np.where(df["Tendecia_media_movil_Altura"]=='2','Crecreciente',df["Tendecia_media_movil_Altura"])
    df["Tendecia_media_movil_Altura_categorizada"]=np.where(df["Tendecia_media_movil_Altura"]=='3','Constate',df["Tendecia_media_movil_Altura"])
    del df["Tendecia_media_movil_Altura"]


    if df.loc[i,"media_movil_media_movil_Coste"]>df.loc[i+1,"media_movil_media_movil_Coste"]:
        df.loc[i,"Tendecia_media_movil_Coste"]=1
    else:
        if df.loc[i,"media_movil_Coste"]<df.loc[i+1,"media_movil_Coste"]:
            df.loc[i,"Tendecia_media_movil_Coste"]=2
        else:
            df.loc[i,"Tendecia_media_movil_Coste"]=3

    df["Tendecia_media_movil_Coste_categorizada"]=np.where(df["Tendecia_media_movil_Coste"]==1,'Decreciente',df["Tendecia_media_movil_Coste"])
    df["Tendecia_media_movil_Coste_categorizada"]=np.where(df["Tendecia_media_movil_Coste"]=='2','Crecreciente',df["Tendecia_media_movil_Coste"])
    df["Tendecia_media_movil_Coste_categorizada"]=np.where(df["Tendecia_media_movil_Coste"]=='3','Constate',df["Tendecia_media_movil_Coste"])
    del df["Tendecia_media_movil_Coste"]


    if df.loc[i,"media_movil_media_movil_Beneficio"]>df.loc[i+1,"media_movil_media_movil_Beneficio"]:
        df.loc[i,"Tendecia_media_movil_Beneficio"]=1
    else:
        if df.loc[i,"media_movil_Beneficio"]<df.loc[i+1,"media_movil_Beneficio"]:
            df.loc[i,"Tendecia_media_movil_Beneficio"]=2
        else:
            df.loc[i,"Tendecia_media_movil_Beneficio"]=3

    df["Tendecia_media_movil_Beneficio_categorizada"]=np.where(df["Tendecia_media_movil_Beneficio"]==1,'Decreciente',df["Tendecia_media_movil_Beneficio"])
    df["Tendecia_media_movil_Beneficio_categorizada"]=np.where(df["Tendecia_media_movil_Beneficio"]=='2','Crecreciente',df["Tendecia_media_movil_Beneficio"])
    df["Tendecia_media_movil_Beneficio_categorizada"]=np.where(df["Tendecia_media_movil_Beneficio"]=='3','Constate',df["Tendecia_media_movil_Beneficio"])
    del df["Tendecia_media_movil_Beneficio"]


    if df.loc[i,"media_movil_media_movil_Base_X"]>df.loc[i+1,"media_movil_media_movil_Base_X"]:
        df.loc[i,"Tendecia_media_movil_Base_X"]=1
    else:
        if df.loc[i,"media_movil_Base_X"]<df.loc[i+1,"media_movil_Base_X"]:
            df.loc[i,"Tendecia_media_movil_Base_X"]=2
        else:
            df.loc[i,"Tendecia_media_movil_Base_X"]=3

    df["Tendecia_media_movil_Base_X_categorizada"]=np.where(df["Tendecia_media_movil_Base_X"]==1,'Decreciente',df["Tendecia_media_movil_Base_X"])
    df["Tendecia_media_movil_Base_X_categorizada"]=np.where(df["Tendecia_media_movil_Base_X"]=='2','Crecreciente',df["Tendecia_media_movil_Base_X"])
    df["Tendecia_media_movil_Base_X_categorizada"]=np.where(df["Tendecia_media_movil_Base_X"]=='3','Constate',df["Tendecia_media_movil_Base_X"])
    del df["Tendecia_media_movil_Base_X"]


    if df.loc[i,"media_movil_media_movil_Base_Y"]>df.loc[i+1,"media_movil_media_movil_Base_Y"]:
        df.loc[i,"Tendecia_media_movil_Base_Y"]=1
    else:
        if df.loc[i,"media_movil_Base_Y"]<df.loc[i+1,"media_movil_Base_Y"]:
            df.loc[i,"Tendecia_media_movil_Base_Y"]=2
        else:
            df.loc[i,"Tendecia_media_movil_Base_Y"]=3

    df["Tendecia_media_movil_Base_Y_categorizada"]=np.where(df["Tendecia_media_movil_Base_Y"]==1,'Decreciente',df["Tendecia_media_movil_Base_Y"])
    df["Tendecia_media_movil_Base_Y_categorizada"]=np.where(df["Tendecia_media_movil_Base_Y"]=='2','Crecreciente',df["Tendecia_media_movil_Base_Y"])
    df["Tendecia_media_movil_Base_Y_categorizada"]=np.where(df["Tendecia_media_movil_Base_Y"]=='3','Constate',df["Tendecia_media_movil_Base_Y"])
    del df["Tendecia_media_movil_Base_Y"]


    if df.loc[i,"media_movil_media_movil_CRM"]>df.loc[i+1,"media_movil_media_movil_CRM"]:
        df.loc[i,"Tendecia_media_movil_CRM"]=1
    else:
        if df.loc[i,"media_movil_CRM"]<df.loc[i+1,"media_movil_CRM"]:
            df.loc[i,"Tendecia_media_movil_CRM"]=2
        else:
            df.loc[i,"Tendecia_media_movil_CRM"]=3

    df["Tendecia_media_movil_CRM_categorizada"]=np.where(df["Tendecia_media_movil_CRM"]==1,'Decreciente',df["Tendecia_media_movil_CRM"])
    df["Tendecia_media_movil_CRM_categorizada"]=np.where(df["Tendecia_media_movil_CRM"]=='2','Crecreciente',df["Tendecia_media_movil_CRM"])
    df["Tendecia_media_movil_CRM_categorizada"]=np.where(df["Tendecia_media_movil_CRM"]=='3','Constate',df["Tendecia_media_movil_CRM"])
    del df["Tendecia_media_movil_CRM"]


    if df.loc[i,"media_movil_media_movil_ZHab_X"]>df.loc[i+1,"media_movil_media_movil_ZHab_X"]:
        df.loc[i,"Tendecia_media_movil_ZHab_X"]=1
    else:
        if df.loc[i,"media_movil_ZHab_X"]<df.loc[i+1,"media_movil_ZHab_X"]:
            df.loc[i,"Tendecia_media_movil_ZHab_X"]=2
        else:
            df.loc[i,"Tendecia_media_movil_ZHab_X"]=3

    df["Tendecia_media_movil_ZHab_X_categorizada"]=np.where(df["Tendecia_media_movil_ZHab_X"]==1,'Decreciente',df["Tendecia_media_movil_ZHab_X"])
    df["Tendecia_media_movil_ZHab_X_categorizada"]=np.where(df["Tendecia_media_movil_ZHab_X"]=='2','Crecreciente',df["Tendecia_media_movil_ZHab_X"])
    df["Tendecia_media_movil_ZHab_X_categorizada"]=np.where(df["Tendecia_media_movil_ZHab_X"]=='3','Constate',df["Tendecia_media_movil_ZHab_X"])
    del df["Tendecia_media_movil_ZHab_X"]


    if df.loc[i,"media_movil_media_movil_ZHab_Y"]>df.loc[i+1,"media_movil_media_movil_ZHab_Y"]:
        df.loc[i,"Tendecia_media_movil_ZHab_Y"]=1
    else:
        if df.loc[i,"media_movil_ZHab_Y"]<df.loc[i+1,"media_movil_ZHab_Y"]:
            df.loc[i,"Tendecia_media_movil_ZHab_Y"]=2
        else:
            df.loc[i,"Tendecia_media_movil_ZHab_Y"]=3

    df["Tendecia_media_movil_ZHab_Y_categorizada"]=np.where(df["Tendecia_media_movil_ZHab_Y"]==1,'Decreciente',df["Tendecia_media_movil_ZHab_Y"])
    df["Tendecia_media_movil_ZHab_Y_categorizada"]=np.where(df["Tendecia_media_movil_ZHab_Y"]=='2','Crecreciente',df["Tendecia_media_movil_ZHab_Y"])
    df["Tendecia_media_movil_ZHab_Y_categorizada"]=np.where(df["Tendecia_media_movil_ZHab_Y"]=='3','Constate',df["Tendecia_media_movil_ZHab_Y"])
    del df["Tendecia_media_movil_ZHab_Y"]


    if df.loc[i,"media_movil_media_movil_Chol"]>df.loc[i+1,"media_movil_media_movil_Chol"]:
        df.loc[i,"Tendecia_media_movil_Chol"]=1
    else:
        if df.loc[i,"media_movil_Chol"]<df.loc[i+1,"media_movil_Chol"]:
            df.loc[i,"Tendecia_media_movil_Chol"]=2
        else:
            df.loc[i,"Tendecia_media_movil_Chol"]=3

    df["Tendecia_media_movil_Chol_categorizada"]=np.where(df["Tendecia_media_movil_Chol"]==1,'Decreciente',df["Tendecia_media_movil_Chol"])
    df["Tendecia_media_movil_Chol_categorizada"]=np.where(df["Tendecia_media_movil_Chol"]=='2','Crecreciente',df["Tendecia_media_movil_Chol"])
    df["Tendecia_media_movil_Chol_categorizada"]=np.where(df["Tendecia_media_movil_Chol"]=='3','Constate',df["Tendecia_media_movil_Chol"])
    del df["Tendecia_media_movil_Chol"]


    if df.loc[i,"media_movil_media_movil_Thalach"]>df.loc[i+1,"media_movil_media_movil_Thalach"]:
        df.loc[i,"Tendecia_media_movil_Thalach"]=1
    else:
        if df.loc[i,"media_movil_Thalach"]<df.loc[i+1,"media_movil_Thalach"]:
            df.loc[i,"Tendecia_media_movil_Thalach"]=2
        else:
            df.loc[i,"Tendecia_media_movil_Thalach"]=3

    df["Tendecia_media_movil_Thalach_categorizada"]=np.where(df["Tendecia_media_movil_Thalach"]==1,'Decreciente',df["Tendecia_media_movil_Thalach"])
    df["Tendecia_media_movil_Thalach_categorizada"]=np.where(df["Tendecia_media_movil_Thalach"]=='2','Crecreciente',df["Tendecia_media_movil_Thalach"])
    df["Tendecia_media_movil_Thalach_categorizada"]=np.where(df["Tendecia_media_movil_Thalach"]=='3','Constate',df["Tendecia_media_movil_Thalach"])
    del df["Tendecia_media_movil_Thalach"]


    if df.loc[i,"media_movil_media_movil_Trestbps"]>df.loc[i+1,"media_movil_media_movil_Trestbps"]:
        df.loc[i,"Tendecia_media_movil_Trestbps"]=1
    else:
        if df.loc[i,"media_movil_Trestbps"]<df.loc[i+1,"media_movil_Trestbps"]:
            df.loc[i,"Tendecia_media_movil_Trestbps"]=2
        else:
            df.loc[i,"Tendecia_media_movil_Trestbps"]=3

    df["Tendecia_media_movil_Trestbps_categorizada"]=np.where(df["Tendecia_media_movil_Trestbps"]==1,'Decreciente',df["Tendecia_media_movil_Trestbps"])
    df["Tendecia_media_movil_Trestbps_categorizada"]=np.where(df["Tendecia_media_movil_Trestbps"]=='2','Crecreciente',df["Tendecia_media_movil_Trestbps"])
    df["Tendecia_media_movil_Trestbps_categorizada"]=np.where(df["Tendecia_media_movil_Trestbps"]=='3','Constate',df["Tendecia_media_movil_Trestbps"])
    del df["Tendecia_media_movil_Trestbps"]


    if df.loc[i,"media_movil_media_movil_Eccentricity"]>df.loc[i+1,"media_movil_media_movil_Eccentricity"]:
        df.loc[i,"Tendecia_media_movil_Eccentricity"]=1
    else:
        if df.loc[i,"media_movil_Eccentricity"]<df.loc[i+1,"media_movil_Eccentricity"]:
            df.loc[i,"Tendecia_media_movil_Eccentricity"]=2
        else:
            df.loc[i,"Tendecia_media_movil_Eccentricity"]=3

    df["Tendecia_media_movil_Eccentricity_categorizada"]=np.where(df["Tendecia_media_movil_Eccentricity"]==1,'Decreciente',df["Tendecia_media_movil_Eccentricity"])
    df["Tendecia_media_movil_Eccentricity_categorizada"]=np.where(df["Tendecia_media_movil_Eccentricity"]=='2','Crecreciente',df["Tendecia_media_movil_Eccentricity"])
    df["Tendecia_media_movil_Eccentricity_categorizada"]=np.where(df["Tendecia_media_movil_Eccentricity"]=='3','Constate',df["Tendecia_media_movil_Eccentricity"])
    del df["Tendecia_media_movil_Eccentricity"]
