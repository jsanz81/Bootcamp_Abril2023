# %% [markdown]
#  ## Distancia Manhattan
#  sean $x, y \in R^n$ definiremos la distancia Manhattan como:
#  $$d(x,y)=|x_1 - y_1| + |x_2 - y_2| + \ldots + |x_n - y_n|$$
#  su implementación en python sería:

# %%
def manhattan(x,y):
    distancia=0
    for key in x:
        if key in y:
            distancia+=abs(x[key] - y[key])
    return distancia

# %%
users={"Abraham":
            {'Batman':5,
            'Toy Story':3.5,
            'Jumanji':2,
            "Pulp Fiction":5,
            'El Padrino':4.5,
            "Boda en Boda":4,
            "Cars":4},
      "Veronica":
            {'Batman':1,
            'Toy Story':2,
            'Jumanji':4,
            "Pulp Fiction":3,
            'El Padrino':2,
            "Orgullo y Prejuicio":4,
            "Diario de Noa":5},
      "Cayetano":
            {'Batman':1,
            "Boda en Boda":0,
            'Jumanji':1,
            "Pulp Fiction":2,
            'El Padrino':5,
            "Diario de Noa":1,
            "Cars":2},
      "Margarita":
            {'Batman':5,
            'Toy Story':4,
            'Jumanji':5,
            "Diario de Noa":3,
            "Boda en Boda":2,
            "Orgullo y Prejuicio":1,
            "Cars":5},
      "Miguel":
            {"Boda en Boda":2,
            'Toy Story':1,
            'Jumanji':3,
            "Pulp Fiction":2,
            'El Padrino':1,
            "Orgullo y Prejuicio":4,
            "Cars":3},
      "Sara":
            {'Batman':2,
            'Toy Story':3,
            'Jumanji':1,
            "Pulp Fiction":4,
            'Diario de Noa':4,
            "Orgullo y Prejuicio":3,
            "Cars":1},
      "Jorge":
            {'Batman':1,
            'Diario de Noa':2,
            'Jumanji':2,
            "Pulp Fiction":1,
            'El Padrino':5,
            "Boda en Boda":4,
            "Cars":2},
      "Ana":
            {'Batman':2,
            'Toy Story':2.5,
            'Jumanji':3,
            "Pulp Fiction":5,
            'El Padrino':5,
            "Orgullo y Prejuicio":3,
            "Cars":3}}

# %%
users["Ana"]

# %%
manhattan(users["Ana"],users["Cayetano"])
# Out:
# 7

# %%
manhattan(users["Ana"],users["Sara"])
# Out:
# 5.5

# %%
def Vecino(Usuario,x):
    distancias=[]
    for usuario in x:
        if usuario!=Usuario:
            distancia=manhattan(x[Usuario],x[usuario])
            distancias.append((distancia,usuario))
    distancias.sort()
    return distancias

# %%
Vecino("Sara",users)
# Out:
# [(5.5, 'Ana'),
#  (7, 'Cayetano'),
#  (8, 'Jorge'),
#  (8, 'Veronica'),
#  (8.5, 'Abraham'),
#  (9, 'Miguel'),
#  (15, 'Margarita')]

# %%
def recomendacion(Usuario,x):
    cercano=Vecino(Usuario,x)[0][1]
    recomendaciones=[]
    puntuacionvecino=x[cercano]
    puntiacionusuario=x[Usuario]
    for pelicula in puntuacionvecino:
        recomendaciones.append((pelicula,puntuacionvecino[pelicula]))
    return sorted(recomendaciones, 
                 key= lambda pelicula: pelicula[1],
                 reverse = True) ## Reverse para que de de mayor puntiacion a menos

# %%
recomendacion("Sara",users)
# Out:
# [('Pulp Fiction', 5),
#  ('El Padrino', 5),
#  ('Jumanji', 3),
#  ('Orgullo y Prejuicio', 3),
#  ('Cars', 3),
#  ('Toy Story', 2.5),
#  ('Batman', 2)]

# %%
users["Sara"]

# %%
recomendacion("Margarita",users)

# %% [markdown]
# Para implementar la función que me generalice:
# $$d(x,y)=(\sum (|x_i - y_i|)^r)^{\frac{1}{r}}$$

# %%
def generalizado(x,y,r):
    distancia=0
    puntuacioncomun=False
    for key in x:
        if key in y:
            distancia+=pow(abs(x[key] - y[key]),r)
            puntuacioncomun=True
    if puntuacioncomun:
        return pow(distancia,1/r)
    else:
        return 0

# %%
generalizado(users["Ana"],users["Cayetano"],2)

# %%
def Vecino_G(Usuario,x,r):
    distancias=[]
    for usuario in x:
        if usuario!=Usuario:
            distancia=generalizado(x[Usuario],x[usuario],r)
            distancias.append((distancia,usuario))
    distancias.sort()
    return distancias

# %%
Vecino_G("Sara",users,2)

# %%
def recomendacion_G(Usuario,x,r):
    cercano=Vecino_G(Usuario,x,r)[0][1]
    recomendaciones=[]
    puntuacionvecino=x[cercano]
    puntiacionusuario=x[Usuario]
    for pelicula in puntuacionvecino:
        recomendaciones.append((pelicula,puntuacionvecino[pelicula]))
    return sorted(recomendaciones, 
                 key= lambda peliculaTuple: peliculaTuple[1],
                 reverse = True) ## Reverse para que de de mayor puntiacion a menos

# %%
recomendacion_G("Margarita",users,2)

# %%
for i in range(1,3):
    print(i,")\t",Vecino_G("Sara",users,i),"\n")

# %% [markdown]
# ## Coeficiente de Pearson

# %% [markdown]
# $$r=\frac{\sum{x_i y_i}-\frac{\sum{x_i}\sum{y_i}}{n}}
# {\sqrt{\sum{x_i^2}-\frac{(\sum{x_i})^2}{n}}\sqrt{\sum{y_i^2}-\frac{(\sum{y_i})^2}{n}}}$$

# %%
import math
def pearson(U1,U2):
    sum_xy=0
    sum_x=0
    sum_y=0
    sum_x2=0
    sum_y2=0
    n=0
    for key in U1:
        if key in U2:
            n+=1
            x=U1[key]
            y=U2[key]
            sum_xy+=x*y
            sum_x+=x
            sum_y+=y
            sum_x2+=x**2
            sum_y2+=y**2
    if n==0:
        return 0
    denonimandor = pow(sum_x2 - sum_x**2/n,1/2)*pow(sum_y2 - sum_y**2/n,0.5)
    numerador = sum_xy -(sum_x*sum_y)/n
    if denonimandor==0:
        return 0
    else:
        return(numerador/denonimandor)

# %% [markdown]
# ## Coseno
# $$cos(u,v)=\frac{u\times v}{||u|| ||v||}=\frac{\sum{u_i v_i}}{\sqrt[2]{u_1^2+\ldots+u_n^2}\sqrt[2]{v_1^2+\ldots+v_n^2}}$$

# %%
def coseno(U1,U2):
    sumxx, sumxy, sumyy = 0, 0, 0
    for key in U1:
        if key in U2:
            x = U1[key]; 
            y = U2[key]
            sumxx += x*x
            sumyy += y*y
            sumxy += x*y
    if pow(sumxx*sumyy,0.5)==0:
        return 0
    else:
        return sumxy/pow(sumxx*sumyy,0.5)

# %%
coseno(users["Ana"],users["Cayetano"])
# Out:
# 0.9163419338230352

# %%
pearson(users["Ana"],users["Cayetano"])
# Out:
# 0.7257747386024228

# %% [markdown]
# ### Ejercicio

# %%
import pandas as pd

movies = pd.read_csv("./Data/Peliculas.csv", sep=',')

m_cols = ['movie_id', 'title']  
ratings = pd.read_csv('./Data/Clasificacion.csv', sep=',')

tags = pd.read_csv('./Data/tags.csv', sep=',')
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
ratings = pd.merge(movies, ratings)
tags= pd.merge(movies, tags)

# %%
ratings.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       1     4.0   964982703
# 1       5     4.0   847434962
# 2       7     4.5  1106635946
# 3      15     2.5  1510577970
# 4      17     4.5  1305696483

# %%
movieRatings = ratings.pivot_table(index=['userId'],columns=['title'],values='rating')  
movieRatings.head()
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
# 5                          NaN                  NaN
#
# title   'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
#
# title   'burbs, The (1989)  'night Mother (1986)  (500) Days of Summer (2009)  \
# userId
# 1                      NaN                   NaN                          NaN
# 2                      NaN                   NaN                          NaN
# 3                      NaN                   NaN                          NaN
# 4                      NaN                   NaN                          NaN
# 5                      NaN                   NaN                          NaN
#
# title   *batteries not included (1987)  \
# userId
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
#
# title                     ...                      Zulu (2013)  [REC] (2007)  \
# userId                    ...
# 1                         ...                              NaN           NaN
# 2                         ...                              NaN           NaN
# 3                         ...                              NaN           NaN
# 4                         ...                              NaN           NaN
# 5                         ...                              NaN           NaN
#
# title   [REC]² (2009)  [REC]³ 3 Génesis (2012)  \
# userId
# 1                 NaN                      NaN
# 2                 NaN                      NaN
# 3                 NaN                      NaN
# 4                 NaN                      NaN
# 5                 NaN                      NaN
#
# title   anohana: The Flower We Saw That Day - The Movie (2013)  \
# userId
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
#
# title   eXistenZ (1999)  xXx (2002)  xXx: State of the Union (2005)  \
# userId
# 1                   NaN         NaN                             NaN
# 2                   NaN         NaN                             NaN
# 3                   NaN         NaN                             NaN
# 4                   NaN         NaN                             NaN
# 5                   NaN         NaN                             NaN
#
# title   ¡Three Amigos! (1986)  À nous la liberté (Freedom for Us) (1931)
# userId
# 1                         4.0                                        NaN
# 2                         NaN                                        NaN
# 3                         NaN                                        NaN
# 4                         NaN                                        NaN
# 5                         NaN                                        NaN
#
# [5 rows x 9719 columns]

# %% [markdown]
# Sabemos que cada columna contiene todas las calificaciones de los usuarios para una película en particular.
# Busquemos todas las calificaciones de los usuarios de la película "Toy Story" y busquemos películas similares. Elegimos esta película porque tiene el mayor número de calificaciones y queremos encontrar la correlación entre las películas que tienen un mayor número de calificaciones.
#
# ![](https://www.compramejor.es/wp-content/uploads/2020/12/Toy-Storyok.jpg)
#
# Para encontrar las calificaciones de los usuarios de "Toy Story",

# %%
toyStoryRatings = movieRatings['Toy Story (1995)']
# Correlamos el resto de peliculas (columnas) con la seleccionada (toy story)  
similarMovies = movieRatings.corrwith(toyStoryRatings)
corr_similarMovies = pd.DataFrame(similarMovies, columns=['Correlacion'])
corr_similarMovies = corr_similarMovies.dropna()  
corr_similarMovies.head()
# Out:
# C:\Users\Daniel Montes\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2392: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# C:\Users\Daniel Montes\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2326: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
#                                 Correlacion
# title
# 'burbs, The (1989)                 0.240563
# (500) Days of Summer (2009)        0.353833
# *batteries not included (1987)    -0.427425
# 10 Cent Pistol (2015)              1.000000
# 10 Cloverfield Lane (2016)        -0.285732

# %%
corr_similarMovies.sort_values('Correlacion',ascending=False).head(10)
# Out:
#                                                     Correlacion
# title
# Land Before Time III: The Time of the Great Giv...          1.0
# Faster Pussycat! Kill! Kill! (1965)                         1.0
# Amen. (2002)                                                1.0
# Machine Girl, The (Kataude mashin gâru) (2008)              1.0
# Waydowntown (2000)                                          1.0
# Brigadoon (1954)                                            1.0
# Project X (1987)                                            1.0
# Imitation of Life (1959)                                    1.0
# Terminal Velocity (1994)                                    1.0
# Washington Square (1997)                                    1.0

# %% [markdown]
# De la salida se puede ver que las películas que tienen alta correlación con "Toy Story" no son muy conocidas. Esto muestra que la correlación por sí sola no es una buena métrica para la similitud porque puede haber un usuario que vio '"Toy Story" y solo otra película y calificó a ambas como 5.
# ![](https://images-na.ssl-images-amazon.com/images/I/51SbdHjnNkL._SY445_.jpg)
# ![](https://images.photowall.com/products/59973/faster-pussycat-kill-kill-ii.jpg?h=699&q=85)
# ![](https://pics.filmaffinity.com/Kataude_mashin_g_ru_The_Machine_Girl_The_One_Armed_Machine_Girl-294916294-large.jpg)
# ![](https://pics.filmaffinity.com/Am_n-851513422-mmed.jpg)

# %%
ratings_mean_count = pd.DataFrame(ratings.groupby('title')['rating'].mean())
ratings_mean_count['rating_counts'] = pd.DataFrame(ratings.groupby('title')['rating'].count())
corr_similarMovies.join(ratings_mean_count['rating_counts']).sort_values('Correlacion',ascending=False)
# Out:
#                                                     Correlacion  rating_counts
# title
# Land Before Time III: The Time of the Great Giv...          1.0              3
# Faster Pussycat! Kill! Kill! (1965)                         1.0              5
# Amen. (2002)                                                1.0              3
# Machine Girl, The (Kataude mashin gâru) (2008)              1.0              2
# Waydowntown (2000)                                          1.0              3
# Brigadoon (1954)                                            1.0              3
# Project X (1987)                                            1.0              2
# Imitation of Life (1959)                                    1.0              2
# Terminal Velocity (1994)                                    1.0              6
# Washington Square (1997)                                    1.0              2
# Principal, The (1987)                                       1.0              2
# I, Tonya (2017)                                             1.0              3
# Terri (2011)                                                1.0              2
# Marine, The (2006)                                          1.0              2
# Prefontaine (1997)                                          1.0              5
# Pillow Talk (1959)                                          1.0              3
# Marvel One-Shot: Item 47 (2012)                             1.0              2
# The Cloverfield Paradox (2018)                              1.0              2
# The Great Train Robbery (1903)                              1.0              2
# Hush (2016)                                                 1.0              3
# The Hitman's Bodyguard (2017)                               1.0              3
# Final Destination, The (Final Destination 4) (F...          1.0              3
# Police Story 2 (Ging chaat goo si juk jaap) (1988)          1.0              2
# War Zone, The (1999)                                        1.0              2
# Police Story (Ging chaat goo si) (1985)                     1.0              2
# Maxed Out: Hard Times, Easy Credit and the Era ...          1.0              2
# May (2002)                                                  1.0              3
# Boogeyman (2005)                                            1.0              2
# Hall Pass (2011)                                            1.0              4
# Eye, The (Gin gwai) (Jian gui) (2002)                       1.0              2
# ...                                                         ...            ...
# Lovely Bones, The (2009)                                   -1.0              3
# That's My Boy (2012)                                       -1.0              3
# Men at Work (1990)                                         -1.0              4
# Roots (1977)                                               -1.0              3
# High Crimes (2002)                                         -1.0              2
# Love Story (1970)                                          -1.0              2
# Waltz with Bashir (Vals im Bashir) (2008)                  -1.0              5
# Love Potion #9 (1992)                                      -1.0              3
# Inferno (2016)                                             -1.0              4
# That Touch of Mink (1962)                                  -1.0              2
# Ripley's Game (2002)                                       -1.0              3
# I'm Not Scared (Io non ho paura) (2003)                    -1.0              2
# Man Who Knew Too Much, The (1956)                          -1.0              9
# Mandela: Long Walk to Freedom (2013)                       -1.0              2
# Elite Squad: The Enemy Within (Tropa de Elite 2...         -1.0              7
# Respiro (2002)                                             -1.0              2
# Who's That Girl? (1987)                                    -1.0              2
# Man of the Year (2006)                                     -1.0              3
# Return from Witch Mountain (1978)                          -1.0              4
# Our Brand Is Crisis (2015)                                 -1.0              2
# Misérables, Les (2000)                                     -1.0              2
# Magic Mike (2012)                                          -1.0              5
# Malibu's Most Wanted (2003)                                -1.0              3
# Admission (2013)                                           -1.0              4
# True Story (2015)                                          -1.0              2
# In a World... (2013)                                       -1.0              2
# The Drop (2014)                                            -1.0              3
# Mo' Money (1992)                                           -1.0              2
# Truly, Madly, Deeply (1991)                                -1.0              3
# I Was a Male War Bride (1949)                              -1.0              2
#
# [4767 rows x 2 columns]

# %%
import numpy as np  
movieStats = ratings.groupby('title').agg({'rating': [np.size, np.mean]})

popularMovies = movieStats['rating']['size'] >= 100


movieStats[popularMovies].sort_values([('rating', 'mean')], ascending=False)[:15]
# Out:
#                                                    rating
#                                                      size      mean
# title
# Shawshank Redemption, The (1994)                    317.0  4.429022
# Godfather, The (1972)                               192.0  4.289062
# Fight Club (1999)                                   218.0  4.272936
# Godfather: Part II, The (1974)                      129.0  4.259690
# Departed, The (2006)                                107.0  4.252336
# Goodfellas (1990)                                   126.0  4.250000
# Casablanca (1942)                                   100.0  4.240000
# Dark Knight, The (2008)                             149.0  4.238255
# Usual Suspects, The (1995)                          204.0  4.237745
# Princess Bride, The (1987)                          142.0  4.232394
# Star Wars: Episode IV - A New Hope (1977)           251.0  4.231076
# Schindler's List (1993)                             220.0  4.225000
# Apocalypse Now (1979)                               107.0  4.219626
# American History X (1998)                           129.0  4.217054
# Star Wars: Episode V - The Empire Strikes Back ...  211.0  4.215640

# %%
df = movieStats[popularMovies].join(pd.DataFrame(corr_similarMovies, columns=['Correlacion']))

# %%
df.sort_values(['Correlacion'], ascending=False)[:15]
# Out:
#                                                     (rating, size)  \
# title
# Toy Story (1995)                                             215.0
# Incredibles, The (2004)                                      125.0
# Finding Nemo (2003)                                          141.0
# Aladdin (1992)                                               183.0
# Monsters, Inc. (2001)                                        132.0
# Mrs. Doubtfire (1993)                                        144.0
# Amelie (Fabuleux destin d'Amélie Poulain, Le) (...           120.0
# American Pie (1999)                                          103.0
# Die Hard: With a Vengeance (1995)                            144.0
# E.T. the Extra-Terrestrial (1982)                            122.0
# Home Alone (1990)                                            116.0
# Babe (1995)                                                  128.0
# Ghostbusters (a.k.a. Ghost Busters) (1984)                   120.0
# Memento (2000)                                               159.0
# Pirates of the Caribbean: The Curse of the Blac...           149.0
#
#                                                     (rating, mean)  \
# title
# Toy Story (1995)                                          3.920930
# Incredibles, The (2004)                                   3.836000
# Finding Nemo (2003)                                       3.960993
# Aladdin (1992)                                            3.792350
# Monsters, Inc. (2001)                                     3.871212
# Mrs. Doubtfire (1993)                                     3.388889
# Amelie (Fabuleux destin d'Amélie Poulain, Le) (...        4.183333
# American Pie (1999)                                       3.378641
# Die Hard: With a Vengeance (1995)                         3.555556
# E.T. the Extra-Terrestrial (1982)                         3.766393
# Home Alone (1990)                                         2.995690
# Babe (1995)                                               3.652344
# Ghostbusters (a.k.a. Ghost Busters) (1984)                3.775000
# Memento (2000)                                            4.122642
# Pirates of the Caribbean: The Curse of the Blac...        3.778523
#
#                                                     Correlacion
# title
# Toy Story (1995)                                       1.000000
# Incredibles, The (2004)                                0.643301
# Finding Nemo (2003)                                    0.618701
# Aladdin (1992)                                         0.611892
# Monsters, Inc. (2001)                                  0.490231
# Mrs. Doubtfire (1993)                                  0.446261
# Amelie (Fabuleux destin d'Amélie Poulain, Le) (...     0.438237
# American Pie (1999)                                    0.420117
# Die Hard: With a Vengeance (1995)                      0.410939
# E.T. the Extra-Terrestrial (1982)                      0.409216
# Home Alone (1990)                                      0.408444
# Babe (1995)                                            0.407493
# Ghostbusters (a.k.a. Ghost Busters) (1984)             0.404487
# Memento (2000)                                         0.378622
# Pirates of the Caribbean: The Curse of the Blac...     0.370938

# %%
userRatings = ratings.pivot_table(index=['userId'],columns=['title'],values='rating')  
userRatings.head()
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
# 5                          NaN                  NaN
#
# title   'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
#
# title   'burbs, The (1989)  'night Mother (1986)  (500) Days of Summer (2009)  \
# userId
# 1                      NaN                   NaN                          NaN
# 2                      NaN                   NaN                          NaN
# 3                      NaN                   NaN                          NaN
# 4                      NaN                   NaN                          NaN
# 5                      NaN                   NaN                          NaN
#
# title   *batteries not included (1987)  \
# userId
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
#
# title                     ...                      Zulu (2013)  [REC] (2007)  \
# userId                    ...
# 1                         ...                              NaN           NaN
# 2                         ...                              NaN           NaN
# 3                         ...                              NaN           NaN
# 4                         ...                              NaN           NaN
# 5                         ...                              NaN           NaN
#
# title   [REC]² (2009)  [REC]³ 3 Génesis (2012)  \
# userId
# 1                 NaN                      NaN
# 2                 NaN                      NaN
# 3                 NaN                      NaN
# 4                 NaN                      NaN
# 5                 NaN                      NaN
#
# title   anohana: The Flower We Saw That Day - The Movie (2013)  \
# userId
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
#
# title   eXistenZ (1999)  xXx (2002)  xXx: State of the Union (2005)  \
# userId
# 1                   NaN         NaN                             NaN
# 2                   NaN         NaN                             NaN
# 3                   NaN         NaN                             NaN
# 4                   NaN         NaN                             NaN
# 5                   NaN         NaN                             NaN
#
# title   ¡Three Amigos! (1986)  À nous la liberté (Freedom for Us) (1931)
# userId
# 1                         4.0                                        NaN
# 2                         NaN                                        NaN
# 3                         NaN                                        NaN
# 4                         NaN                                        NaN
# 5                         NaN                                        NaN
#
# [5 rows x 9719 columns]

# %%
corrMatrix = userRatings.corr(method='pearson', min_periods=100)  
corrMatrix.head()
# Out:
# title                                    '71 (2014)  \
# title
# '71 (2014)                                      NaN
# 'Hellboy': The Seeds of Creation (2004)         NaN
# 'Round Midnight (1986)                          NaN
# 'Salem's Lot (2004)                             NaN
# 'Til There Was You (1997)                       NaN
#
# title                                    'Hellboy': The Seeds of Creation (2004)  \
# title
# '71 (2014)                                                                   NaN
# 'Hellboy': The Seeds of Creation (2004)                                      NaN
# 'Round Midnight (1986)                                                       NaN
# 'Salem's Lot (2004)                                                          NaN
# 'Til There Was You (1997)                                                    NaN
#
# title                                    'Round Midnight (1986)  \
# title
# '71 (2014)                                                  NaN
# 'Hellboy': The Seeds of Creation (2004)                     NaN
# 'Round Midnight (1986)                                      NaN
# 'Salem's Lot (2004)                                         NaN
# 'Til There Was You (1997)                                   NaN
#
# title                                    'Salem's Lot (2004)  \
# title
# '71 (2014)                                               NaN
# 'Hellboy': The Seeds of Creation (2004)                  NaN
# 'Round Midnight (1986)                                   NaN
# 'Salem's Lot (2004)                                      NaN
# 'Til There Was You (1997)                                NaN
#
# title                                    'Til There Was You (1997)  \
# title
# '71 (2014)                                                     NaN
# 'Hellboy': The Seeds of Creation (2004)                        NaN
# 'Round Midnight (1986)                                         NaN
# 'Salem's Lot (2004)                                            NaN
# 'Til There Was You (1997)                                      NaN
#
# title                                    'Tis the Season for Love (2015)  \
# title
# '71 (2014)                                                           NaN
# 'Hellboy': The Seeds of Creation (2004)                              NaN
# 'Round Midnight (1986)                                               NaN
# 'Salem's Lot (2004)                                                  NaN
# 'Til There Was You (1997)                                            NaN
#
# title                                    'burbs, The (1989)  \
# title
# '71 (2014)                                              NaN
# 'Hellboy': The Seeds of Creation (2004)                 NaN
# 'Round Midnight (1986)                                  NaN
# 'Salem's Lot (2004)                                     NaN
# 'Til There Was You (1997)                               NaN
#
# title                                    'night Mother (1986)  \
# title
# '71 (2014)                                                NaN
# 'Hellboy': The Seeds of Creation (2004)                   NaN
# 'Round Midnight (1986)                                    NaN
# 'Salem's Lot (2004)                                       NaN
# 'Til There Was You (1997)                                 NaN
#
# title                                    (500) Days of Summer (2009)  \
# title
# '71 (2014)                                                       NaN
# 'Hellboy': The Seeds of Creation (2004)                          NaN
# 'Round Midnight (1986)                                           NaN
# 'Salem's Lot (2004)                                              NaN
# 'Til There Was You (1997)                                        NaN
#
# title                                    *batteries not included (1987)  \
# title
# '71 (2014)                                                          NaN
# 'Hellboy': The Seeds of Creation (2004)                             NaN
# 'Round Midnight (1986)                                              NaN
# 'Salem's Lot (2004)                                                 NaN
# 'Til There Was You (1997)                                           NaN
#
# title                                                      ...                      \
# title                                                      ...
# '71 (2014)                                                 ...
# 'Hellboy': The Seeds of Creation (2004)                    ...
# 'Round Midnight (1986)                                     ...
# 'Salem's Lot (2004)                                        ...
# 'Til There Was You (1997)                                  ...
#
# title                                    Zulu (2013)  [REC] (2007)  \
# title
# '71 (2014)                                       NaN           NaN
# 'Hellboy': The Seeds of Creation (2004)          NaN           NaN
# 'Round Midnight (1986)                           NaN           NaN
# 'Salem's Lot (2004)                              NaN           NaN
# 'Til There Was You (1997)                        NaN           NaN
#
# title                                    [REC]² (2009)  \
# title
# '71 (2014)                                         NaN
# 'Hellboy': The Seeds of Creation (2004)            NaN
# 'Round Midnight (1986)                             NaN
# 'Salem's Lot (2004)                                NaN
# 'Til There Was You (1997)                          NaN
#
# title                                    [REC]³ 3 Génesis (2012)  \
# title
# '71 (2014)                                                   NaN
# 'Hellboy': The Seeds of Creation (2004)                      NaN
# 'Round Midnight (1986)                                       NaN
# 'Salem's Lot (2004)                                          NaN
# 'Til There Was You (1997)                                    NaN
#
# title                                    anohana: The Flower We Saw That Day - The Movie (2013)  \
# title
# '71 (2014)                                                                             NaN
# 'Hellboy': The Seeds of Creation (2004)                                                NaN
# 'Round Midnight (1986)                                                                 NaN
# 'Salem's Lot (2004)                                                                    NaN
# 'Til There Was You (1997)                                                              NaN
#
# title                                    eXistenZ (1999)  xXx (2002)  \
# title
# '71 (2014)                                           NaN         NaN
# 'Hellboy': The Seeds of Creation (2004)              NaN         NaN
# 'Round Midnight (1986)                               NaN         NaN
# 'Salem's Lot (2004)                                  NaN         NaN
# 'Til There Was You (1997)                            NaN         NaN
#
# title                                    xXx: State of the Union (2005)  \
# title
# '71 (2014)                                                          NaN
# 'Hellboy': The Seeds of Creation (2004)                             NaN
# 'Round Midnight (1986)                                              NaN
# 'Salem's Lot (2004)                                                 NaN
# 'Til There Was You (1997)                                           NaN
#
# title                                    ¡Three Amigos! (1986)  \
# title
# '71 (2014)                                                 NaN
# 'Hellboy': The Seeds of Creation (2004)                    NaN
# 'Round Midnight (1986)                                     NaN
# 'Salem's Lot (2004)                                        NaN
# 'Til There Was You (1997)                                  NaN
#
# title                                    À nous la liberté (Freedom for Us) (1931)
# title
# '71 (2014)                                                                     NaN
# 'Hellboy': The Seeds of Creation (2004)                                        NaN
# 'Round Midnight (1986)                                                         NaN
# 'Salem's Lot (2004)                                                            NaN
# 'Til There Was You (1997)                                                      NaN
#
# [5 rows x 9719 columns]

# %%
myRatings = userRatings.loc[105].dropna()


myRatings

# %%
posiblesSimilares = pd.Series()


for i in range(0, len(myRatings.index)):  
    
   
    sims = corrMatrix[myRatings.index[i]].dropna()
   
    sims = sims.map(lambda x: x * myRatings[i])
    
   
    posiblesSimilares = posiblesSimilares.append(sims)

    posiblesSimilares = posiblesSimilares.groupby(posiblesSimilares.index).sum()

    filtered = posiblesSimilares.drop(myRatings.index,errors='ignore')  
    filtered.head(10) 
    print("Similares a " + myRatings.index[i] , filtered.head(10))
